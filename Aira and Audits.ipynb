# %%
# !pwd
# Out:
# /home/dileep/Desktop/python

# %%
import requests
from pymongo import MongoClient

# %% [markdown]
# # Notegen

# %%
import pandas as pd
import numpy as np

# %%
# Connecting to server
client2 = MongoClient("mongodb://dhruvsud:7zyCxVyg7iXmr07G@13.234.5.82:27017/emr-local?authSource=admin")
db2 = client2['emr-local']

# %%
client2 = MongoClient('mongodb://localhost:27017/dbMallige')
db2 = client2['dbMallige']

# %% [markdown]
# ## CVS

# %%
pat_obj = list(db2.patients.find({'name':'Malle Gowda'}))

# %%
def getSubhead(pat_obj, head):
    for key, obj in (pat_obj[0]).items():
        if (key == head):
            subhead = obj
    return subhead

# %%
all_pats[2]['documents'][0]
# Out:
# {'tags': ['Procedures', 'Cardiac', 'ECG', None],
#  '_id': ObjectId('5cfcfc2d8f8e8c3ed970cbb5'),
#  'key': 'images/1316975849:2019-06-09T12:31:40.832Z.jpg',
#  'reportedAt': datetime.datetime(2019, 6, 9, 12, 22, 17, 247000),
#  'updatedAt': datetime.datetime(2019, 6, 9, 12, 31, 41, 302000),
#  'createdAt': datetime.datetime(2019, 6, 9, 12, 31, 41, 302000)}

# %%
for x in range(len(all_pats)):
    pat_obj = all_pats[x]
    getVitalList(pat_obj)

# %%
def getVitalList(pat_obj):    
    temp_list = []; vit_list = [];
    pat_days = pat_obj['days']
    for i in range(len(pat_days)):
        if ((datetime.datetime.now() - (pat_days[i]).get('dayDate')) > timedelta(days = 2)):
            continue
        for j in range(len(pat_days[i]['hours'])):
            h = pat_days[i]['hours'][j]['hourNumber']
            obj = pat_days[i]['hours'][j]['minutes'][0]['vitals']
            if ((obj.get('daysTemperature') != None) & (obj.get('daysTemperature') != '')):
                temparature = obj['daysTemperature']
            else: 
                temparature = None
            if ((obj.get('daysHR') != None) & (obj.get('daysHR') != '')):
                hr = obj['daysHR']
            else: 
                hr = None
            if ((obj.get('daysRR') != None) & (obj.get('daysRR') != '')):
                rr = obj['daysRR']
            else: 
                rr = None
            if ((obj.get('daysBP') != None) & (obj.get('daysBP') != '')):
                bp = obj['daysBP']
            else: 
                bp = None
            if ((obj.get('daysMAP') != None) & (obj.get('daysMAP') != '')):
                Map = obj['daysMAP']
            else: 
                Map = None
            #cvp = obj['daysCVP'] CVP is not present consistently in all records
            cvp = None
            if ((obj.get('daysSpO2') != None) & (obj.get('daysSpO2') != '')):
                spo2 = obj['daysSpO2']
            else: 
                spo2 = None
            if ((obj.get('daysFiO2') != None) & (obj.get('daysFiO2') != '')):
                fio2 = obj['daysFiO2']
            else: 
                fio2 = None
            temp_list.append([h, temparature, hr, rr, bp, Map, cvp, spo2, fio2])
            vit_list.append(temp_list)
            temp_list = []
    return vit_list

# %%
def getLatestVital(vitalList, vital):
    keys = {'temparature':1, 'hr':2, 'rr':3, 'bp':4, 'Map':5, 'cvp':6, 'spo2':7, 'fio2':8}
    value = None
    for i in range(len(vitalList)):
        if (vitalList[i][0][keys[vital]] != None):
            value = vitalList[i][0][keys[vital]]
            break
    if (value == None):
        value = np.nan
    return value

# %%
pat_obj = all_pats[1]
days = pat_obj['days']

# %%
for x in range(len(days)):
    print(datetime.datetime.now() - days[x].get('dayDate') > timedelta(days = 2))
# Out:
# True
# True

# %%
def getVitals(pat_obj):
    
    v_list = getVitalList(pat_obj)
    
    if(type(getLatestVital(v_list, 'bp')) is str):
        sbp = pd.to_numeric(getLatestVital(v_list, 'bp').split('/')[0])
        dbp = pd.to_numeric(getLatestVital(v_list, 'bp').split('/')[1])
    elif(np.isnan(getLatestVital(v_list, 'bp'))):
        sbp = np.nan
        dbp = np.nan
    
    vits = [['daysHR', pd.to_numeric(getLatestVital(v_list, 'hr'))], 
    ['daysBP', getLatestVital(v_list, 'bp')], 
    ['daysRR', pd.to_numeric(getLatestVital(v_list, 'rr'))], 
    ['daysMAP', pd.to_numeric(getLatestVital(v_list, 'Map'))], 
    ['daysSpO2', pd.to_numeric(getLatestVital(v_list, 'spo2'))], 
    ['daysFiO2', pd.to_numeric(getLatestVital(v_list, 'fio2'))], 
    ['sbp', sbp], 
    ['dbp', dbp]]
    
    return vits

# %%
def getPressorString(pat_obj):
    
    if (pat_obj[0].get('isPressor') != None):    
        if (pat_obj[0]['isPressor'] == True):
            pressor_string = 'Patient is on IV vasopressors. '
        else:
            pressor_string = ''
    else:
        pressor_string = ''
    
    return pressor_string

# %%
def getCvsString(pat_obj):
    '''
    **getVitals(mrn) %>% getCvsString().get() %>% "CVS string"
    '''
    import numpy as np

    vitals = getVitals(pat_obj)
    pressor_string = getPressorString(pat_obj)

    for key, value in vitals:
        if (key == 'daysMAP'):
            daysMap = value
        if (key == 'daysHR'):
            hr = value
        if (key == 'daysBP'):
            bp = value

    if (np.isnan(daysMap) == True):
        map_str = 'No MAP recorded. '
    elif ((daysMap>(normals['daysMAP'][0])) & (pressor_string == '')):
        map_str = 'Hemodynamically stable. '
    elif (daysMap<(normals['daysMAP'][0])):
        map_str = 'Hemodynamically unstable. '
    elif (pressor_string != ''):
        map_str = 'Hemodynamically unstable. ' + pressor_string

    if (type(bp) is str):
        bp_str = 'Last measured BP is ' + bp + '. '
    elif (np.isnan(bp) == True):
        bp_str = 'BP not available in records'

    hr_str = ''
    if ((hr>(normals['daysHR'][0])) & (hr<(normals['daysHR'][1]))):
        hr_str = ''
    elif (hr<(normals['daysHR'][0])):
        hr_str = 'Bradycardic with HR of ' + str(hr) + '. '
    elif (hr>(normals['daysHR'][1])):
        hr_str = 'Tachycardic with HR of ' + str(hr) + '. '

    cvsString = map_str + bp_str + hr_str

    return cvsString

# %% [markdown]
# ## CNS

# %%
def getLatestGCS(gcsList, param):
    keys = {'eyes':1, 'verbal':2, 'motor':3}
    value = None
    for i in range(len(gcsList)):
        if (gcsList[i][0][keys[param]] != None):
            value = gcsList[i][0][keys[param]]
            break
    return value

# %%
def getGCSList(pat_obj):    
    temp_list = []; gcs_list = [];
    pat_days = (getSubhead(pat_obj, 'days'))
    for i in range(len(pat_days)):
        for j in range(len(pat_days[i]['hours'])):
            h = pat_days[i]['hours'][j]['hourNumber']
            obj = pat_days[i]['hours'][j]['minutes'][0]['vitals']
            if ((obj.get('daysGCSeyes') != None) & (obj.get('daysGCSeyes') != '')):
                eyes = obj['daysGCSeyes']
            else: 
                eyes = None
            if ((obj.get('daysGCSverbal') != None) & (obj.get('daysGCSverbal') != '')):
                verbal = obj['daysGCSverbal']
            else: 
                verbal = None
            if ((obj.get('daysGCSmotor') != None) & (obj.get('daysGCSmotor') != '')):
                motor = obj['daysGCSmotor']
            else: 
                motor = None
            temp_list.append([h, eyes, verbal, motor])
            gcs_list.append(temp_list)
            temp_list = []
    return gcs_list

# %%
def getCNSstring(pat_obj):
    '''
    Wraps getGCS()
    Takes in mrn and returns "GCS string"
    '''
    gcs = getGCSList(pat_obj); e = getLatestGCS(gcs, 'eyes'); v = getLatestGCS(gcs, 'verbal'); m = getLatestGCS(gcs, 'motor')

    if ((e == None) | (v == None) | (m == None)):
        cns_string = 'GCS not available in chart'
    else:
        cns_string = 'E' + str(round(e)) + 'V' + str(round(v)) + 'M' + str(round(m)) + '. '
    return cns_string

# %% [markdown]
# ## Getting system attributes and cleaning

# %%
def getAttributes(pat_obj):
    '''
    *Takes in mrn and returns info collected from all the documents for the patient 
    *Returns a list of lists with each list has a group of labs - {key: value} and 
    the time stamp for the group of labs
    '''
    tab = []; 
    for i in range(len(pat_obj[0]['documents'])):
        pat = [];
        if ((pat_obj[0]['documents'][i]).get('attributes') != None):
            if (pat_obj[0]['documents'][i] != {}):
                if (pat_obj[0]['documents'][i]['attributes'] != {}):
                    pat.append((pat_obj[0]['documents'][i]['attributes']))
                    pat.append(pat_obj[0]['documents'][i]['updatedAt'])
                tab.append(pat)
    return tab

# %%
def getPairs(tab):
    '''
    *Takes in output from getAttributes()
    *Returns [[key, value], timestamp, type] of each lab
    '''
    #For pH in abg, urinalysis and bunch of other stuff, assignment of type has to 
    #go in the outer loop and not inner loop - stuff for version 2
    lol = []; item = []; 
    for i in range(len(tab)):
        dic = tab[i][0]
        if (dic.get('Color') != None):
            continue
        for pair, value in dic.items():
            if (types.get(pair) != None):
                if (value != ''):
                    item.append([pair, value])
                    item.append(tab[i][1])
                    item.append(types[pair])
                    lol.append(item);
                    item = []
                else:
                    continue
            else:
                continue
    return lol

# %%
def Sort(sub_li, sort_index):
    '''
    *Takes in input from getPairs and sorts items as newest on the top (using timestamp)
    '''
    sub_li.sort(key = lambda x: x[sort_index])
    return sub_li

# %%
def systemWiseSplit (prs):
    '''
    According to the type of the lab, splits the document list into eight seperate lists
    '''
    cvs = []; cns = []; ren = []; abg = []; Id = []; gi = []; endo = []; heme = []; lipids = [];
    for i in range(len(prs)):
        if (prs[i][2] == 'abg'):
            abg.append(prs[i])
        if (prs[i][2] == 'cvs'):
            cvs.append(prs[i])
        if (prs[i][2] == 'cns'):
            cns.append(prs[i])
        if (prs[i][2] == 'ren'):
            ren.append(prs[i])
        if (prs[i][2] == 'Id'):
            Id.append(prs[i])
        if (prs[i][2] == 'gi'):
            gi.append(prs[i])
        if (prs[i][2] == 'endo'):
            endo.append(prs[i])
        if (prs[i][2] == 'heme'):
            heme.append(prs[i])
        if (prs[i][2] == 'lipids'):
            lipids.append(prs[i])
    return (cvs, cns, ren, abg, Id, gi, endo, heme, lipids)

# %%
def getLatest(i_string):
    '''
    Extracts just the latest set of labs (by looking at the time stamp)
    '''
    latest = []
    s = set()
    for a, b, c in i_string:
        s.add(b)
    if (len(s) == 1):
        for a, b, c in i_string:
            latest.append(a)
    elif (len(s) > 1):
        for i in range(len(i_string)):
            if (i_string[i][1] == i_string[i+1][1]):
                latest.append(i_string[i][0])
            else:
                latest.append(i_string[i][0])
                break
    return latest

# %%
px = [[['Troponin T', 'Positive'], datetime.datetime.now(), 'heme']]

# %%
interpret(px)
# Out:
# [[['Troponin T', 'Positive', 'Positive'],
#   datetime.datetime(2019, 7, 29, 17, 15, 40, 261014),
#   'heme']]

# %%
st = 'ABCD'
st.lower()
# Out:
# 'abcd'

# %%
at = getAttributes([pat_obj])
pr = getPairs(at)
inte = interpret(pr)
sr = Sort(inte, 2)
cvs, cns, ren, abg, Id, gi, endo, heme, lipids = systemWiseSplit(sr)
getLatest(cvs)
# Out:
# [['Troponin T', '19.85', 'high']]

# %%
def interpret(pairs):
    '''
    Creates pairs of [[key, value, interpretation], timestamp, type] from [[key, value], timestamp, type]
    '''
    import numpy as np
    import copy
    interp = copy.deepcopy(pairs)
    for i in range(len(pairs)):
        try:
            pd.to_numeric(pairs[i][0][1])
        except ValueError:
            interp[i][0].append(pairs[i][0][1])
            return interp
        if ((pd.to_numeric(pairs[i][0][1]) == np.nan)):
            interp[i][0].append('no value')
        if ((pd.to_numeric(pairs[i][0][1]) >= normals[pairs[i][0][0]][0]) & 
            (pd.to_numeric(pairs[i][0][1]) <= normals[pairs[i][0][0]][1])):
            interp[i][0].append('normal')
        if ((pd.to_numeric(pairs[i][0][1]) < normals[pairs[i][0][0]][0])):
            interp[i][0].append('low')
        if ((pd.to_numeric(pairs[i][0][1]) > normals[pairs[i][0][0]][1])):
            interp[i][0].append('high')
    return interp

# %% [markdown]
# ## Resp

# %%
def getABGstring(pairs):
    '''
    Takes in abg list (product of above funcitons) and outputs "ABG string"
    '''
    if (pairs == []):
        return ''
    lactate = None
    for name, num, value in pairs:
        if (name == 'pH'):
            pH = value
            pH_val = num
        if (name == 'PaCO2'):
            paCO2 = value
            paCO2_val = num
        if (name == 'PaO2'):
            paO2 = value
            paO2_val = num
        if (name == 'Bicarb'):
            Bicarb = value
            Bicarb_val = num
        if (name == 'Lactic'):
            lactate = value
            lactate_val = num
    if (pH == 'low'):
        if ((paCO2 == 'high') & ((Bicarb == 'high') | (Bicarb == 'normal'))):
            abg_string = 'ABG suggestive of respiratory acidosis. '
        elif (((paCO2 == 'normal') | (paCO2 == 'low')) & (Bicarb == 'low')):
            abg_string = 'ABG suggestive of metabolic acidosis. '
        else:
            abg_string = 'ABG: pH ' + str(pH_val) + ' PaCO2 ' + str(paCO2_val) + ' PaO2 ' + str(paO2_val) + ' Bicarb ' + str(Bicarb_val) + '. '
    elif (pH == 'high'):
        if ((paCO2 == 'low') & ((Bicarb == 'low') | (Bicarb == 'normal'))):
            abg_string = 'ABG suggestive of respiratory alkalosis. '
        elif (((paCO2 == 'normal') | (paCO2 == 'high')) & (Bicarb == 'high')):
            abg_string = 'ABG suggestive of metabolic alkalosis. '
        else:
            abg_string = 'ABG: pH ' + str(pH_val) + ' PaCO2 ' + str(paCO2_val) + ' PaO2 ' + str(paO2_val) + ' Bicarb ' + str(Bicarb_val) + '. '
    elif ((pH == 'normal') & (paCO2 == 'normal') & (Bicarb == 'normal') & (paO2 == 'normal')):
        abg_string = 'ABG reviewed, normal'
    else:
        abg_string = 'ABG: pH ' + str(pH_val) + ' PaCO2 ' + str(paCO2_val) + ' PaO2 ' + str(paO2_val) + ' Bicarb ' + str(Bicarb_val) + '. '

    if (lactate == None):
        lac_string = 'Lactate not available. '
    elif (lactate == 'normal'):
        lac_string = 'Lactate normal. '
    elif (lactate == 'high'):
        lac_string = 'Lactic acidosis with lactate of ' + lactate_val + '. '

    return (abg_string + lac_string)

# %%
def getOxygenDeliv(pat_obj):
    '''
    Takes in mrn and outputs a list of [oxDeliveryTechnique, True/False, timestamp]
    '''
    ox_delivery = ['isNIV', 'isIntubated', 'isTrach']
    from datetime import datetime
    t = []; ox_all = [];
    for i, ox in enumerate(ox_delivery):
        if ((pat_obj[0]).get(ox) == None):
            continue
        else:
            ox_list = pat_obj[0][ox]
            if ((pat_obj[0]).get(ox) == None):
                t.append([ox, None, None])
            else:
                ox_bool = ox_list['value']
                ox_datetime = datetime.utcfromtimestamp(ox_list['timestamp']/1000)
                t.append([ox, ox_bool, ox_datetime])
            ox_all.append(t)
            t = []
    return ox_all

# %%
def getOxString(pat_obj):
    '''
    Wraps getOxygenDeliv()
    Takes in mrn and outputs "ox_string"
    '''
    ox_all = getOxygenDeliv(pat_obj)
    vitals = getVitals(pat_obj)
    
    for name, value in vitals:
        if (name == 'daysSpO2'):
            spo2 = str(value)
        if (name == 'daysFiO2'):
            fio2 = str(value)
    
    ox_string = ''
    if (ox_all == []):
        ox_string = ''
    else:
        for idx, ls in enumerate(ox_all):
            for ox, ox_bool, dt in ls:
                if (ox_bool == True):
                    if (ox == 'isNIV'):
                        ox_string = 'Patient is in NIV saturating ' + spo2 + '% on ' + fio2 + '% FiO2. '
                    elif (ox == 'isTrach'):
                        ox_string = 'Patient on trach collar saturating ' + spo2 + '% on ' + fio2 + '% FiO2. '
                    elif (ox == 'isIntubated'):
                        ox_string = 'Patient is intubated saturating ' + spo2 + '% on ' + fio2 + '% FiO2. Intubated on ' + dt.strftime("%m/%d/%Y, %I:%M %p") + '. '
    if (ox_string == ''):
        ox_string = 'Saturating ' + spo2 + '% on ' + fio2 + '% FiO2. ' 
    
    return ox_string

# %%
tab = getAttributes(pat_obj)
prs = getPairs(tab)
prs_sorted = Sort(prs, 2)
cvs, cns, ren, abg, Id, gi, endo, heme, lipids = systemWiseSplit(prs_sorted)

# %%
abg_i = interpret(abg)
abg_l = getLatest(abg_i)
getABGstring(abg_l)
# Out:
# 'ABG suggestive of metabolic acidosis. Lactate not available. '

# %%
lipidAnalysis(lipids)
# Out:
# ''

# %% [markdown]
# ## Lipids

# %%
def lipidAnalysis(lipids):
    if (lipids == []):
        lipid_str = ''
    else:
        for i in range(len(lipids)):
            for j in range(len(lipids[i])):
                if (lipids[i][0][0] != 'HDL'):
                    if(pd.to_numeric(lipids[i][0][1]) > (normals[(lipids[i][0][0])][1])):
                        lipid_str = 'Abnormal lipid panel'
                elif (lipids[i][0][0] == 'HDL'):
                    if(pd.to_numeric(lipids[i][0][1]) < (normals[(lipids[i][0][0])][1])):
                        lipid_str = 'Abnormal lipid panel. '
    return lipid_str

# %% [markdown]
# ## Renal

# %%
ren_i = interpret2(ren).get()
ren_l = getLatest(ren_i)
highlowStrings(ren_l).get()
# Out:
# ''

# %% [markdown]
# ## GI

# %%
gi_i = interpret2(gi).get()
gi_l = getLatest(gi_i)
highlowStrings(gi_l).get()
# Out:
# ''

# %% [markdown]
# ## Endo

# %%
endo_i = interpret2(endo).get()
if (endo_i != []):
    endo_str = 'Last GRBS measured at ' + (endo_i[0][1]).strftime("%B %d %Y, %I:%M %p") + ' and is ' + endo_i[0][0][2] + '(' + endo_i[0][0][1] + ')'
endo_str
# Out:
# 'Last GRBS measured at June 16 2019, 11:00 AM and is high(272)'

# %% [markdown]
# ## Heme

# %%
heme_i = interpret2(heme).get()
heme_l = getLatest(heme_i)
highlowStrings(heme_l).get()
# Out:
# ''

# %% [markdown]
# ## Lines and tubes

# %%
def getFoleyString(pat_obj):
    '''
    Takes in mrn and outputs "Foley string"
    '''
    ord_list = pat_obj[0]['orders']['active']['procedures']
    f_string = ''
    if (ord_list != []):
        for i in range(len(ord_list)):
            if (ord_list[i]['pType'] == 'Foley'):
                f_string = 'Foley in situ, inserted on ' + (ord_list[i]['startTime']).strftime("%B %d %Y, %I:%M %p")
            else:
                continue
    else:
        f_string = 'No Foley in situ'
    if (f_string == ''):
        f_string = 'No Foley in situ'
    return f_string

# %% [markdown]
# ## Intake output - needs fixing

# %%
pat_obj[0]['io']
# Out:
# {'props': {'drain': [], 'procedure': [], 'dialysis': []},
#  'days': [{'_id': ObjectId('5d098db834a42876ffb06111'),
#    'dayDate': datetime.datetime(2019, 6, 19, 0, 0),
#    'dayNumber': 2,
#    'hours': [{'_id': ObjectId('5d098db834a428201fb06112'),
#      'hourName': 6,
#      'minutes': [{'intake': {'meds': {'infusion': [], 'bolus': []},
#         'others': {'name': 'total intake', 'amount': 2175, 'note': ''}},
#        'output': {'urine': {'amount': 1200, 'note': ''},
#         'drain': [],
#         'procedure': [],
#         'dialysis': []},
#        '_id': ObjectId('5d098db834a4288b4db06113'),
#        'minuteName': 40}]}]}]}

# %%
y[0]['io']['days'][0]
# Out:
# {'_id': ObjectId('5cf713ae4beb6e79451ba17d'),
#  'dayDate': datetime.datetime(2019, 6, 5, 0, 0),
#  'dayNumber': 2.0,
#  'hours': [{'_id': ObjectId('5cf713ae4beb6e17a61ba17e'),
#    'hourName': 6.0,
#    'minutes': [{'intake': {'meds': {'infusion': [], 'bolus': []}},
#      'output': {'urine': {'amount': 1800.0, 'note': ''},
#       'drain': [],
#       'procedure': [],
#       'dialysis': []},
#      '_id': ObjectId('5cf713ae4beb6e72aa1ba17f'),
#      'minuteName': 28.0}]}]}

# %%
for i in range(len(all_pats)):
    print('============{}==========='.format(i))
    print(getIOStr(all_pats[i]['io']))
# Out:
# ============0===========
# ('Recorded intake and output for last 24 hrs is 570 and 400 respectively. ', 'Recorded urine output for last 24 hrs is 400')
# ============1===========
# ('Recorded intake and output for last 24 hrs is 0 and 4250 respectively. ', 'Recorded urine output for last 24 hrs is 4250')
# ============2===========
# ('Recorded intake and output for last 24 hrs is 1100 and 1200 respectively. ', 'Recorded urine output for last 24 hrs is 1200')
# ============3===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============4===========
# ('Recorded intake and output for last 24 hrs is 0 and 600 respectively. ', 'Recorded urine output for last 24 hrs is 600')
# ============5===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============6===========
# ('Recorded intake and output for last 24 hrs is 2845 and 0 respectively. ', 'Recorded urine output for last 24 hrs is 0')
# ============7===========
# ('Recorded intake and output for last 24 hrs is 300 and 400 respectively. ', 'Recorded urine output for last 24 hrs is 400')
# ============8===========
# ('Recorded intake and output for last 24 hrs is 2014 and 2080 respectively. ', 'Recorded urine output for last 24 hrs is 2080')
# ============9===========
# ('Recorded intake and output for last 24 hrs is 621 and 4200 respectively. ', 'Recorded urine output for last 24 hrs is 4200')
# ============10===========
# ('Recorded intake and output for last 24 hrs is 2175 and 1200 respectively. ', 'Recorded urine output for last 24 hrs is 1200')
# ============11===========
# ('Recorded intake and output for last 24 hrs is 1640 and 1740 respectively. ', 'Recorded urine output for last 24 hrs is 1690')
# ============12===========
# ('Recorded intake and output for last 24 hrs is 1560 and 1735 respectively. ', 'Recorded urine output for last 24 hrs is 1685')
# ============13===========
# ('Recorded intake and output for last 24 hrs is 1800 and 700 respectively. ', 'Recorded urine output for last 24 hrs is 300')
# ============14===========
# ('Recorded intake and output for last 24 hrs is 2610 and 3025 respectively. ', 'Recorded urine output for last 24 hrs is 3025')
# ============15===========
# ('Recorded intake and output for last 24 hrs is 1070 and 900 respectively. ', 'Recorded urine output for last 24 hrs is 900')
# ============16===========
# ('Recorded intake and output for last 24 hrs is 3450 and 2600 respectively. ', 'Recorded urine output for last 24 hrs is 2600')
# ============17===========
# ('Recorded intake and output for last 24 hrs is 2200 and 3880 respectively. ', 'Recorded urine output for last 24 hrs is 3880')
# ============18===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============19===========
# ('Recorded intake and output for last 24 hrs is 985 and 275 respectively. ', 'Recorded urine output for last 24 hrs is 275')
# ============20===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============21===========
# ('Recorded intake and output for last 24 hrs is 1519 and 0 respectively. ', 'Recorded urine output for last 24 hrs is 0')
# ============22===========
# ('Recorded intake and output for last 24 hrs is 72 and 2100 respectively. ', 'Recorded urine output for last 24 hrs is 2100')
# ============23===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============24===========
# ('Recorded intake and output for last 24 hrs is 2900 and 1850 respectively. ', 'Recorded urine output for last 24 hrs is 850')
# ============25===========
# ('Recorded intake and output for last 24 hrs is 575 and 1495 respectively. ', 'Recorded urine output for last 24 hrs is 1495')
# ============26===========
# ('Recorded intake and output for last 24 hrs is 2100 and 1300 respectively. ', 'Recorded urine output for last 24 hrs is 1100')
# ============27===========
# ('Recorded intake and output for last 24 hrs is 1321 and 1090 respectively. ', 'Recorded urine output for last 24 hrs is 1090')
# ============28===========
# ('Recorded intake and output for last 24 hrs is 1500 and 1425 respectively. ', 'Recorded urine output for last 24 hrs is 1425')
# ============29===========
# ('Recorded intake and output for last 24 hrs is 799 and 2900 respectively. ', 'Recorded urine output for last 24 hrs is 2900')
# ============30===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============31===========
# ('Recorded intake and output for last 24 hrs is 3605 and 3390 respectively. ', 'Recorded urine output for last 24 hrs is 3270')
# ============32===========
# ('Recorded intake and output for last 24 hrs is 0 and 1950 respectively. ', 'Recorded urine output for last 24 hrs is 1950')
# ============33===========
# ('Recorded intake and output for last 24 hrs is 2050 and 2265 respectively. ', 'Recorded urine output for last 24 hrs is 2265')
# ============34===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============35===========
# ('Recorded intake and output for last 24 hrs is 0 and 1300 respectively. ', 'Recorded urine output for last 24 hrs is 1300')
# ============36===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============37===========
# ('Recorded intake and output for last 24 hrs is 0 and 1600 respectively. ', 'Recorded urine output for last 24 hrs is 1600')
# ============38===========
# ('Recorded intake and output for last 24 hrs is 300 and 850 respectively. ', 'Recorded urine output for last 24 hrs is 850')
# ============39===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============40===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============41===========
# ('Recorded intake and output for last 24 hrs is 0 and 1350 respectively. ', 'Recorded urine output for last 24 hrs is 1350')
# ============42===========
# ('Recorded intake and output for last 24 hrs is 0 and 1035 respectively. ', 'Recorded urine output for last 24 hrs is 1035')
# ============43===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============44===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============45===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============46===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============47===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============48===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============49===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# ============50===========
# ('Recorded intake and output for last 24 hrs is 880 and 590 respectively. ', 'Recorded urine output for last 24 hrs is 590')
# ============51===========
# ('Recorded intake and output for last 24 hrs is 1563 and 1200 respectively. ', 'Recorded urine output for last 24 hrs is 1200')
# ============52===========
# ('Recorded intake and output for last 24 hrs is 2600 and 600 respectively. ', 'Recorded urine output for last 24 hrs is 600')
# ============53===========
# ('Recorded intake and output for last 24 hrs is 3997 and 3075 respectively. ', 'Recorded urine output for last 24 hrs is 3075')
# ============54===========
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')

# %%
def getIO(pat_io):
    intake_tot = []; output_tot = []; urine_tot = []
    days = pat_io.get('days')
    days_list = [sublist for sublist in days if sublist]
    # Iterating inside each day
    days_i = 0; days_o = 0; days_u = 0; dayAdd = 24
    intake_ls = []; output_ls = []; urine_ls = []
    for j in range(len(days_list)):
        hrs = days_list[j].get('hours')
        hrs_list = [sublist for sublist in hrs if sublist]
        # Iterating inside each hour
        for k in range(len(hrs_list)):
            hr_name = hrs_list[k].get('hourName') + dayAdd
            mts = hrs_list[k].get('minutes')
            mts_list = [sublist for sublist in mts if sublist]
            for l in range(len(mts_list)):
                intake = mts_list[l].get('intake')
                for name, value in intake.items():
                    for key, num in value.items():
                        if (type(num) == int):
                            days_i += num
                output = mts_list[l].get('output')
                for name, value in output.items():
                    if (value):
                        if (type(value) == list):
                            value = value[0]
                        for key, num in value.items():
                            if (type(num) == int):
                                days_o += num
                                if (name == 'urine'):
                                    days_u += num
        # Creating lists of days outputs
        intake_tot.append(days_i)
        output_tot.append(days_o)
        urine_tot.append(days_u)
        intake_ls.append([hr_name, days_i]); output_ls.append([hr_name, days_o])
        urine_ls.append([hr_name, days_u])
        days_i = 0; days_o = 0; days_u = 0; dayAdd += 24
    # Output if lists are all null
    print(urine_ls)
    temp = []
    if ((intake_ls == []) & (output_ls == [])):
        return(None, None, None)
    # Calculating 24hr 
    for i in range(len(intake_ls)):
        temp.append(abs((intake_ls[i][0] - datetime.datetime.now().hour)-24))
    index_min = np.argmin(temp)
    if (index_min == 0):
        index_min = 1
    int_24 = out_24 = urine_24 = 0
    for i in range(index_min-1, -1, -1):
        int_24 += intake_ls[i][1]
        out_24 += output_ls[i][1]
        urine_24 += urine_ls[i][1]
    
    return(int_24, out_24, urine_24)

# %%
def getIOStr(pat_io):
    if (getIO(pat_io)): 
        intake, output, urine = getIO(pat_io)
        if ((intake != None) & (output != None)):
            io_str = "Recorded intake and output for last 24 hrs is " + str(intake) + ' and ' + str(output) + ' respectively. '
            ur_str = "Recorded urine output for last 24 hrs is " + str(urine)
        else:
            io_str = 'No intake, output records available in the charts at present. '
            ur_str = 'Urine output not recorded in the chart'
    return (io_str, ur_str)

# %%
for i in range(len(all_pats)):
    print(i)
    print(getIOStr(all_pats[i]['io']))
# Out:
# 0
# ('Recorded intake and output for last 24 hrs is 570 and 400 respectively. ', 'Recorded urine output since midnight is 400')
# 1
# ('Recorded intake and output for last 24 hrs is 0 and 4250 respectively. ', 'Recorded urine output since midnight is 4250')
# 2
# ('Recorded intake and output for last 24 hrs is 0 and 700 respectively. ', 'Recorded urine output since midnight is 700 and output yesterday is 1200. ')
# 3
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 4
# ('Recorded intake and output for last 24 hrs is 0 and 600 respectively. ', 'Recorded urine output since midnight is 600')
# 5
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 6
# ('Recorded intake and output for last 24 hrs is 2845 and 0 respectively. ', 'Recorded urine output since midnight is 0')
# 7
# ('Recorded intake and output for last 24 hrs is 300 and 400 respectively. ', 'Recorded urine output since midnight is 400')
# 8
# ('Recorded intake and output for last 24 hrs is 2014 and 2080 respectively. ', 'Recorded urine output since midnight is 2080')
# 9
# ('Recorded intake and output for last 24 hrs is 1182 and 3810 respectively. ', 'Recorded urine output since midnight is 3810 and output yesterday is 4200. ')
# 10
# ('Recorded intake and output for last 24 hrs is 2175 and 1200 respectively. ', 'Recorded urine output since midnight is 1200')
# 11
# ('Recorded intake and output for last 24 hrs is 0 and 1135 respectively. ', 'Recorded urine output since midnight is 785 and output yesterday is 1690. ')
# 12
# ('Recorded intake and output for last 24 hrs is 1560 and 1735 respectively. ', 'Recorded urine output since midnight is 1685')
# 13
# ('Recorded intake and output for last 24 hrs is 1800 and 700 respectively. ', 'Recorded urine output since midnight is 300')
# 14
# ('Recorded intake and output for last 24 hrs is 1035 and 3460 respectively. ', 'Recorded urine output since midnight is 3460 and output yesterday is 3025. ')
# 15
# ('Recorded intake and output for last 24 hrs is 1070 and 900 respectively. ', 'Recorded urine output since midnight is 900')
# 16
# ('Recorded intake and output for last 24 hrs is 2250 and 1700 respectively. ', 'Recorded urine output since midnight is 1700 and output yesterday is 2600. ')
# 17
# ('Recorded intake and output for last 24 hrs is 2800 and 2015 respectively. ', 'Recorded urine output since midnight is 1815 and output yesterday is 1575. ')
# 18
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 19
# ('Recorded intake and output for last 24 hrs is 985 and 275 respectively. ', 'Recorded urine output since midnight is 275')
# 20
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 21
# ('Recorded intake and output for last 24 hrs is 1519 and 0 respectively. ', 'Recorded urine output since midnight is 0')
# 22
# ('Recorded intake and output for last 24 hrs is 72 and 2100 respectively. ', 'Recorded urine output since midnight is 2100')
# 23
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 24
# ('Recorded intake and output for last 24 hrs is 2900 and 1850 respectively. ', 'Recorded urine output since midnight is 850')
# 25
# ('Recorded intake and output for last 24 hrs is 1213 and 1210 respectively. ', 'Recorded urine output since midnight is 1210 and output yesterday is 1495. ')
# 26
# ('Recorded intake and output for last 24 hrs is 2100 and 1300 respectively. ', 'Recorded urine output since midnight is 1100')
# 27
# ('Recorded intake and output for last 24 hrs is 1321 and 1090 respectively. ', 'Recorded urine output since midnight is 1090')
# 28
# ('Recorded intake and output for last 24 hrs is 1500 and 1425 respectively. ', 'Recorded urine output since midnight is 1425')
# 29
# ('Recorded intake and output for last 24 hrs is 799 and 2900 respectively. ', 'Recorded urine output since midnight is 2900')
# 30
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 31
# ('Recorded intake and output for last 24 hrs is 0 and 790 respectively. ', 'Recorded urine output since midnight is 790 and output yesterday is 1375. ')
# 32
# ('Recorded intake and output for last 24 hrs is 0 and 1950 respectively. ', 'Recorded urine output since midnight is 1950')
# 33
# ('Recorded intake and output for last 24 hrs is 0 and 1330 respectively. ', 'Recorded urine output since midnight is 1330 and output yesterday is 2265. ')
# 34
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 35
# ('Recorded intake and output for last 24 hrs is 1000 and 900 respectively. ', 'Recorded urine output since midnight is 900 and output yesterday is 1300. ')
# 36
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 37
# ('Recorded intake and output for last 24 hrs is 1395 and 660 respectively. ', 'Recorded urine output since midnight is 660 and output yesterday is 1600. ')
# 38
# ('Recorded intake and output for last 24 hrs is 0 and 600 respectively. ', 'Recorded urine output since midnight is 0 and output yesterday is 450. ')
# 39
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 40
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 41
# ('Recorded intake and output for last 24 hrs is 0 and 1350 respectively. ', 'Recorded urine output since midnight is 1350')
# 42
# ('Recorded intake and output for last 24 hrs is 0 and 1035 respectively. ', 'Recorded urine output since midnight is 1035')
# 43
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 44
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 45
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 46
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 47
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 48
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 49
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')
# 50
# ('Recorded intake and output for last 24 hrs is 2684 and 510 respectively. ', 'Recorded urine output since midnight is 510 and output yesterday is 0. ')
# 51
# ('Recorded intake and output for last 24 hrs is 1563 and 1200 respectively. ', 'Recorded urine output since midnight is 1200')
# 52
# ('Recorded intake and output for last 24 hrs is 2600 and 600 respectively. ', 'Recorded urine output since midnight is 600')
# 53
# ('Recorded intake and output for last 24 hrs is 1775 and 1250 respectively. ', 'Recorded urine output since midnight is 1250 and output yesterday is 3075. ')
# 54
# ('No intake, output records available in the charts at present. ', 'Urine output not recorded in the chart')

# %% [markdown]
# ## Diet

# %%
def getDietString(pat_obj):
    '''
    Takes in mrn and outputs "diet_string"
    '''
    d_list = pat_obj[0]['orders']['active']['diets']
    
    if (d_list == []):
        diet_str = 'No active patiet diet orders in the chart. '
    else:
        temp = []; d_list_i = []
        for i in range(len(d_list)):
            name = d_list[i]['name']
            freq = d_list[i]['frequency']
            time = d_list[i]['startTime']
            instructions = d_list[i]['instructions']
            temp.append([name, freq, time, instructions])
            d_list_i.append(temp)
            temp = []

        j = len(d_list_i)

        instr = d_list_i[j-1][0][3]
        if (instr == None):
            instr_string = ''
        else:
            instr_string = instr

        if (name != 'NPO'):
            diet_str = 'Patient is on ' + d_list_i[(j-1)][0][0] + ' feeds. ' + instr_string + '. '
        elif (name == 'NPO'):
            diet_str = 'Patient is NPO since ' + (d_list_i[(j-1)][0][2]).strftime("%B %d %Y, %I:%M %p")
    
    return diet_str

# %% [markdown]
# ## ID

# %%
antibiotics = ['amikacin', 'amoxicillin', 'amoxicillin + clavunic potassium', 'amoxicillin/clavulanate', 'amoxicillin/potassium', 'amoxicillin + clavulanic acid', 'amoxicillin + clavulanic acid', 
               'amoxicillin + clavulanic acid-dry', 'amoxicillin + cloxacillin', 'amoxicillin + cloxacillin + lactic acid bacillus', 'amoxicillin + dicloxacillin + lactobacillus', 
               'amoxicillin + omeprazole + tinidazole', 'amoxycillin', 'amoxycillin + clavulanic acid', 'amphotericin', 'amphotericin b', 'amphotericin b(liposomal)', 'ampicillin', 
               'ampicillin/probenecid', 'ampicillin + cloxacillin', 'ampicillin + dicloxacillin', 'arterlonae maleate + piperaquine', 'arterolane maleate + piperaquine', 'artesunate', 
               'artesunate + sulfadoxine + pyrimethamine', 'atovaquone', 'atovaquone/proguanil', 'azithromycin', 'azithromycin + cefpodoxime', 'azithromycin + fluconazole + secnidazole', 
               'aztreonam', 'bacampicillin', 'bacitrac/tyroth/diph-pyra/benz', 'bacitrac/tyroth/poly/benzo/ctk', 'bacitracin', 'bacitracin/gramicid/poly/lido', 'bacitracin/gramicidin/polymyxn', 
               'bacitracin/lidocaine', 'bacitracin/polymyxin', 'bacitracin/polymyxinb/lidocain', 'bacitracin topical + neomycin + polymyxin b', 'bacitra/tyrothric/pmyx/b-caine', 'cefaclor', 
               'cefadroxil'	'cefalexin', 'cefamandole', 'cefazolin', 'cefdinir', 'cefepime', 'cefepime + tazobactam', 'cefixime', 'cefixime + azithromycin', 'cefixime + azithromycin', 
               'cefixime + clavulanic acid', 'cefixime + ofloxacin', 'cefonicid', 'cefoperazone', 'cefoperazone/sulbactam', 'cefoperazone + sulbactam', 'cefoperazone + sulbactam', 'cefotaxime', 
               'cefotetan', 'cefoxitin', 'cefpodoxime', 'cefpodoxime + azithromycin', 'cefpodoxime + azithromycin', 'cefpodoxime + clavulanic acid', 'cefpodoxmine proxetil', 'cefprozil', 
               'cefsulodin', 'ceftazidime', 'ceftazidime/arginine', 'ceftibuten', 'ceftizoxime', 'ceftobiprole', 'ceftolozane/tazobactam', 'ceftriaxone', 'ceftriaxone + sulbactam', 
               'ceftriaxone + sulbactam', 'ceftriaxone + tazobactam', 'ceftriaxonesulbactam', 'cefuroxim', 'cefuroxime', 'cefuroxime + clavulanic acid', 'cefuroxime + linezolid', 'cefuroxime + sulbactam', 
               'cephalexin', 'cephaloridine', 'cephalothin', 'cephapirin', 'cephradine', 'cepoperazone + sulbactam', 'cepoperazone + tazobactam', 
               'cipladine', 'ciprofloxacin', 'ciprofloxacin/ciprofloxa', 'ciprofloxacin/hydrocortisone', 'ciprofloxacin + tinidazole', 
               'ciprofloxacin + tinidazole', 'clindamycin', 'clindamycin/avobenzone/octinox', 'clindamycin/tretinoin', 'clindamycin + benzoyl peroxide', 
               'clindamycin + clotrimazole', 'clindamycin + clotrimazole + tinidazole', 'clindamycin + clotrimazole + tinidazole', 
               'clindamycin + nicotinamide', 'clindamycin + tretinoin', 'cloxacillin', 'colistimethate sodium', 'colistin', 'colistin (colistimethate na)', 
               'dapsone', 'daptomycin', 'dicloxacillin', 'emtricitabine', 'emtricitabine/tenofov', 'emtricitabine/tenofovir', 
               'emtricitabine + tenofovir + efavirenz', 'emtricita/rilpivirine/tenof', 'enfuvirtide', 'entecavir', 'ertapenem', 
               'erythromycin', 'erythromycin/benzoyl', 'ethambutol', 'faropenem', 'fluconazole', 'flucloxacillin sodium', 
               'fluconazole', 'fluconazole + azithromycin + secnidazole', 'ganciclovir', 'gancyclovir', 'gatifloxacin', 
               'gatifloxacin/d5w', 'gemifloxacin', 'gentamicin', 'gentamicin/betamethasone', 'gentamicin/sodium', 'gentamycin', 
               'grepafloxacin', 'griseofulvin', 'griseofulvin,', 'imipenem/cilastatin', 'imipenem + cilastatin', 'interferon alfa 2b', 
               'interferon beta 1a', 'isoniazid', 'isoniazide', 'isoniazid/pyridoxine', 'isoniazid + rifampicin + ethambutol + pyrazinamide', 
               'itraconazole', 'ketoconazole', 'ketoconazole topical', 'lamivudine', 'lamivudine/zidovudine', 'lamivudine + nevirapine + zidovudine', 
               'lamivudine + zidovudine', 'levofloxacin', 'linezolid', 'meropenem', 'meropenem + sulbactam', 'metronidazole', 
               'metronidazole/octinox/avobenz', 'metronidazole/sodium', 'metronidazole + norfloxacin', 'micafungin', 'miconazole', 
               'miconazole + fluocinolone', 'miconazole + ornidazole', 'miconazole topical + ornidazole topical', 'moxicillin + clavunic potassium', 
               'moxifloxacin', 'moxifloxacin/sod.ace,sul/water', 'nafcillin', 'neomycin', 'neomycin/bacit/p-myx/hydrocort', 'neomycin/bacitracin/amino', 
               'neomycin/bacitracin/polymyxinb', 'neomycin/betamethasone', 'neomycin/dexamethasone', 'neomycin/gramc', 'neomycin/gramicidin/nyst/triam', 
               'neomycin/m-prednisol/alum/sulf', 'neomycin/methylprednisolone', 'neomycin/polymyxin', 'neomycin/polymyxn', 'neomycin/tyroth/poly/dexa/hal', 
               'neomycin + fluocinolone', 'neomycin + hydrocortisone', 'neomycin + polymixin b sulphate', 'neomycin + polymyxin b sulphate + zinc bacitracin', 
               'neomycin sulfate + polymyxin b sulfate + bacitracin zinc', 'nevirapine'	'nitrofurantoin', 'norfloxacin'	'norfloxacin + tinidazole', 
               'ofloxacin', 'ofloxacin + ornidazole', 'ofloxacin + ornidazole', 'ofloxacin + tinidazole', 'ofloxocin + ornidazole', 'ornidazole', 
               'oseltamivir', 'penicillin', 'penicillin g potassium', 'piperacillin', 'piperacillin + tazobactam', 'quinine', 'quinupristin/dalfopristin', 
               'rifamp/isoniazid/pyrazinamide', 'rifampicin', 'rifampicin + isoniazid', 'rifampicin + isoniazide + pyrazinamide + ethambutol', 'rifampicin + isoniazid + ethambutol', 
               'rifampin', 'rifaximin', 'ritonavir', 'ritonavir + lopinavir', 'sofosbuvir', 'sofosbuvir/velpatas/voxilaprev', 'sofosbuvir/velpatasvir', 
               'streptomycin', 'sulbactam', 'sulfamethoxazole', 'sulfamethoxazole-trimethoprim', 'sulfamethoxazole/trimethoprim', 'sulfamethoxazole + trimethoprim', 
               'sulphamethoxazole + trimethoprim', 'sulphamethoxazole + trimethoprim', 'tenofovir', 'tenofovir + emtricitabine', 'tizanidine', 
               'tobramycin', 'tobramycin/dexamethasone', 'tobramycin + dexamethasone', 'tobramycin + fluorometholone', 'trimethoprim', 
               'trimethoprim + sulfamethoxazole', 'trimethoprim + sulphamethoxazole', 'voriconazole', 'zanamivir']

# %%
def getFebrileStatus(pat_obj):
    
    vit_list = getVitalList(pat_obj)
    
    temp_string = ''
    
    if (len(vit_list)>24):
        parse = 24
    else: 
        parse = len(vit_list)
    
    for i in range(parse):
        if ((vit_list[i][0][1]) == None):
            continue
        else:
            if (pd.to_numeric(vit_list[i][0][1]) <99):
                temp_string = 'Afebrile for the last 24 hours. '
            if (pd.to_numeric(vit_list[i][0][1] >= 99)):
                h = vit_list[i][0][0]
                if (h<12):
                    hours = h
                    ampm = 'AM'
                elif (h>12):
                    hours = h-12
                    ampm = 'PM'
                elif (h == 12):
                    hours = 12
                    ampm = 'PM'
                elif (h == 0):
                    hours = 12
                    ampm = 'AM'
                temp_string = 'Last 24 hour Tmax of ' + str(vit_list[i][0][1]) + ' recorded at ' + str(hours) + ampm + '. '

    return temp_string

# %%
def getMedList(pat_obj):
    med_list = pat_obj[0]['orders']['active']['medications']

    temp = []; med_list_i = []

    for i in range(len(med_list)):
        name = med_list[i]['name']
        freq = med_list[i]['frequency']
        qty = med_list[i]['quantity']
        unit = med_list[i]['unit']
        time = med_list[i]['startTime']
        days = (datetime.datetime.now() - time).days
        instructions = med_list[i]['instructions']
        temp.append([name, freq, qty, unit, days, instructions])
        med_list_i.append(temp)
        temp = []
        
    return med_list_i

# %%
def getAntibiotics(pat_obj):
    '''
    Takes in mrn, gets names of all meds patient is on, compares it with antibiotics list above
    and outputs the antibiotic med patient is on. 
    '''
    med_list_i = getMedList(pat_obj)
    
    abs_str = ''
    for i in range(len(med_list_i)):
        for name, freq, qty, unit, days, instr in med_list_i[i]:
            if (str(name.lower()) in antibiotics):
                abs_str += (name + ' ' + str(round(qty)) + ' ' + unit + ' q' + str(freq['hours']) + ' hrs ' + 
                      'D' + str(days) + '. ')
            if (abs_str == ''):
                abs_str = ''
    if (abs_str == ''):
        abs_str = 'Currently not on any antibiotics. '
    else:
        abs_str = 'Patient currently on ' + abs_str
    return abs_str

# %%
def highlowStrings(pairs):
    '''
    Takes in a processed system interpreted list, from the same, outputs a string with the
    format "Lab is high/low"
    '''
    string = ''
    for i in range(len(pairs)):
        if ((pairs[i][2] != 'normal') | (pairs[i][2] == 'no value')):
            string += str(pairs[i][0]) + ' is ' + str(pairs[i][2]) + ' (' + str(pairs[i][1]) + ')' +'. '
    return string

# %%
def getSysStrings(pat_obj):
    
    '''
    Function takes in mrn, 
    extracts attributes from the patient object, 
    processes attributes, breaks it to system wise lists and interprets them
    Creates high low strings out of the processed lists
    Assembles all into one list and outputs
    '''
    
    t = []
    tab = getAttributes(pat_obj)
    prs = getPairs(tab)
    prs_sorted = Sort(prs, 2)
    cvs, cns, ren, abg, Id, gi, endo, heme, lipids = systemWiseSplit(prs_sorted)
    
    cvs_i = interpret(cvs)
    cvs_l = getLatest(cvs_i)
    t.append(highlowStrings(cvs_l))
    
    abg_i = interpret(abg)
    abg_l = getLatest(abg_i)
    t.append(getABGstring(abg_l))
    
    ren_i = interpret(ren)
    ren_l = getLatest(ren_i)
    t.append(highlowStrings(ren_l))
    
    gi_i = interpret(gi)
    gi_l = getLatest(gi_i)
    t.append(highlowStrings(gi_l))
    heme_i = interpret(heme)
    heme_l = getLatest(heme_i)
    t.append(highlowStrings(heme_l))
    
    endo_i = interpret(endo)
    if (endo_i != []):
        endo_str = 'Last GRBS measured at ' + (endo_i[0][1]).strftime("%B %d %Y, %I:%M %p") + ' and is ' + endo_i[0][0][2] + '(' + endo_i[0][0][1] + ')'
    elif (endo_i == []):
        endo_str = 'No GRBS available in the chart'    
    t.append(endo_str)
    
    Id_i = interpret(Id)
    Id_l = getLatest(Id_i)
    t.append(highlowStrings(Id_l))
    
    t.append(lipidAnalysis(lipids))
    
    return t

# %%
dict = {
        "Na is low" : ["Hyponatremia", "Sodium is low", "Low sodium"],
        "Na is high": ["Hypernatremia", "High sodium"],
        "K is low" : "Hypokalemia",
        "K is high": "Hyperkalemia", 
        "Chloride is low" : "Low Chloride",
        "Chloride is high": "Hyperchloremia", 
        "Platelet is low" : "Low platelet counts", 
        "Platelet is high": "High platelet counts", 
        "Neutrophils is high" : "Neutrophilia", 
        "Total count is high" : "Leukocytosis", 
        "Troponin I is high" : "High troponins", 
        "Urea is high" : "High Blood urea", 
        "Creatinine is high" : "High creatinine", 
        "Albumin is low" : "Hypoalbuminemia", 
        "Hb is low": "Patient anemic", 
        "Lymphocytes is high": "Lymphocytosis", 
        "MCV is low": "Microcytosis", 
        "MCV is high": "Macrocytosis"
      }

# %%
text = 'Na is low'

# %%
multiple_replace(dict, text)
# Out:
# 'Sodium is low'

# %%
import re
import random

def multiple_replace(dict, text):
    # Create a regular expression  from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: random.choice(dict[mo.string[mo.start():mo.end()]]), text)

# %%
def getDVTstring(pat_obj):
    
    dvt = {'heparin', 'enoxeparin', 'fondaparinux'}
    
    med_list_i = getMedList(pat_obj)

    dvt_str = ''
    for i in range(len(med_list_i)):
        for name, freq, qty, unit, days, instr in med_list_i[i]:
            if (str(name.lower()) in dvt):
                dvt_str += 'DVT prophylaxis with ' + name + ' ' + str(round(qty)) + ' ' + unit + ' q' + str(freq['hours']) + ' hrs '
            if (dvt_str == ''):
                dvt_str = ''
    if (dvt_str == ''):
        dvt_str = 'Not on pharmacological DVT Prophylaxis. '

    return dvt_str

# %% [markdown]
# ## Final

# %%
def getReports(pat_obj):
    '''
    Final script that wraps all the above scripts and outputs the final report
    '''
    import json
    
    strings = getSysStrings(pat_obj)
    for i in range(len(strings)):
        strings[i] = multiple_replace(dict, strings[i])
    
    cvs1 = getCvsString(pat_obj)
    cvs2 = strings[0]
    cvs3 = strings[7]
    print('CVS: ' + cvs1 + cvs2 + cvs3)

    print('CNS: ' + getCNSstring(pat_obj))

    resp1 = strings[1]
    print('Resp: ' + getOxString(pat_obj) + resp1)

    ren1 = strings[2]
    print('Renal: ' + ren1 + getFoleyString(pat_obj))

    gi1 = strings[3]
    print('GI: ' + gi1 + getDietString(pat_obj))
    
    heme1 = strings[4]
    print('Heme: ' + heme1)
    
    Id1 = getFebrileStatus(pat_obj)
    Id2 = strings[6]
    print('ID: ' + Id1 + getAntibiotics(pat_obj) + Id2)

    endo1 = strings[5]
    print('Endo: ' + endo1)
    
    print('Prophylaxis: ' + getDVTstring(pat_obj))
    
    print("-------------------------------------------------------")

# %%
getReports(pat_obj)
# Out:
# CVS: Hemodynamically stable. Last measured BP is 99/55. Tachycardic with HR of 110. Troponin T is high (19.85).
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2. ABG suggestive of respiratory alkalosis. Lactic acidosis with lactate of 2.1.
# Renal: High Blood urea (59). High creatinine (1.67). Foley in situ, inserted on July 09 2019, 02:57 AM
# GI: ALK phos is low (26). Patient is on Oral-semi solid feeds. oral semisolid-soft diet as tolerated.
# Heme: Patient anemic (11.8). Low platelet counts (33000).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.

# %%
trial = (list(db2.patients.find({'name':'Mallegowda'}, {'CPMRN':1, '_id':0}))[0]['CPMRN'])
pat_obj = list(db2.patients.find({'CPMRN':trial}))

# %%
for i in range(len(list(db2.patients.find({}, {'CPMRN':1, '_id':0})))):
    name = list(db2.patients.find({}, {'name':1, '_id':0}))[i]['name']
    trial = list(db2.patients.find({}, {'CPMRN':1, '_id':0}))[i]['CPMRN']
    pat_obj = list(db2.patients.find({'CPMRN':trial}))
    print(name)
    print(trial)
    getReports(pat_obj)
# Out:
# Vijaya
# INKABLRMAL1
# CVS: Hemodynamically unstable. Patient is on IV vasopressors. Last measured BP is 153/81.
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2. ABG: pH 7.38 PaCO2 34.9 PaO2 63 Bicarb 15.5. Lactic acidosis with lactate of 3.2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme: Lymphocytosis (45.6).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sathi skandan
# INKABLRMAL2
# CVS: Hemodynamically stable. Last measured BP is 106/84. Tachycardic with HR of 110.
# CNS: E4V5M6.
# Resp: Saturating 98% on 21% FiO2. ABG suggestive of respiratory alkalosis. Lactate not available.
# Renal: No Foley in situ
# GI: Patient is on Oral-semi solid feeds. oral semisolid diet .
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams q8 hrs D21.
# Endo: Last GRBS measured at June 10 2019, 01:27 AM and is high(321)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Vijaya ravi
# INKABLRMAL3
# CVS: Hemodynamically stable. Last measured BP is 130/70.
# CNS: E4V5M6.
# Resp: Patient is in NIV saturating 87% on 21% FiO2.
# Renal: No Foley in situ
# GI: Patient is on Oral-semi solid feeds. Oral semisolids diet.
# Heme:
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: Last GRBS measured at June 10 2019, 01:28 AM and is high(283)
# Prophylaxis: DVT prophylaxis with Heparin 5000 IU qNone hrs
# -------------------------------------------------------
# Kavitha
# INKABLRMAL5
# CVS: Hemodynamically stable. Last measured BP is 128/73. Tachycardic with HR of 105.
# CNS: E4V5M6.
# Resp: Saturating 97% on 28% FiO2.
# Renal: Hyperkalemia (5.2). No Foley in situ
# GI: SGOT(AST) is high (78). Patient is on Oral-soft feeds. oral soft diet in small quantities..
# Heme: Patient anemic (11.6).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 1 grams q8 hrs D21. Oseltamivir 75 mg q12 hrs D21. Leukocytosis (12800).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Selvaraj
# INKABLRMAL8
# CVS: No MAP recorded. BP not available in records
# CNS: E4V5M6.
# Resp: Saturating 98% on 21% FiO2.
# Renal: High Blood urea (32). No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 1 grams q8 hrs D21. Metronidazole 500 mg q8 hrs D21. Neutrophilia (72.5).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sarojamma V
# INKABLRMAL6
# CVS: Hemodynamically stable. Last measured BP is 155/83.
# CNS: E4V5M6.
# Resp: Saturating 94% on 32% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme: Patient anemic (12.1).
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone + Sulbactam 2 grams q12 hrs D21. Neutrophilia (83.6).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sai Nath
# INKABLRMAL9
# CVS: Hemodynamically stable. Last measured BP is 190/105. Tachycardic with HR of 138.
# CNS: E4V5M6.
# Resp: Saturating 95% on 28% FiO2.
# Renal: No Foley in situ
# GI: Patient is NPO since June 15 2019, 07:18 AM
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Keshava Narayana Raju
# INKABLRMAL7
# CVS: Hemodynamically stable. Last measured BP is 130/81.
# CNS: E4V5M6.
# Resp: Saturating 98% on 34% FiO2.
# Renal: Hyponatremia (127). High Blood urea (21). No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme: Patient anemic (11.5).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Neutrophilia (94.5). Leukocytosis (14930).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sudhakar Reddy
# INKABLRMAL12
# CVS: Hemodynamically stable. Last measured BP is 135/78.
# CNS: GCS not available in chart
# Resp: Saturating 96% on 32% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Cefixime 1 grams q8 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Hamsa
# INKABLRMAL11
# CVS: Hemodynamically stable. Last measured BP is 140/670.
# CNS: E4V5M6.
# Resp: Saturating 97% on 21% FiO2. ABG suggestive of metabolic acidosis. Lactate not available.
# Renal: Foley in situ, inserted on June 16 2019, 11:28 AM
# GI: Patient is on Oral-soft feeds. oral semisolid-soft diet. 4-5 small feeds..
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21.
# Endo: Last GRBS measured at June 16 2019, 11:00 AM and is high(272)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Ugam Devi Purohit
# INKABLRMAL13
# CVS: Hemodynamically stable. Last measured BP is 112/74.
# CNS: E3V5M6.
# Resp: Saturating 98% on 21% FiO2.
# Renal: Foley in situ, inserted on June 18 2019, 01:43 PM
# GI: Patient is NPO since June 19 2019, 07:33 AM
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Amikacin 500 mg q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Shobha
# INKABLRMAL10
# CVS: Hemodynamically stable. Last measured BP is 110/70. Tachycardic with HR of 105.
# CNS: E4V5M6.
# Resp: Saturating 99% on 28% FiO2.
# Renal: Hyperkalemia (5.2). Foley in situ, inserted on June 15 2019, 01:20 AM
# GI: Patient is NPO since June 15 2019, 07:06 AM
# Heme: Patient anemic (9.7).
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams q8 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: DVT prophylaxis with Heparin 5000 IU q8 hrs
# -------------------------------------------------------
# Banu Kumari
# INKABLRMAL15
# CVS: Hemodynamically stable. Last measured BP is 124/73.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2.
# Renal: Foley in situ, inserted on June 19 2019, 11:45 AM
# GI: Patient is NPO since June 19 2019, 11:44 AM
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 1 grams q12 hrs D21. Clindamycin 600 mg q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Rajaleela
# INKABLRMAL17
# CVS: Hemodynamically stable. Last measured BP is 127/63.
# CNS: E4V5M6.
# Resp: Saturating 100% on 21% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Cefixime 1 grams q12 hrs D21.
# Endo: Last GRBS measured at June 21 2019, 06:44 PM and is normal(162)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Marappa
# INKABLRMAL14
# CVS: Hemodynamically stable. Last measured BP is 131/88.
# CNS: E4V5M6.
# Resp: Saturating 98% on 32% FiO2.
# Renal: Hyponatremia (126). Low Chloride (92). No Foley in situ
# GI: Patient is on Tube-NG feeds. NG feeds @ 200ml/ Q2H, 8-9 feeds / day..
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 2 grams q12 hrs D21.
# Endo: Last GRBS measured at June 19 2019, 02:07 AM and is normal(131)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# G D SHINDE
# INKABLRMAL18
# CVS: Hemodynamically unstable. Last measured BP is 88/36.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: Last GRBS measured at June 21 2019, 06:44 PM and is normal(97)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Channappa Sajjan
# INKABLRMAL16
# CVS: Hemodynamically stable. Last measured BP is 125/63. Tachycardic with HR of 114.
# CNS: E3V2M4.
# Resp: Saturating 98% on 21% FiO2.
# Renal: High creatinine (6.02). High Blood urea (116). Foley in situ, inserted on June 21 2019, 10:58 AM
# GI: Patient is on Tube-NG feeds. Started on NG feeds clear liquids .
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone + Sulbactam 2 grams q8 hrs D21.
# Endo: Last GRBS measured at June 22 2019, 02:09 AM and is high(208)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Annapurna
# INKABLRMAL4
# CVS: Hemodynamically stable. Last measured BP is 122/78.
# CNS: E1V0M1.
# Resp: Saturating 100% on 40% FiO2. ABG suggestive of respiratory alkalosis. Lactate not available.
# Renal: Hypokalemia (3.3). High Blood urea (24). Foley in situ, inserted on June 11 2019, 09:05 AM
# GI: Patient is on Tube-NG feeds. NG feeds @ 150 ml /Q2H, 7-8 feeds,.
# Heme: Patient anemic (12). Microcytosis (79).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 1 grams q8 hrs D21. Clindamycin 600 mg q8 hrs D21. Neutrophilia (87). Leukocytosis (24500).
# Endo: Last GRBS measured at June 18 2019, 02:06 AM and is high(186)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# N. Sainath
# INKABLRMAL21
# CVS: Hemodynamically stable. Last measured BP is 176/105. Tachycardic with HR of 102.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2.
# Renal: High Blood urea (32). High creatinine (1.28). No Foley in situ
# GI: Patient is NPO since June 22 2019, 06:45 AM
# Heme: Hb is high (17.4). Low platelet counts (213000).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics. Neutrophilia (81.4). Leukocytosis (10040).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Ramamani K
# INKABLRMAL20
# CVS: Hemodynamically stable. Last measured BP is 121/53.
# CNS: E4V5M6.
# Resp: Saturating 93% on 36% FiO2. ABG suggestive of metabolic acidosis. Lactate not available.
# Renal: Hyponatremia (126). High Blood urea (103). High creatinine (5.65). Foley in situ, inserted on June 22 2019, 07:03 AM
# GI: Patient is on Tube-NG feeds. NG feeds @ 100 ml / Q2H.
# Heme: Patient anemic (8.5). Low platelet counts (150000). Basophils is high (02).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 500 mg q8 hrs D21. Neutrophilia (75). Leukocytosis (10320).
# Endo: Last GRBS measured at June 24 2019, 02:12 AM and is normal(102)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Ramamani K
# INKABLRMAL20
# CVS: Hemodynamically stable. Last measured BP is 121/53.
# CNS: E4V5M6.
# Resp: Saturating 93% on 36% FiO2. ABG suggestive of metabolic acidosis. Lactate not available.
# Renal: Hyponatremia (126). High Blood urea (103). High creatinine (5.65). Foley in situ, inserted on June 22 2019, 07:03 AM
# GI: Patient is on Tube-NG feeds. NG feeds @ 100 ml / Q2H.
# Heme: Patient anemic (8.5). Low platelet counts (150000). Basophils is high (02).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 500 mg q8 hrs D21. Neutrophilia (75). Leukocytosis (10320).
# Endo: Last GRBS measured at June 24 2019, 02:12 AM and is normal(102)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Narayanappa V
# INKABLRMAL19
# CVS: Hemodynamically stable. Last measured BP is 99/52. Tachycardic with HR of 104.
# CNS: E1V0M1.
# Resp: Patient is intubated saturating 95% on 100% FiO2. Intubated on 06/22/2019, 03:16 AM. ABG: pH 7.22 PaCO2 37.2 PaO2 284 Bicarb 33. Lactate normal.
# Renal: High Blood urea (70). High creatinine (4.77). Foley in situ, inserted on June 21 2019, 10:27 PM
# GI: No active patiet diet orders in the chart.
# Heme: Patient anemic (9.2).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 500 mg q8 hrs D21.
# Endo: Last GRBS measured at June 21 2019, 10:40 PM and is normal(120)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sheela
# INKABLRMAL23
# CVS: Hemodynamically stable. Last measured BP is 126/66. Tachycardic with HR of 102. Troponin T is high (15.94).
# CNS: E4V5M6.
# Resp: Saturating 81% on 32% FiO2. ABG suggestive of respiratory alkalosis. Lactate not available.
# Renal: High Blood urea (40). No Foley in situ
# GI: Patient is on Oral-soft feeds. oral semisolid -soft diet.
# Heme: Patient anemic (12).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics. Leukocytosis (10740).
# Endo: Last GRBS measured at June 23 2019, 06:05 AM and is normal(91)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# vbvb
# INKABLRMAL26
# CVS: No MAP recorded. BP not available in records
# CNS: GCS not available in chart
# Resp: Saturating nan% on nan% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Brunda G S
# INKABLRMAL25
# CVS: Hemodynamically stable. Last measured BP is 110/77.
# CNS: GCS not available in chart
# Resp: Saturating 98% on 21% FiO2.
# Renal: High Blood urea (33). Foley in situ, inserted on June 23 2019, 12:51 PM
# GI: Hypoalbuminemia (3). No active patiet diet orders in the chart.
# Heme: Patient anemic (12.4). Low platelet counts (198000).
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams q8 hrs D21. Metronidazole 500 mg q8 hrs D21. Leukocytosis (16060).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Uma Devamma
# INKABLRMAL24
# CVS: Hemodynamically stable. Last measured BP is 103/53.
# CNS: E2V2M4.
# Resp: Saturating 95% on 32% FiO2.
# Renal: Hypokalemia (3.4). High Blood urea (26). No Foley in situ
# GI: Hypoalbuminemia (2.3). Patient is on Tube-NG feeds. NG feeds - 50 ml / Q2H .
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 1 grams q8 hrs D21. Leukocytosis (12540).
# Endo: Last GRBS measured at June 24 2019, 02:14 AM and is normal(82)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Akash
# INKABLRMAL22
# CVS: Hemodynamically stable. Last measured BP is 157/98. Tachycardic with HR of 108.
# CNS: E4V5M6.
# Resp: Saturating 92% on 21% FiO2.
# Renal: Hyperkalemia (5.3). High Blood urea (23). High creatinine (1.25). Hyperchloremia (107). No Foley in situ
# GI: SGOT(AST) is high (137). SGPT(ALT) is high (105). Hypoalbuminemia (3.2). GGT is high (154). Patient is on Oral-liquid feeds. oral liquids -semisolids as tolerated.
# Heme: Hb is high (21.8). Low platelet counts (10000).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics. Neutrophilia (77.1).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Lakshmamma
# INKABLRMAL27
# CVS: No MAP recorded. BP not available in recordsTachycardic with HR of 115.
# CNS: E4V5M6.
# Resp: Saturating 100% on 32% FiO2.
# Renal: Hyponatremia (129). High Blood urea (131). High creatinine (2.37). Foley in situ, inserted on June 24 2019, 12:08 PM
# GI: Hypoalbuminemia (3.3). Patient is on Oral-liquid feeds. Started on oral liquids.
# Heme: Patient anemic (9). Low platelet counts (198000).
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone/sulbactam 2 g q12 hrs D21. Leukocytosis (18000).
# Endo: Last GRBS measured at June 25 2019, 01:47 AM and is high(228)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Kusalavan V
# INKABLRMAL28
# CVS: Hemodynamically stable. Last measured BP is 150/83.
# CNS: E4V5M6.
# Resp: Saturating 93% on 32% FiO2.
# Renal: High Blood urea (27). Foley in situ, inserted on June 24 2019, 07:04 PM
# GI: Patient is on Tube-NG feeds. 50ml/hr.
# Heme: Low platelet counts (199000).
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams q8 hrs D21. Metronidazole 500 mg q8 hrs D21. Neutrophilia (89.1). Leukocytosis (10830).
# Endo: Last GRBS measured at June 25 2019, 01:46 AM and is normal(103)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Dr Nagaraj
# INKABLRMAL30
# CVS: Hemodynamically stable. Last measured BP is 154/69. Troponin T is high (20.88).
# CNS: E4V5M6.
# Resp: Saturating 93% on 32% FiO2.
# Renal: Hyponatremia (126). Low Chloride (87). No Foley in situ
# GI: Patient is on Oral-semi solid feeds. oral semisolid-soft diet as tolerance.
# Heme: Low platelet counts (180000).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Azithromycin 500 mg q12 hrs D21. Oseltamivir 75 mg q12 hrs D21.
# Endo: Last GRBS measured at June 28 2019, 02:35 AM and is high(229)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Mallegowda
# INKABLRMAL32
# CVS: No MAP recorded. BP not available in records
# CNS: GCS not available in chart
# Resp: Saturating nan% on nan% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Sumangala V Pattanashetti
# INKABLRMAL29
# CVS: Hemodynamically stable. Last measured BP is 116/81.
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2.
# Renal: Foley in situ, inserted on June 26 2019, 04:40 PM
# GI: Patient is on Oral-semi solid feeds.   orally semisolids with liquids..
# Heme: Patient anemic (11.1). Low platelet counts (219000).
# ID: Afebrile for the last 24 hours. Patient currently on Cefotaxime 1 grams q8 hrs D21. Amikacin 500 mg q24 hrs D21.
# Endo: Last GRBS measured at June 29 2019, 02:16 AM and is high(195)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Naveen S G
# INKABLRMAL34
# CVS: Hemodynamically stable. Last measured BP is 130/82.
# CNS: E4V4M5.
# Resp: Saturating 97% on 21% FiO2. ABG reviewed, normalLactate normal.
# Renal: No Foley in situ
# GI: Patient is on Oral-semi solid feeds. oral semisolids-soft diet.
# Heme: Low platelet counts (194000).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# K Selvam
# INKABLRMAL35
# CVS: Hemodynamically stable. Last measured BP is 122/86.
# CNS: E4V5M6.
# Resp: Saturating 96% on 28% FiO2.
# Renal: Hyponatremia (123). High Blood urea (52). High creatinine (1.51). Foley in situ, inserted on June 29 2019, 09:10 AM
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone/sulbactam 2 grams q12 hrs D21.
# Endo: Last GRBS measured at June 29 2019, 09:54 AM and is high(320)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Srinivas reddy
# INKABLRMAL37
# CVS: Hemodynamically stable. Last measured BP is 147/67.
# CNS: E4V5M6.
# Resp: Saturating 83% on 21% FiO2.
# Renal: High Blood urea (57). High creatinine (3.75). No Foley in situ
# GI: Patient is on Oral-soft feeds. oral diabetic- renal soft diet.
# Heme: Patient anemic (9.2).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone + sulbactam 2 grams q12 hrs D21. Oseltamivir 75 mg q12 hrs D21. Leukocytosis (14470). ESR is high (71).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Shanthamma
# INKABLRMAL36
# CVS: Hemodynamically stable. Last measured BP is 165/96.
# CNS: E4V5M6.
# Resp: Saturating 93% on 21% FiO2.
# Renal: No Foley in situ
# GI: Patient is NPO since June 29 2019, 01:06 PM
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone + Sulbactam 2 grams q12 hrs D21. Metronidazole 500 mg q8 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Lakshmamma
# INKABLRMAL38
# CVS: Hemodynamically stable. Last measured BP is 164/82. Tachycardic with HR of 105.
# CNS: E4V5M6.
# Resp: Saturating 98% on 21% FiO2.
# Renal: High Blood urea (70). High creatinine (1.51). Foley in situ, inserted on July 01 2019, 10:35 AM
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone + sulbactam 2 grams q12 hrs D21. Metronidazole 100 ml q8 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Vimalamma
# INKABLRMAL39
# CVS: Hemodynamically stable. Last measured BP is 125/77.
# CNS: E2V2M3.
# Resp: Saturating 98% on 36% FiO2.
# Renal: Hyponatremia (106). Low Chloride (76). High Blood urea (46). High creatinine (1.76). Foley in situ, inserted on July 01 2019, 02:00 PM
# GI: Hypoalbuminemia (3.3). Patient is on Tube-NG feeds. NG feeds @ 200 ml/Q2H.
# Heme: Patient anemic (10.3).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics. Leukocytosis (11960).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Ramamani K
# INKABLRMAL31
# CVS: Hemodynamically stable. Last measured BP is 112/77. Tachycardic with HR of 113.
# CNS: E3V0M5.
# Resp: Patient is intubated saturating 99% on 32% FiO2. Intubated on 07/09/2019, 03:24 AM.
# Renal: High Blood urea (85). High creatinine (6.12). Hyperchloremia (106). No Foley in situ
# GI: ALK phos is high (312). Hypoalbuminemia (2.5). GGT is high (70). Patient is on Tube-NG feeds. NG feeds @ 200ml/Q2H.
# Heme: Patient anemic (8.8).
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone + Sulbactam 2 grams q12 hrs D21. Fluconazole 100 mg q24 hrs D21. ESR is high (68). Neutrophilia (80.3).
# Endo: Last GRBS measured at June 28 2019, 02:33 AM and is normal(130)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Siddaiha
# INKABLRMAL40
# CVS: Hemodynamically stable. Last measured BP is 120/65. Tachycardic with HR of 121.
# CNS: E4V5M6.
# Resp: Saturating 93% on 32% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Oseltamivir 75 mg q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Aaisha begum
# INKABLRMAL42
# CVS: Hemodynamically stable. Last measured BP is 125/78.
# CNS: E4V5M6.
# Resp: Saturating 98% on 21% FiO2.
# Renal: High Blood urea (29). No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme: Patient anemic (11.7).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Neutrophilia (74.9).
# Endo: Last GRBS measured at July 03 2019, 06:42 PM and is normal(150)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Siddaiha
# INKABLRMAL40
# CVS: Hemodynamically stable. Last measured BP is 120/65. Tachycardic with HR of 121.
# CNS: E4V5M6.
# Resp: Saturating 93% on 32% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21. Oseltamivir 75 mg q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Eramma
# INKABLRMAL41
# CVS: Hemodynamically stable. Last measured BP is 161/81.
# CNS: E4V5M6.
# Resp: Saturating 94% on 24% FiO2.
# Renal: High Blood urea (46). High creatinine (1.76). Hyponatremia (106). No Foley in situ
# GI: Hypoalbuminemia (3.3). Patient is on Oral-soft feeds. provide semisolids with adequate liquids.
# Heme: Patient anemic (10.3).
# ID: Afebrile for the last 24 hours. Patient currently on Oseltamivir 75 mg q12 hrs D21. Ceftriaxone 1 grams q12 hrs D21. Leukocytosis (11960).
# Endo: Last GRBS measured at July 03 2019, 02:24 AM and is high(263)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Umadevamma
# INKABLRMAL44
# CVS: Hemodynamically unstable. Last measured BP is 91/51. Troponin T is high (185.30).
# CNS: E4V5M6.
# Resp: Saturating 89% on 36% FiO2.
# Renal: No Foley in situ
# GI: SGPT(ALT) is low (3). Patient is on Oral-semi solid feeds. oral semisolids with liquids.
# Heme: High platelet counts (611000).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21.
# Endo: Last GRBS measured at July 05 2019, 01:46 AM and is normal(128)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Mohammed Asifulla
# INKABLRMAL43
# CVS: Hemodynamically stable. Last measured BP is 156/92. Tachycardic with HR of 106. Troponin T is high (20.85).
# CNS: E4V5M6.
# Resp: Saturating 99% on 32% FiO2. ABG suggestive of respiratory alkalosis. Lactate normal.
# Renal: High Blood urea (25). No Foley in situ
# GI: Hypoalbuminemia (3.1). Patient is on Oral-semi solid feeds. oral semisolid diet with adequate fluids.
# Heme: Microcytosis (41.8).
# ID: Last 24 hour Tmax of 99.4 recorded at 11PM. Patient currently on Cefoperazone + Sulbactam 1 g q12 hrs D21. Oseltamivir 75 mg q12 hrs D21. Leukocytosis (10300). ESR is high (54).
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Boramma
# INKABLRMAL45
# CVS: Hemodynamically stable. Last measured BP is 130/73.
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2.
# Renal: Hyperkalemia (5.6). High Blood urea (245). High creatinine (8.89). No Foley in situ
# GI: Patient is on Oral-semi solid feeds. oral semisolid-soft diet as tolerated.
# Heme: Patient anemic (6.9). Low platelet counts (1.97).
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams qNone hrs D21. Piperacillin + tazobactam 2 grams q8 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Padma
# INKABLRMAL46
# CVS: Hemodynamically stable. Last measured BP is 144/78.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2. ABG: pH 7.37 PaCO2 26 PaO2 37 Bicarb 14.8. Lactic acidosis with lactate of 5.3.
# Renal: No Foley in situ
# GI: Patient is on Oral-semi solid feeds. oral semisolids and liquids as tolerated.
# Heme:
# ID: Last 24 hour Tmax of 99 recorded at 4PM. Patient currently on Meropenem 1 grams q12 hrs D21.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Gowtham S
# INKABLRMAL49
# CVS: No MAP recorded. BP not available in records
# CNS: GCS not available in chart
# Resp: Saturating nan% on nan% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Gowtham S
# INKABLRMAL50
# CVS: Hemodynamically stable. Last measured BP is 113/69.
# CNS: E4V5M6.
# Resp: Saturating 98% on 21% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Chandrasekhar
# INKABLRMAL47
# CVS: Hemodynamically stable. Last measured BP is 110/62.
# CNS: E4V5M6.
# Resp: Saturating 93% on 21% FiO2.
# Renal: No Foley in situ
# GI: No active patiet diet orders in the chart.
# Heme:
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Malle Gowda
# INKABLRMAL33
# CVS: Hemodynamically stable. Last measured BP is 166/77. Troponin T is high (472.90).
# CNS: E4V0M6.
# Resp: Patient is intubated saturating 99% on 40% FiO2. Intubated on 07/09/2019, 03:22 AM. ABG suggestive of metabolic acidosis. Lactate not available.
# Renal: High Blood urea (60). High creatinine (2.55). Foley in situ, inserted on June 29 2019, 05:56 AM
# GI: Patient is on Tube-NG feeds. NG feeds @ 100 ml/Q2H..
# Heme: Patient anemic (9).
# ID: Afebrile for the last 24 hours. Patient currently on Meropenem 500 mg q8 hrs D21. Fluconazole 200 mg q24 hrs D21. ESR is high (62). Leukocytosis (10550). Neutrophilia (90.3).
# Endo: Last GRBS measured at June 28 2019, 04:39 AM and is high(402)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Somashekar M B
# INKABLRMAL52
# CVS: Hemodynamically stable. Last measured BP is 128/68.
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2.
# Renal: High Blood urea (112). Hyperchloremia (112). No Foley in situ
# GI: Bili(direct) is high (0.47). Hypoalbuminemia (2.9). No active patiet diet orders in the chart.
# Heme: Patient anemic (4). Low platelet counts (130000). Microcytosis (76.5).
# ID: Afebrile for the last 24 hours. Patient currently on Cefoperazone + Sulbactam 2 grams q12 hrs D21. Neutrophilia (73).
# Endo: Last GRBS measured at July 09 2019, 02:13 AM and is high(201)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Saroja B P
# INKABLRMAL51
# CVS: Hemodynamically stable. Last measured BP is 117/67.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2.
# Renal: Hyperkalemia (5.2). No Foley in situ
# GI: Patient is NPO since July 09 2019, 05:44 AM
# Heme: PT is high (16.7). INR is high (1.24).
# ID: Afebrile for the last 24 hours. Patient currently on Piperacillin + tazobactam 4 grams q8 hrs D21. Metronidazole 100 ml q8 hrs D21.
# Endo: Last GRBS measured at July 09 2019, 01:41 AM and is high(308)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Praveen Kumar
# INKABLRMAL48
# CVS: Hemodynamically stable. Last measured BP is 118/72. Tachycardic with HR of 111.
# CNS: E4V5M6.
# Resp: Saturating 94% on 21% FiO2.
# Renal: Hypokalemia (3.4). High Blood urea (30). Foley in situ, inserted on July 07 2019, 01:44 PM
# GI: Patient is NPO since July 08 2019, 06:57 AM
# Heme: PT is high (14.9).
# ID: Afebrile for the last 24 hours. Patient currently on Ceftriaxone 1 grams q12 hrs D21.
# Endo: Last GRBS measured at July 07 2019, 05:06 PM and is normal(136)
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------
# Bili Gowda
# INKABLRMAL53
# CVS: Hemodynamically stable. Last measured BP is 99/55. Tachycardic with HR of 110. Troponin T is high (19.85).
# CNS: E4V5M6.
# Resp: Saturating 99% on 21% FiO2. ABG suggestive of respiratory alkalosis. Lactic acidosis with lactate of 2.1.
# Renal: High Blood urea (59). High creatinine (1.67). Foley in situ, inserted on July 09 2019, 02:57 AM
# GI: ALK phos is low (26). Patient is on Oral-semi solid feeds. oral semisolid-soft diet as tolerated.
# Heme: Patient anemic (11.8). Low platelet counts (33000).
# ID: Afebrile for the last 24 hours. Currently not on any antibiotics.
# Endo: No GRBS available in the chart
# Prophylaxis: Not on pharmacological DVT Prophylaxis.
# -------------------------------------------------------

# %%
normals = {
    'daysHR': [60, 100],
    'daysMAP': [65, 200],
    'sbp': [20, 100],
    'dbp': [60, 180],
    'Na': [130, 145],
    'K': [3.5, 5],
    'Urea': [7, 20], 
    'Creatinine': [0, 1.2],
    'CALCIUM': [8.5, 10.5],
    'Ca': [8.5, 10.5], 
    'Mag': [1.7, 2.2], 
    'Phos': [2.5, 4.5], 
    'Chloride': [95, 105],
    'CO2': [22, 28],
    'Urine output': [1000, 4000],
    'daysSpO2': [90, 100],
    'RR': [8, 20], 
    'daysFiO2 (%)': [21, 100], 
    'pH': [7.36, 7.44], 
    'PaCO2': [36, 45], 
    'PaO2': [60, 150], 
    'Bicarb': [18, 26],
    'tCO2': [22, 29], 
    'Lactic': [0.4, 2],
    'Bili(Total)': [0.1, 1.2],
    'Bili(direct)': [0.01, 0.4],
    'Bili(indirect)': [0, 0.8], 
    'SGOT(AST)': [8, 48], 
    'SGPT(ALT)': [7, 55], 
    'ALK phos': [44, 147],
    'GGT': [0, 48], 
    'Albumin': [3.4, 5.4],
    'Total count': [4000, 10000], 
    'Hb': [12.5, 17],
    'Platelet': [225000, 450000],
    'Glucose': [70, 180],
    'Glucose Fasting': [70, 126], 
    'MCV': [80, 96], 
    'Neutrophils': [0, 70], 
    'Eosinophil': [0, 4], 
    'Lymphocytes': [0, 30], 
    'Atypical': [0, 0], 
    'Basophils': [0, 1],
    'INR': [0, 1.2], 
    'PT': [11, 13.5],
    'aptt': [30, 40], 
    'APTT': [30, 40], 
    'HbA1c': [0, 6], 
    'Troponin I': [0, 14], 
    'Troponin T': [0, 14], 
    'LDL': [0, 129], 
    'HDL': [50, 125], 
    'VLDL': [2, 30], 
    'Triglycerides': [100, 499], 
    'ESR': [0, 29], 
    'procalcitonin': [0, 0.14]
}

# %%
types = {
    'Na': 'ren',
    'K': 'ren',
    'Urea': 'ren', 
    'Creatinine': 'ren',
    'CALCIUM': 'ren', 
    'Ca': 'ren', 
    'Mag': 'ren', 
    'Phos': 'ren', 
    'Chloride': 'ren',
    'CO2': 'ren',
    'Urine output': 'ren', 
    'pH': 'abg', 
    'PaCO2': 'abg',
    'PaO2': 'abg', 
    'Bicarb': 'abg',
    'tCO2': 'ren', 
    'Lactic': 'abg',
    'Bili(Total)': 'gi',
    'Bili(direct)': 'gi',
    'Bili(indirect)': 'gi', 
    'SGOT(AST)': 'gi', 
    'SGPT(ALT)': 'gi', 
    'ALK phos': 'gi',
    'GGT': 'gi',
    'Albumin': 'gi',
    'Total count': 'Id', 
    'Hb': 'heme',
    'Platelet': 'heme',
    'Glucose': 'endo',
    'Glucose Fasting': 'endo', 
    'MCV': 'heme', 
    'Neutrophils': 'Id', 
    'Eosinophil': 'heme', 
    'Lymphocytes': 'heme', 
    'Atypical': 'heme', 
    'Basophils': 'heme',
    'INR': 'heme', 
    'PT': 'heme',
    'aptt': 'heme',
    'APTT': 'heme', 
    'HbA1c': 'heme', 
    'Troponin I': 'cvs', 
    'Troponin T': 'cvs', 
    'LDL': 'lipids', 
    'HDL': 'lipids', 
    'VLDL': 'lipids', 
    'Triglycerides': 'lipids', 
    'ESR': 'Id', 
    'procalcitonin': 'Id'
}

# %% [markdown]
# # Audits

# %%
def getD1UrineO(pat_io):
    intake_tot = []; output_tot = []; urine_tot = []
    days = pat_io.get('days')
    days_list = [sublist for sublist in days if sublist]
    # Iterating inside each day
    days_i = 0; days_o = 0; days_u = 0; dayAdd = 24
    intake_ls = []; output_ls = []; urine_ls = []
    for j in range(len(days_list)):
        hrs = days_list[j].get('hours')
        hrs_list = [sublist for sublist in hrs if sublist]
        # Iterating inside each hour
        for k in range(len(hrs_list)):
            hr_name = hrs_list[k].get('hourName') + dayAdd
            mts = hrs_list[k].get('minutes')
            mts_list = [sublist for sublist in mts if sublist]
            for l in range(len(mts_list)):
                intake = mts_list[l].get('intake')
                for name, value in intake.items():
                    for key, num in value.items():
                        if (type(num) == int):
                            days_i += num
                output = mts_list[l].get('output')
                for name, value in output.items():
                    if (value):
                        if (type(value) == list):
                            value = value[0]
                        for key, num in value.items():
                            if (type(num) == int):
                                days_o += num
                                if (name == 'urine'):
                                    days_u += num
        # Creating lists of days outputs
        urine_tot.append(days_u)
        urine_ls.append([hr_name, days_u])
        days_u = 0; dayAdd += 24
    # Output if lists are all null
    temp = []
    if (urine_ls == []):
        return None
    # Calculating 24hr 
    for i in range(len(urine_ls)):
        temp.append(abs((urine_ls[i][0])-24))
    index_min = np.argmin(temp)
    if (index_min == 0):
        index_min = 1
    urine_24 = 0
    for i in range(index_min-1, -1, -1):
        urine_24 += urine_ls[i][1]
    
    return urine_24

# %%
import numpy as np
import pandas as pd
import datetime 
from datetime import timedelta

# %% [markdown]
# ## Calculated Vars

# %%
def getAttributes(pat_obj):
    '''
    *Takes in mrn and returns info collected from all the documents for the patient 
    *Returns a list of lists with each list has a group of labs - {key: value} and 
    the time stamp for the group of labs
    '''
    tab = []; 
    for i in range(len(pat_obj[0]['documents'])):
        pat = [];
        if ((pat_obj[0]['documents'][i]).get('attributes') != None):
            if (pat_obj[0]['documents'][i] != {}):
                if (pat_obj[0]['documents'][i]['attributes'] != {}):
                    pat.append((pat_obj[0]['documents'][i]['attributes']))
                    pat.append(pat_obj[0]['documents'][i]['updatedAt'])
                tab.append(pat)
    return tab

# %%
def getAuditFC(pat_obj):
    audit_orders = pat_obj.get('orders')
    foley_days = 0; cvc_days = 0
    if (audit_orders.get('active').get('procedures')):
        actives = audit_orders.get('active').get('procedures')
        for i in range(len(actives)):
            if (actives[i].get('pType') == 'Foley'):
                # if there is no discharge date on a patient, but a order
                # alg will assume that patient still has the order - will take los 
                # as number of order days
                if (pat_obj.get('ICUDischargeDate')):
                    discharge_date = assertAndChange(pat_obj['ICUDischargeDate'])
                    orderStart = assertAndChange(actives[i].get('startTime'))
                    foley_days = (discharge_date.date() - orderStart.date()).days + 1
                else:
                    foley_days = pat_obj['days'][0].get('dayNumber')
            if ((actives[i].get('pType') == 'CVC') | (actives[i].get('pType') == 'PICC')):
                if (pat_obj.get('ICUDischargeDate')):
                    discharge_date = assertAndChange(pat_obj['ICUDischargeDate'])
                    orderStart = assertAndChange(actives[i].get('startTime'))
                    cvc_days = (discharge_date.date() - orderStart.date()).days + 1
                else:
                    cvc_days = pat_obj['days'][0].get('dayNumber')
    if (audit_orders.get('inactive').get('procedures')):
        inactives = audit_orders.get('inactive').get('procedures')
        for i in range(len(inactives)):
            if (inactives[i].get('pType') == 'Foley'):
                orderStart = assertAndChange(inactives[i].get('startTime'))
                dc_date = assertAndChange(inactives[i].get('updatedAt'))
                foley_days = (dc_date.date() - orderStart.date()).days + 1
            if ((inactives[i].get('pType') == 'CVC') | (inactives[i].get('pType') == 'PICC')):
                orderStart = assertAndChange(inactives[i].get('startTime'))
                dc_date = assertAndChange(inactives[i].get('updatedAt'))
                cvc_days = (dc_date.date() - orderStart.date()).days + 1
    return (foley_days, cvc_days)

# %%
def getAuditVitals(pat_obj):
    vital_dayList = pat_obj['days']
    v_all = []
    v_days = []
    fin = []
    for i in range(len(vital_dayList)):
        for j in range(len(vital_dayList[i]['hours'])):
            v_days.append(vital_dayList[i]['dayNumber'])
            v_days.append((vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysVentType')) == 'Mech')
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysMAP'))
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysTemperature'))
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysHR'))
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysRR'))
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysSpO2'))
            v_days.append(vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysFiO2'))
            bp = (vital_dayList)[i]['hours'][j]['minutes'][0]['vitals'].get('daysBP')
            sbp = pd.to_numeric(bp.split('/')[0]) if ((bp != None) & (bp!='')) else None
            v_days.append(sbp)
            e = (vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysGCSeyes'))
            v = (vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysGCSverbal'))
            m = (vital_dayList[i]['hours'][j]['minutes'][0]['vitals'].get('daysGCSmotor'))
            gcs = (e+v+m) if ((e!=None) & (v!=None) & (m!=None)) else None
            v_days.append(gcs)
            v_all.append(v_days)
            v_days = []
    return v_all

# %%
def getD1Vital(pat_obj, idx):
    vit_ls = getAuditVitals(pat_obj)
    d1vit = None
    for k in reversed(vit_ls):
        if ((k[0] < 3)):
            if (k[idx] is not None):
                d1vit = pd.to_numeric(k[idx])
                break
    return d1vit

# %%
def getD1Array(pat_obj):
    d1vit_arr = []
    for j in range(2, 10):
        d1vit_arr.append(getD1Vital(pat_obj, j))
    return d1vit_arr

# %%
def getAuditVent(pat_obj):
    v_all = getAuditVitals(pat_obj)
    # Vent days
    if (len(v_all)>0):
        vent_df = (pd.DataFrame(v_all).iloc[:, [0, 1]])
    else:
        vent_days = 0
        return vent_days
    dfs = []
    for k, v in vent_df.groupby(0):
        dfs.append(v)
    vent_days = 0
    for i in range(len(dfs)):
        if (sum(dfs[i][1])>=1):
            vent_days += 1
    return vent_days

# %%
def checkAndSubstitute(value, value_to_substitute):
    try:
        return_value = pd.to_numeric(value)
    except ValueError:
        return_value = value_to_substitute
    
    return return_value

# %%
def getAuditTwa(pat_obj):
    admit_date = assertAndChange(pat_obj['ICUAdmitDate'])
    if (pat_obj.get('ICUDischargeDate')):
        discharge_date = assertAndChange(pat_obj['ICUDischargeDate'])
    else:
        discharge_date = admit_date + timedelta(getAuditVitals(pat_obj)[0][0])
    audit_docs = pat_obj.get('documents')
    
    # TWA
    t = []; glu = []
    for i in range(len(audit_docs)):
        if (audit_docs[i].get('attributes')):
            if ((audit_docs[i].get('attributes')).get('Glucose')):
                g_val = (audit_docs[i].get('attributes')).get('Glucose')
                g_ts = assertAndChange(audit_docs[i].get('reportedAt'))
                t.append(g_val); t.append(g_ts)
                glu.append(t)
                t = []

    if (len(glu)>0):
        glu.append([0, discharge_date])

        tot_time = ((discharge_date - glu[0][1]).total_seconds())/3600
        numerator = 0
        for i in range(len(glu)):
            if ((i+1)<len(glu)):
                numerator += checkAndSubstitute(glu[i][0], 0) * (((glu[i+1][1] - glu[i][1]).total_seconds())/3600)
        wt_avg = (round(numerator/tot_time, 1)) 
    else:
        wt_avg = np.nan
    
    return wt_avg

# %%
audit_normals = { 
    1 : 7.4, 
    2: 40.5,
    3: 105,
    4: 22,
    5: 14.75,
    6: 7000, 
    7: 337500,
    8: 4.25,
    9: 137.5,
    10: 0.6,
    11: 14, 
    12: 0.6,
    13: 2500,
    14: 1.2,
    15: 0.6,
}

# %%
def getFirstDayLabs(pat_obj):
    
    labs = get24hrlabs(pat_obj)
    
    worst = []
    for j in range(15):
        try:
            labs[j] = pd.to_numeric([x for x in labs[j] if x is not None])
        except ValueError:
            labs[j] = []
    
    dist = []
    for k in range(15):
        if (len(labs[k])>1):
            for l in range(len(labs[k])):
                dist.append(abs(audit_normals.get(k+1) - labs[k][l]))
            maxindex = dist.index(max(dist))
            labs[k] = labs[k][maxindex]
            dist =[]
        elif (len(labs[k])==1):
            labs[k] = labs[k][0]
        elif (len(labs[k])==0):
            labs[k] = np.nan
    
    return labs

# %%
def get24hrlabs(pat_obj):
    pH = []; PaO2 = []; PaCO2 = []; HCO3 = []; Hb = []; TLC = []; Platelets = [];K = [];Na = []
    Cr = []; Ur = []; Bili = []; uo = []; Lactate = []; INR = [];
    attributes = getAttributes([pat_obj])
    admit_date = assertAndChange(pat_obj['ICUAdmitDate'])
    for i in range(len(attributes)):
        lapsed_hrs = ((assertAndChange(attributes[i][1]) - admit_date).total_seconds())/3600
        if (lapsed_hrs < 24):
            pH.append(attributes[i][0].get('pH'))
            PaCO2.append(attributes[i][0].get('PaCO2'))
            PaO2.append(attributes[i][0].get('PaO2'))
            HCO3.append(attributes[i][0].get('Bicarb'))
            Hb.append(attributes[i][0].get('Hb'))
            TLC.append(attributes[i][0].get('Total count'))
            Platelets.append(attributes[i][0].get('Platelet'))
            K.append(attributes[i][0].get('K'))
            Na.append(attributes[i][0].get('Na'))
            Cr.append(attributes[i][0].get('Creatinine'))
            Ur.append(attributes[i][0].get('Urea'))
            Bili.append(attributes[i][0].get('Bili(Total)'))
            output = getD1UrineO(pat_obj['io']) if (pat_obj.get('io')) else np.nan
            uo.append(output)
            Lactate.append(attributes[i][0].get('Lactic'))
            INR.append(attributes[i][0].get('INR'))
    return [pH, PaO2, PaCO2, HCO3, Hb, TLC, Platelets, K, Na, Cr, Ur, Bili, uo, Lactate, INR]

# %%
# LOS
def getPatientDetails(pat_obj):
    all_details = []; pat_details = []
    for x in range(len(all_pats)):
        
        pat_obj = all_pats[x]
        
        audit_name = pat_obj.get('name')
        pat_details.append(audit_name)
        audit_cpmrn = pat_obj.get('CPMRN')
        pat_details.append(audit_cpmrn)
        admit_date = pat_obj.get('ICUAdmitDate')
        admit_date = assertAndChange(admit_date)
        pat_details.append(admit_date)
        discharge_date = pat_obj.get('ICUDischargeDate')
        discharge_date = assertAndChange(discharge_date)
        pat_details.append(discharge_date)
        audit_age = pat_obj.get('age')
        pat_details.append(audit_age)
        audit_sex = pat_obj.get('sex')
        pat_details.append(audit_sex)
        audit_hosp = pat_obj.get('hospitalName')
        pat_details.append(audit_hosp)
        audit_chr = pat_obj.get('chronic')
        if (audit_chr):
            pat_details.append(audit_chr[0])
        else:
            pat_details.append(None)
        audit_immune = pat_obj.get('immune')
        if (audit_immune):
            pat_details.append(audit_immune[0])
        else:
            pat_details.append(None)
        audit_operative = pat_obj.get('operativeStatus')
        pat_details.append(audit_operative)
        dc_dispo = pat_obj.get('ICUDischargeDisposition')
        pat_details.append(dc_dispo)
        
        v_all = getAuditVitals(pat_obj)
        
        if (len(v_all) > 0):
            pat_details.append(v_all[0][0])
        else:
            pat_details.append(0)
        
        all_details.append(pat_details)
        pat_details = []
        
        

    pat_df = pd.DataFrame(all_details)
    pat_df = pat_df.rename({0:'Name', 1:'CPMRN', 2:'Admit date', 3:'Discharge date', 4:'Age', 
                           5:'Sex', 6:'Hospital', 7:'Chronic diseases', 8:'Immune status', 
                           9:'Operative status', 10:'Dishcarge disposition', 11:'LOS'}, axis=1)
    
    return pat_df

# %%
def getPatDets(pat_obj):
    pat_details = []
    
    audit_name = pat_obj.get('name')
    pat_details.append(audit_name)
    audit_cpmrn = pat_obj.get('CPMRN')
    pat_details.append(audit_cpmrn)
    admit_date = assertAndChange(pat_obj.get('ICUAdmitDate')).strftime("%B %Y")
    pat_details.append(admit_date)
    discharge_date = assertAndChange(pat_obj.get('ICUDischargeDate')).strftime("%B %Y") if pat_obj.get('ICUDischargeDate') else ''
    pat_details.append(discharge_date)
    audit_age = pat_obj.get('age')
    pat_details.append(audit_age)
    audit_sex = pat_obj.get('sex')
    pat_details.append(audit_sex)
    audit_hosp = pat_obj.get('hospitalName')
    pat_details.append(audit_hosp)
    audit_chr = pat_obj.get('chronic')
    if (audit_chr):
        pat_details.append(audit_chr[0])
    else:
        pat_details.append(None)
    audit_immune = pat_obj.get('immune')
    if (audit_immune):
        pat_details.append(audit_immune[0])
    else:
        pat_details.append(None)
    audit_operative = pat_obj.get('operativeStatus')
    pat_details.append(audit_operative)
    dc_dispo = pat_obj.get('ICUDischargeDisposition')
    pat_details.append(dc_dispo)
    
    return (pat_details)

# %%
def getCalcVars(all_pats):
    
    # FOLEY
    f_list = []; los_list = []; c_list = []; all_vent = []; all_twa = []; all_vit_list = []; alld1labs = []
    f_array = []; c_array = []
    for j in range(len(all_pats)):
        f_array.append(getAuditFC(all_pats[j])[0])
        c_array.append(getAuditFC(all_pats[j])[1])
        all_vent.append(getAuditVent(all_pats[j]))
        all_twa.append(getAuditTwa(all_pats[j]))
        all_vit_list.append(getD1Array(all_pats[j]))
        v_all = getAuditVitals(all_pats[j])
        alld1labs.append(getFirstDayLabs(all_pats[j]))
        los_list.append(v_all[0][0]) if (len(v_all) > 0) else los_list.append(0)    
    
    los_array = np.array(los_list)
    
    # Rectifying cases where foley days > los
    for i in range(len(f_array)):
        if((f_array[i] > los_array[i])):
            f_array[i] = los_array[i]
    
    # VENT DAYS
    all_vent = np.array(all_vent)
    
    # TWA GLUCOSE
    all_twa = np.array(all_twa)
    
    # CREATING DATAFRAME
    data = {'Foley days': f_array,  
       'Vent days': all_vent, 
       'TWA Glucose': all_twa}
    calculated_vars_df = pd.DataFrame(data)
    
    vit_df = pd.DataFrame(all_vit_list)
    vit_df = vit_df.rename({0:'MAP', 1:'Temperature', 2:'HR', 3:'RR', 4:'SpO2', 5:'FiO2', 6:'E', 7:'V', 8:'M'}, axis=1)
    
    labs_df = pd.DataFrame(alld1labs)
    labs_df = labs_df.rename({0:'pH', 1:'PaO2', 2:'PaCO2', 3:'Bicarb', 4:'Hb', 5:'TLC', 6:'Platelets', 7:'K', 
                   8:'Na', 9:'Creatinine', 10:'BUN', 11:'T.Bili', 12:'Urine output', 13:'Lactate', 14:'INR'}, axis=1)
    
    return (calculated_vars_df, vit_df, labs_df)

# %%
def getTempScore(temp):
    temp = ((temp-32)*0.56)
    if ((36<=temp) & (temp<=38.4)):
        tempScore = 0 
    elif (((38.5<=temp) & (temp<=38.9)) | ((34<=temp) & (temp<=35.9))):
        tempScore = 1
    elif ((32<=temp) & (temp<=33.9)):
        tempScore = 2
    elif (((39<=temp) & (temp<=40.9)) | ((30<=temp) & (temp<=31.9))):
        tempScore = 3
    elif ((temp >= 41) | (temp <= 29.9)):
        tempScore = 4
    else:
        tempScore = 0
    return tempScore
        
def getMapScore(Map):
    if ((70<=Map) & (Map<=109)):
        mapScore = 0 
    elif (((110<=Map) & (Map<=129)) | ((50<=Map) & (Map<=69))):
        mapScore = 2
    elif ((130<=Map) & (Map<=159)):
        mapScore = 3
    elif ((Map >= 160) | (Map <= 49)):
        mapScore = 4
    else:
        mapScore = 0
    return mapScore

def getHrScore(hr):
    if ((70<=hr) & (hr<=109)):
        hrScore = 0 
    elif (((110<=hr) & (hr<=139)) | ((55<=hr) & (hr<=69))):
        hrScore = 2
    elif (((140<=hr) & (hr<=179)) | ((40<=hr) & (hr<=54))):
        hrScore = 3
    elif ((hr >= 180) | (hr <= 39)):
        hrScore = 4
    else:
        hrScore = 0
    return hrScore

def getRrScore(rr):
    if ((12<=rr) & (rr<=24)):
        rrScore = 0 
    elif (((10<=rr) & (rr<=11)) | ((25<=rr) & (rr<=34))):
        rrScore = 1
    elif ((6<=rr) & (rr<=9)):
        rrScore = 2
    elif ((35<=rr) & (rr<=49)):
        rrScore = 3
    elif ((rr >= 50) | (rr <= 5)):
        rrScore = 4
    else:
        rrScore = 0
    return rrScore

def getOxScore(fio2, pao2,paco2):
    if((fio2<0.5) & (pao2 != np.nan)):
        if(pao2>70):
            oxScore = 0
        elif ((61<=pao2) & (pao2<=70)):
            oxScore = 1
        elif ((55<=pao2) & (pao2<=60)):
            oxScore = 3
        elif (pao2<55):
            oxScore = 4
        else:
            oxScore = 0
    else:
        if (paco2 != np.nan):
            Aa = ((fio2*(760-47))-(paco2/0.8))
            if(Aa<200):
                oxScore = 0
            elif ((200<=Aa) & (Aa<=349)):
                oxScore = 2
            elif ((350<=Aa) & (Aa<=499)):
                oxScore = 3
            elif (Aa>=500):
                oxScore = 4
            else:
                oxScore = 0
    # Throwing out VBG entries
    if (pao2<0.45):
        oxScore = 0
    return oxScore

def getPhScore(ph):
    if ((7.33<=ph) & (ph<=7.49)):
        phScore = 0 
    elif ((7.5<=ph) & (ph<=7.59)):
        phScore = 1
    elif ((7.25<=ph) & (ph<=7.32)):
        phScore = 2
    elif ((7.15<=ph) & (ph<=7.24) | (7.6<=ph) & (ph<=7.69)):
        phScore = 3
    elif ((ph >= 7.7) | (ph < 7.15)):
        phScore = 4
    else:
        phScore = 0
    return phScore

def getNaScore(Na):
    if ((130<=Na) & (Na<=149)):
        NaScore = 0 
    elif ((150<=Na) & (Na<=154)):
        NaScore = 1
    elif (((155<=Na) & (Na<=159)) | ((120<=Na) & (Na<=129))):
        NaScore = 2
    elif (((160<=Na) & (Na<=179)) | ((111<=Na) & (Na<=119))):
        NaScore = 3
    elif ((Na >= 180) | (Na <= 110)):
        NaScore = 4
    else:
        NaScore = 0
    return NaScore

def getKScore(K):
    if ((3.5<=K) & (K<=5.4)):
        KScore = 0 
    elif (((5.5<=K) & (K<=5.9)) | ((3<=K) & (K<=3.4))):
        KScore = 1
    elif ((2.5<=K) & (K<=2.9)):
        KScore = 2
    elif ((6<=K) & (K<=6.9)):
        KScore = 3
    elif ((K >= 7) | (K < 2.5)):
        KScore = 4
    else:
        KScore = 0
    return KScore

def getCrScore(Cr):
    if ((0.6<=Cr) & (Cr<=1.4)):
        CrScore = 0 
    elif (((1.5<=Cr) & (Cr<=1.9)) | (Cr<0.6)):
        CrScore = 2
    elif ((2<=Cr) & (Cr<=3.4)):
        CrScore = 3
    elif (Cr >= 3.5):
        CrScore = 4
    else:
        CrScore = 0
    return CrScore

def getHctScore(hb):
    hct = (hb*3)
    if ((30<=hct) & (hct<=45.9)):
        hctScore = 0 
    elif ((46<=hct) & (hct<=49.9)):
        hctScore = 1
    elif (((50<=hct) & (hct<=59.9)) | ((20<=hct) & (hct<=29.9))):
        hctScore = 2
    elif ((hct >= 60) | (hct < 20)):
        hctScore = 4
    else:
        hctScore = 0
    return hctScore
        
def getTcScore(tc):
    tc = tc/1000;
    if ((3<=tc) & (tc<=14.9)):
        tcScore = 0 
    elif ((15<=tc) & (tc<=19.9)):
        tcScore = 1
    elif (((20<=tc) & (tc<=39.9)) | ((1<=tc) & (tc<=2.9))):
        tcScore = 2
    elif ((tc >= 40) | (tc < 1)):
        tcScore = 4
    else:
        tcScore = 0
    return tcScore

def getAgeScore(age):
    if ((age<=44)):
        ageScore = 0 
    elif ((45<=age) & (age<=54)):
        ageScore = 2
    elif ((55<=age) & (age<=64)):
        ageScore = 3
    elif ((65<=age) & (age<=74)):
        ageScore = 5
    elif (age>=75):
        ageScore = 6
    else:
        ageScore = 0
    return ageScore

# %%
trop_arr = []
for x in range(len(all_pats)):
    pat_obj = all_pats[x]
    trop_arr.append(trop(pat_obj))

# %%
def trop(pat_obj):

    vits = getD1Array(pat_obj)
    labs = getFirstDayLabs(pat_obj)
    otrs = getPatDets(pat_obj)
    
    surgery = otrs[-2]; hb = labs[4]; bun = (labs[-5])/2.14; gcs = vits[-1]; sbp = vits[-2]; rr = vits[3]
    surgScore = getSurgScore(surgery) if (surgery) else 0
    hbScore = getHbScore(hb) if (~np.isnan(hb)) else 0
    bunScore = getBunScore(bun) if (~np.isnan(bun)) else 0
    gcsScore = getGcsScore(gcs) if (gcs) else 0
    sbpScore = getSbpScore(sbp) if (sbp) else 0
    rrScore = getRRScore(rr) if (rr) else 0
    
    tropics = surgScore + hbScore + bunScore + sbpScore + gcsScore + rrScore
    tropicsMort = mortCalc(tropics)

    return tropicsMort

def getSurgScore(surgery):
    if (surgery == "Non-Operative"):
        surgScore = 1.5
    else:
        surgScore = 0
    return surgScore

def getHbScore(hb):
    if ((hb >= 12.1)):
        hbScore = 0
    elif ((hb <= 12) & (hb >= 8.1)):
        hbScore = 1
    elif ((hb <= 8) & (hb >= 4.1)):
        hbScore = 3
    elif (hb <= 4):
        hbScore = 3
    return hbScore

def getBunScore(bun):
    if (bun <= 59.9):
        bunScore = 0
    elif ((bun >= 60) & (bun <= 119)):
        bunScore = 1
    elif ((bun >= 120) & (bun <= 179)):
        bunScore = 2
    elif ((bun >= 180) & (bun <= 239)):
        bunScore = 3
    elif ((bun >= 240) & (bun <= 299)):
        bunScore = 4
    elif ((bun >= 300) & (bun <= 359)):
        bunScore = 5
    elif ((bun >= 360) & (bun <= 419)):
        bunScore = 6
    elif ((bun >= 420) & (bun <= 479)):
        bunScore = 7
    elif ((bun >= 480) & (bun <= 539)):
        bunScore = 8
    elif ((bun >= 540) & (bun <= 599)):
        bunScore = 9
    elif (bun > 600):
        bunScore = 10
    return bunScore

def getGcsScore(gcs):
    if (gcs > 14):
        gcsScore = 0
    elif ((gcs <= 14) & (gcs > 11)):
        gcsScore = 1
    elif ((gcs <= 11) & (gcs > 9)):
        gcsScore = 2
    elif ((gcs <= 9) & (gcs > 6)):
        gcsScore = 3
    elif ((gcs <= 6) & (gcs > 4)):
        gcsScore = 4
    elif (gcs <= 4):
        gcsScore = 5
    return gcsScore

def getSbpScore(sbp):
    if (sbp >= 90.1):
        sbpScore = 0
    elif ((sbp <= 90) & (sbp >= 60.1)):
        sbpScore = 0.5
    elif (sbp <= 60):
        sbpScore = 1
    return sbpScore

def getRRScore(rr):
    if ((rr >= 12) | (rr <= 24)):
        rrScore = 0
    elif ((rr <= 11.9) & (rr >= 8)):
        rrScore = 0.5
    elif ((rr <= 7.9) & (rr >= 6)):
        rrScore = 1
    elif ((rr <= 5.9) & (rr >= 4)):
        rrScore = 1.5
    elif (rr < 3.9):
        rrScore = 2
    elif ((rr >= 24.1) & (rr <= 28)):
        rrScore = 0.5
    elif ((rr >= 28.1) & (rr <= 30)):
        rrScore = 1
    elif ((rr >= 30.1) & (rr <= 32)):
        rrScore = 1.5
    elif ((rr >= 32.1) & (rr <= 34)):
        rrScore = 2
    elif ((rr >= 34.1) & (rr <= 36)):
        rrScore = 2.5
    elif ((rr >= 36.1) & (rr <= 38)):
        rrScore = 3
    elif (rr >= 38):
        rrScore = 3.5
    else:
        rrScore = 0
    return rrScore

def mortCalc(tropics):
    if (tropics <= 0.49):
        tropicsMort = 0
    elif (tropics == 0.5):
        tropicsMort = 5
    elif (tropics == 1):
        tropicsMort = 7 
    elif (tropics == 1.5): 
        tropicsMort = 8
    elif (tropics == 2):
        tropicsMort = 9
    elif (tropics == 2.5):
        tropicsMort = 11
    elif (tropics == 3):
        tropicsMort = 14 
    elif (tropics == 3.5): 
        tropicsMort = 15
    elif (tropics == 4):
        tropicsMort = 17
    elif (tropics == 4.5):
        tropicsMort = 20
    elif (tropics == 5):
        tropicsMort = 23
    elif (tropics == 5.5): 
        tropicsMort = 27
    elif (tropics == 6):
        tropicsMort = 30
    elif (tropics == 6.5):
        tropicsMort = 35
    elif (tropics == 7):
        tropicsMort = 39
    elif (tropics == 7.5): 
        tropicsMort = 44
    elif (tropics == 8):
        tropicsMort = 48
    elif (tropics == 8.5):
        tropicsMort = 53
    elif (tropics == 9):
        tropicsMort = 57
    elif (tropics == 9.5): 
        tropicsMort = 61
    elif (tropics == 10):
        tropicsMort = 65
    elif (tropics == 10.5):
        tropicsMort = 70
    elif (tropics == 11):
        tropicsMort = 72
    elif (tropics == 11.5): 
        tropicsMort = 76
    elif (tropics == 12):
        tropicsMort = 79
    elif (tropics == 12.5):
        tropicsMort = 82
    elif (tropics == 13):
        tropicsMort = 84
    elif (tropics == 13.5): 
        tropicsMort = 86
    elif (tropics == 14):
        tropicsMort = 88
    elif (tropics == 14.5):
        tropicsMort = 91
    elif (tropics == 15):
        tropicsMort = 92
    elif (tropics == 15.5): 
        tropicsMort = 93
    elif (tropics == 16):
        tropicsMort = 94
    elif (tropics == 16.5):
        tropicsMort = 95
    elif (tropics == 17):
        tropicsMort = 95.5
    elif (tropics == 17.5):
        tropicsMort = 96
    elif (tropics == 18):
        tropicsMort = 96.5
    elif (tropics == 18.5): 
        tropicsMort = 97
    elif (tropics == 19):
        tropicsMort = 97.5
    elif (tropics == 19.5):
        tropicsMort = 98
    elif (tropics == 20):
        tropicsMort = 98.5
    elif (tropics == 20.5): 
        tropicsMort = 99
    elif (tropics == 21):
        tropicsMort = 99
    return (tropicsMort/100)

# %%
def getApache(pat_obj):
    
    vits = getD1Array(pat_obj)
    labs = getFirstDayLabs(pat_obj)
    otrs = getPatDets(pat_obj)
    
    temp = vits[1]; Map = vits[0]; hr = vits[2]; rr = vits[3]; fio2 = vits[5]
    ph = labs[0]; pao2 = labs[1]; paco2 = labs[2]; Na = labs[8]; K = labs[7]; Cr = labs[9]
    hb = labs[4]; tc = labs[5]; age = otrs[3];
    age = pd.to_numeric(otrs[4]); chronic = otrs[-3]; sur = otrs[-2]
    
    tempScore = getTempScore(temp) if (temp) else 0
    mapScore = getMapScore(Map) if (Map) else 0
    hrScore = getHrScore(hr) if (hr) else 0
    rrScore = getRrScore(rr) if (rr) else 0
    oxScore = getOxScore(fio2, pao2, paco2) if (fio2) else 0
    phScore = getPhScore(ph) if (ph) else 0
    NaScore = getNaScore(Na) if (Na) else 0
    KScore = getKScore(K) if (K) else 0
    CrScore = getCrScore(Cr) if (Cr) else 0
    hctScore = getHctScore(hb) if (hb) else 0
    tcScore = getTcScore(tc) if (tc) else 0
    ageScore = getAgeScore(age) if (age) else 0
    
    if(vits[-1] != None):
        gcs = vits[-1]
        if (gcs<3):
            gcs = 3
        gcsScore = (15 - gcs)
    else:
        gcsScore = 0
    
    physio = (tempScore + mapScore + hrScore + rrScore + oxScore + phScore 
          + NaScore + KScore + CrScore + hctScore + tcScore + gcsScore + ageScore)
    
    if ((chronic == "Heart Failure") | (chronic == "Cirrhosis") | (chronic == "Chronic Lung Disease") | (chronic == "Dialysis Dependent")):
        if (sur == "Post-Operative"):
            surg = 2
        if (sur == "Non-Operative"):
            surg = 5
    else:
        surg = 0
    
    prob = (-3.517 + (0.146*physio) + 0.603*surg)
    probinlog = math.exp(prob)
    apacheMort = round((probinlog/(1+probinlog)), 3)
    
    return apacheMort

# %%
def calcArray(pat_obj):
    foley = (getAuditFC(pat_obj)[0])
    cvc = (getAuditFC(pat_obj)[1])
    vent = (getAuditVent(pat_obj))
    twa = (getAuditTwa(pat_obj))
    v_all = getAuditVitals(pat_obj)
    los = (v_all[0][0]) if (len(v_all) > 0) else 0
    
    return (foley, cvc, vent, twa, los)

# %%
def getAuditArray(pat_obj):
    vits = np.array(getD1Array(pat_obj)).reshape(1, -1)
    calcs = np.array(calcArray(pat_obj)).reshape(1, -1)
    labs = np.array(getFirstDayLabs(pat_obj)).reshape(1, -1)
    otrs = np.array(getPatDets(pat_obj)).reshape(1, -1)
    apache = np.array(getApache(pat_obj)).reshape(1, -1)
    tropics = np.array(trop(pat_obj)).reshape(1, -1)
    
    arr = np.concatenate((otrs, vits, calcs, labs, apache, tropics), axis=1)
    return arr

# %%
import math

# %%
with open('patients.json') as json_file:
    all_pats = json.load(json_file)

# %%
print(len(all_pats))
# Out:
# 1224

# %%
def assertAndChange(dic):
    if (dic != None):
        try:
            assert(type(dic) == datetime.datetime)
        except AssertionError:
            dic = (datetime.datetime.strptime(dic.get('$date'), '%Y-%m-%dT%H:%M:%S.%f%z'))
    return dic

# %%
def determine(x):
    name = x['name']
    det = False
    if (re.match('z*test', name.lower())):
        det = True
    return det

# %%
all_pats[:] = [x for x in all_pats if not determine(x)]

# %%
def exportAuditsToCSV(all_pats, filename):
    for x in range(len(all_pats)):
        all_pats[:] = [x for x in all_pats if not determine(x)]
        pat_obj = all_pats[x]
        array = getAuditArray(pat_obj)
        if (x<1):
            array1 = array
            continue
        elif (x==1):
            array_all = np.concatenate((array1, array), axis=0)
        else:
            array_all = np.concatenate((array_all, array), axis=0)

    pd.set_option('display.max_columns', 500)
    df_stats = pd.DataFrame(array_all)
    df_stats.columns = ['Name', 'CPMRN', 'Date of admission', 'Date of Discharge', 
                         'Age', 'Gender', 'Hospital', 'Chronic disease', 'Immune status', 
                         'Surgical status', 'DC Dispo', 'MAP', 'Temperature', 'HR', 'RR', 
                         'SpO2', 'FiO2', 'SBP', 'GCS' , 'Foley days', 
                         'CVC days', 'Vent days', 'TWA Glucose', 'LOS', 'pH', 'PaO2', 
                         'PaCO2', 'HCO3', 'Hb', 'TLC', 'Platelets', 'K', 'Na', 'Cr', 
                         'Ur', 'T.Bili', 'Urine output', 'Lactate', 'INR', 'APACHE II Pred Mort', 'Trop Pred Mort']
    df_stats.to_csv('{}.csv'.format(filename))
    return df_stats

# %%
df_stats = exportAuditsToCSV(all_pats, 'June_July_allhosp')

# %%
import sqlite3

conn = sqlite3.connect('trial.db')
c = conn.cursor()

# %%
df_stats.to_sql(name='data', con=conn, if_exists='append', index=False)
# Out:
# /home/dileep/anaconda3/envs/cpcv/lib/python3.7/site-packages/pandas/core/generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
def getPivotTable(df_stats, hospital_name):
    
    df_stats['Age'] = pd.to_numeric(df_stats['Age'])
    df_stats['LOS'] = pd.to_numeric(df_stats['LOS'])
    df_stats['TWA Glucose'] = pd.to_numeric(df_stats['TWA Glucose'])
    
    hosp = df_stats.groupby([df_stats['Hospital']==hospital_name, 'Date of admission']).agg({'LOS':{'Avg LOS':'mean',
                                                                          'Patient days':'sum'},
                                                                   'Age':'mean', 
                                                                   'CPMRN':'count', 
                                                                  'Foley days':'sum', 
                                                                  'CVC days':'sum', 
                                                                  'Vent days':'sum', 
                                                                  'TWA Glucose':'mean'}).round(1).transpose()
    CP = df_stats.groupby(['Date of admission']).agg({'LOS':{'Avg LOS':'mean',
                                                                      'Patient days':'sum'},
                                                               'Age':'mean', 
                                                               'CPMRN':'count', 
                                                              'Foley days':'sum', 
                                                              'CVC days':'sum', 
                                                              'Vent days':'sum', 
                                                              'TWA Glucose':'mean'}).round(1).transpose()
    hosp_audit = pd.concat((hosp, CP), axis=1).iloc[:,3:]
    
    import copy
    hosp_audit_t = copy.deepcopy(hosp_audit)
    for i in range(hosp_audit_t.shape[1]):
        pat_days = hosp_audit_t.iloc[1, i]
        fol_days = hosp_audit_t.iloc[4, i]
        cvc_days = hosp_audit_t.iloc[5, i]
        vent_days = hosp_audit_t.iloc[6, i]

        f_100pd = (fol_days/pat_days)*100
        c_100pd = (cvc_days/pat_days)*100
        v_100pd = (vent_days/pat_days)*100

        hosp_audit.iloc[4, i] = (f_100pd).round(1)
        hosp_audit.iloc[5, i] = (c_100pd).round(1)
        hosp_audit.iloc[6, i] = (v_100pd).round(1)
        
    new_cols = []
    for col in hosp_audit.columns:
        if (type(col)==tuple):
            a, b = col
            new_cols.append(b)
        else:
            new_cols.append(col)
    
    hosp_audit.reset_index(inplace=True)
    hosp_audit.drop(['level_0', 'level_1'], axis=1, inplace=True)
    hosp_audit.index = ['Avg LOS', 'Patient days', 'Age', 'Admissions', 
                        'Foley days', 'CVC days', 'Vent days', 'TWA Glucose']
    hosp_audit.columns = new_cols
    
    return hosp_audit

# %%
def getMortTable(df_stats, hospital_name):
    m = df_stats.groupby([df_stats['Hospital']==hospital_name, 'Date of admission', 'DC Dispo']).agg({'CPMRN':'count'}).transpose()
    m = m.iloc[:, m.columns.get_level_values(0)==True].transpose().droplevel('Hospital')
    return m

# %%
def getApacheTable(df_stats, hospital_name):
    df_stats['APACHE II Score'] = pd.to_numeric(df_stats['APACHE II Score'])
    ap = df_stats.groupby([df_stats['Hospital']==hospital_name, 'Date of admission']).agg({'APACHE II Score':{'Avg APACHE Predicted mortality':'mean',
                                                                              'Predicted mort count':'sum'}}).round(2).transpose()
    ap = ap.iloc[:, ap.columns.get_level_values(0)==True].transpose().droplevel('Hospital')
    return ap

# %%
hosp_audit = getPivotTable(df_stats, 'BHIO')
hosp_audit
# Out:
#               August 2019  July 2019  June 2019  August 2019  July 2019  \
# Avg LOS               1.7        2.4        2.4          2.3        2.8
# Patient days         15.0      123.0      107.0        310.0     1596.0
# Age                  58.2       56.5       54.2         52.3       51.5
# Admissions            9.0       52.0       45.0        136.0      578.0
# Foley days           73.3       60.2       51.4         41.9       45.7
# CVC days              0.0        0.0       10.3          3.9        4.2
# Vent days             0.0        2.4        3.7         16.5       11.2
# TWA Glucose         170.4      161.3      147.3        151.9      149.9
#
#               June 2019
# Avg LOS             2.7
# Patient days     1381.0
# Age                51.7
# Admissions        506.0
# Foley days         34.3
# CVC days           11.4
# Vent days           7.5
# TWA Glucose       154.1

# %%
getApacheTable(df_stats, 'Prashant')
# Out:
#                                  APACHE II Score
#                   Avg APACHE Predicted mortality Predicted mort count
# Date of admission
# August 2019                                 0.16                13.41
# July 2019                                   0.16                52.87
# June 2019                                   0.13                42.99

# %%
hosp_audit
# Out:
#               (True, August 2019)  (True, July 2019)  (True, June 2019)  \
# Avg LOS                       1.6                2.6                3.1
# Patient days                  8.0               64.0               46.0
# Age                          41.6               53.2               46.9
# Admissions                    5.0               25.0               15.0
# Foley days                   62.5               57.8               52.2
# CVC days                     37.5               10.9               19.6
# Vent days                    37.5               17.2               13.0
# TWA Glucose                 214.6              143.9              178.8
#
#               August 2019  July 2019  June 2019
# Avg LOS               2.3        2.8        2.7
# Patient days        310.0     1596.0     1381.0
# Age                  52.3       51.5       51.7
# Admissions          136.0      578.0      506.0
# Foley days           41.9       45.7       34.3
# CVC days              3.9        4.2       11.4
# Vent days            16.5       11.2        7.5
# TWA Glucose         151.9      149.9      154.1

# %%
getMortTable(df_stats, 'MRNH')
# Out:
#                                                                       CPMRN
# Date of admission DC Dispo
# August 2019       Death                                                   1
#                   Discharged to home/self care AGAINST medical ad...      1
#                   Discharged to home/self care as per medical advice      1
# July 2019         Death                                                   4
#                   Discharged to higher centre of care                     1
#                   Discharged to home/self care AGAINST medical ad...      5
#                   Discharged to home/self care as per medical advice      7
#                   Discharged to ward/floor                                8
# June 2019         Discharged to another facility                          1
#                   Discharged to higher centre of care                     2
#                   Discharged to home/self care AGAINST medical ad...      2
#                   Discharged to other ICU within the same hospital        1
#                   Discharged to ward/floor                                9

# %%
los.to_csv('Audit_table.csv')
mort_data.to_csv('Mort_table.csv')

# %%
post = pd.read_csv('/home/dileep/Desktop/python/All_csvs/Audits.csv')
pre = pd.read_csv('/home/dileep/Desktop/python/All_csvs/Micus_Data_Jul-Jan.csv')

# %%
print(post.shape)
print(pre.shape)
# Out:
# (1220, 42)
# (2893, 42)

# %%
colnames = post.columns
pre.columns = colnames

# %%
cp_data_18_19 = post

# %%
dc_dispos = list(cp_data_18_19['DC Dispo'].unique())

# %%
for d in dc_dispos:
    if (d not in dispos):
        print(d)
# Out:
# nan

# %%
cp_data_18_19['Gender'].replace(to_replace=dict(Male='M', 
                                                  Female='F'), inplace=True)

# %%
cp_data_18_19['DC Dispo'].replace(to_replace=dict(No='Discharged to ward/floor', 
                                                  Alive='Discharged to home/self care as per medical advice'), inplace=True)

# %%
cp_data_18_19['Surgical status'].replace(['Elective surgery', 'Emergency surgery'], 
                                         ['Post-Operative', 'Post-Operative'], inplace=True)

# %%
cp_data_18_19['DC Dispo'].replace(['Discharge to home', 'Transfer to ward', 
                                   'Transfer to another hospital as per physician recommendation', 
                                  'undefined', 'Undefined', 'Expired', 'LAMA - Palliation due to cost', 
                                  'pulseless electrical activity', 'LAMA - Shift to outside ICU'], ['Discharged to home/self care as per medical advice', 'Discharged to ward/floor', 
                                'Discharged to higher centre of care', 'Discharged to ward/floor', 'Discharged to ward/floor', 
                                'Death', 'Death', 'Death', 'Discharged to home/self care AGAINST medical advice (DAMA)'], inplace=True)

# %%
dispos = ['Discharged to home/self care AGAINST medical advice (DAMA)', 
         'Discharged to home/self care as per medical advice', 
         'Discharged to ward/floor', 
         'Discharged to Intermediate Care Unit/High Dependency Unit (HDU)', 
         'Discharged to other ICU within the same hospital', 
         'Discharged to higher centre of care',
         'Discharged to another facility', 
         'Death']

# %%
cp_data_18_19.to_csv('CP_2018-19_data.csv')

# %% [markdown]
# ## Final

# %%
import datetime
from datetime import timedelta
from IPython.display import display
pd.options.display.max_columns = None

# %%
all_pats = list(db2.patients.find({}))

# %%
pat_details = getPatDetails(all_pats)

# %%
calc_df, vit_df, labs_df = getCalcVars(all_pats)

# %%
final_df = pd.concat([pat_details, calc_df, vit_df, labs_df], axis=1)
final_df.head()
# Out:
#             Name        CPMRN              Admit date          Discharge date  \
# 0         Vijaya  INKABLRMAL1 2019-06-04 22:40:43.009 2019-06-05 06:30:20.480
# 1  Sathi skandan  INKABLRMAL2 2019-06-09 08:50:06.686 2019-06-10 07:50:30.440
# 2    Vijaya ravi  INKABLRMAL3 2019-06-09 11:30:59.479 2019-06-11 06:31:19.852
# 3        Kavitha  INKABLRMAL5 2019-06-11 10:38:01.392 2019-06-13 07:30:11.659
# 4       Selvaraj  INKABLRMAL8 2019-06-13 16:46:45.046 2019-06-14 06:31:11.989
#
#   Age   Sex Hospital Chronic diseases Immune status Operative status  \
# 0  67     F  Mallige             None          None    Non-Operative
# 1  67     F  Mallige             None          None             None
# 2  57     F  Mallige             None          None             None
# 3  40  None  Mallige             None          None    Non-Operative
# 4  40     M  Mallige             None          None   Post-Operative
#
#       Dishcarge disposition  LOS  Foley days  Vent days  TWA Glucose     MAP  \
# 0  Discharged to ward/floor    1           0          0          NaN  104.67
# 1  Discharged to ward/floor    2           0          0        321.0   89.67
# 2  Discharged to ward/floor    3           0          0        244.3  103.33
# 3  Discharged to ward/floor    3           0          0          NaN   79.00
# 4  Discharged to ward/floor    2           0          0          NaN     NaN
#
#    Temperature     HR    RR  SpO2  FiO2    E    V    M    pH  PaO2  PaCO2  \
# 0         98.7   67.0  18.0  96.0  32.0  4.0  5.0  6.0  7.38  63.0   34.9
# 1         98.6  130.0  23.0  95.0  28.0  4.0  5.0  6.0  7.60  65.0   22.8
# 2         98.6  112.0  23.0  90.0  24.0  4.0  5.0  6.0   NaN   NaN    NaN
# 3         98.7  104.0  22.0  98.0  32.0  4.0  5.0  6.0   NaN   NaN    NaN
# 4         98.2   88.0  27.0  99.0  36.0  4.0  5.0  6.0   NaN   NaN    NaN
#
#    Bicarb    Hb      TLC  Platelets    K     Na  Creatinine   BUN  T.Bili  \
# 0    15.5  16.2   9100.0   308000.0  4.1  143.0        0.67  22.0    0.49
# 1    22.3   NaN      NaN        NaN  NaN    NaN         NaN   NaN     NaN
# 2     NaN   NaN      NaN        NaN  NaN    NaN         NaN   NaN     NaN
# 3     NaN  11.6  12800.0   322000.0  5.2  137.0        0.82  20.0    0.35
# 4     NaN  14.3   8980.0   243000.0  4.0  138.0        1.03  32.0    0.77
#
#    Urine output  Lactate   INR
# 0           NaN      3.2  0.82
# 1           NaN      NaN   NaN
# 2           NaN      NaN   NaN
# 3           NaN      NaN   NaN
# 4           NaN      NaN  0.88

# %%
final_df
# Out:
#                          Name         CPMRN              Admit date  \
# 0                      Vijaya   INKABLRMAL1 2019-06-04 22:40:43.009
# 1               Sathi skandan   INKABLRMAL2 2019-06-09 08:50:06.686
# 2                 Vijaya ravi   INKABLRMAL3 2019-06-09 11:30:59.479
# 3                     Kavitha   INKABLRMAL5 2019-06-11 10:38:01.392
# 4                    Selvaraj   INKABLRMAL8 2019-06-13 16:46:45.046
# 5                 Sarojamma V   INKABLRMAL6 2019-06-11 22:16:30.710
# 6                    Sai Nath   INKABLRMAL9 2019-06-14 10:32:17.807
# 7       Keshava Narayana Raju   INKABLRMAL7 2019-06-11 22:52:19.014
# 8              Sudhakar Reddy  INKABLRMAL12 2019-06-17 18:40:36.487
# 9                       Hamsa  INKABLRMAL11 2019-06-16 10:44:40.208
# 10          Ugam Devi Purohit  INKABLRMAL13 2019-06-18 12:40:45.049
# 11                     Shobha  INKABLRMAL10 2019-06-14 19:51:03.372
# 12                Banu Kumari  INKABLRMAL15 2019-06-19 11:32:38.311
# 13                  Rajaleela  INKABLRMAL17 2019-06-21 18:13:35.360
# 14                    Marappa  INKABLRMAL14 2019-06-18 18:06:15.321
# 15                 G D SHINDE  INKABLRMAL18 2019-06-21 18:17:50.446
# 16           Channappa Sajjan  INKABLRMAL16 2019-06-21 10:30:55.794
# 17                  Annapurna   INKABLRMAL4 2019-06-11 00:52:32.399
# 18                 N. Sainath  INKABLRMAL21 2019-06-22 06:36:16.341
# 19                Ramamani K   INKABLRMAL20 2019-06-22 05:58:32.773
# 20                Ramamani K   INKABLRMAL20 2019-06-22 05:36:21.119
# 21              Narayanappa V  INKABLRMAL19 2019-06-21 22:20:16.577
# 22                     Sheela  INKABLRMAL23 2019-06-23 05:21:42.281
# 23                       vbvb  INKABLRMAL26 2019-06-23 09:52:47.617
# 24                 Brunda G S  INKABLRMAL25 2019-06-23 09:49:30.272
# 25                Uma Devamma  INKABLRMAL24 2019-06-23 06:48:03.365
# 26                      Akash  INKABLRMAL22 2019-06-22 09:13:24.651
# 27                 Lakshmamma  INKABLRMAL27 2019-06-24 09:44:14.381
# 28                Kusalavan V  INKABLRMAL28 2019-06-24 18:55:58.970
# 29                 Dr Nagaraj  INKABLRMAL30 2019-06-27 08:02:43.224
# 30                 Mallegowda  INKABLRMAL32 2019-06-28 03:26:41.124
# 31  Sumangala V Pattanashetti  INKABLRMAL29 2019-06-26 20:23:00.154
# 32                 Naveen S G  INKABLRMAL34 2019-06-28 05:19:39.861
# 33                   K Selvam  INKABLRMAL35 2019-06-29 07:36:00.601
# 34             Srinivas reddy  INKABLRMAL37 2019-07-01 04:20:31.164
# 35                 Shanthamma  INKABLRMAL36 2019-06-29 12:34:50.275
# 36                 Lakshmamma  INKABLRMAL38 2019-07-01 10:03:32.795
# 37                  Vimalamma  INKABLRMAL39 2019-07-01 13:29:02.392
# 38                 Ramamani K  INKABLRMAL31 2019-06-27 03:00:00.000
# 39                   Siddaiha  INKABLRMAL40 2019-07-01 20:47:29.134
# 40               Aaisha begum  INKABLRMAL42 2019-07-03 06:52:19.453
# 41                   Siddaiha  INKABLRMAL40 2019-07-02 20:11:05.738
# 42                     Eramma  INKABLRMAL41 2019-07-02 10:07:24.856
# 43                 Umadevamma  INKABLRMAL44 2019-07-05 01:26:32.942
# 44          Mohammed Asifulla  INKABLRMAL43 2019-07-03 17:51:00.000
# 45                    Boramma  INKABLRMAL45 2019-07-05 04:04:19.101
# 46                      Padma  INKABLRMAL46 2019-07-05 08:35:58.236
# 47                  Gowtham S  INKABLRMAL49 2019-07-08 00:51:29.994
# 48                  Gowtham S  INKABLRMAL50 2019-07-08 00:51:29.994
# 49              Chandrasekhar  INKABLRMAL47 2019-07-06 04:36:51.440
# 50                Malle Gowda  INKABLRMAL33 2019-06-28 04:29:12.019
# 51             Somashekar M B  INKABLRMAL52 2019-07-08 14:22:01.989
# 52                 Saroja B P  INKABLRMAL51 2019-07-08 13:41:03.285
# 53              Praveen Kumar  INKABLRMAL48 2019-07-07 13:41:22.194
# 54                 Bili Gowda  INKABLRMAL53 2019-07-08 20:30:42.938
#
#             Discharge date   Age   Sex Hospital Chronic diseases  \
# 0  2019-06-05 06:30:20.480    67     F  Mallige             None
# 1  2019-06-10 07:50:30.440    67     F  Mallige             None
# 2  2019-06-11 06:31:19.852    57     F  Mallige             None
# 3  2019-06-13 07:30:11.659    40  None  Mallige             None
# 4  2019-06-14 06:31:11.989    40     M  Mallige             None
# 5  2019-06-12 07:11:36.401    73     F  Mallige             None
# 6  2019-06-15 10:10:50.022    35     M  Mallige             None
# 7  2019-06-13 08:26:18.420    83     M  Mallige             None
# 8  2019-06-18 04:30:52.656    58     M  Mallige             None
# 9  2019-06-18 05:55:18.120    63     F  Mallige             None
# 10 2019-06-19 09:35:40.760    49     F  Mallige             None
# 11 2019-06-17 06:00:28.366    61     F  Mallige             None
# 12 2019-06-20 06:28:46.720    22     F  Mallige             None
# 13 2019-06-22 07:08:16.658    70     F  Mallige             None
# 14 2019-06-20 10:43:51.571    55     M  Mallige             None
# 15 2019-06-22 07:31:43.921    83     M  Mallige             None
# 16 2019-06-22 10:43:36.668    74     M  Mallige             None
# 17 2019-06-18 10:39:37.261    52     F  Mallige             None
# 18 2019-06-23 04:44:04.369    67     M  Mallige             None
# 19 2019-06-24 11:18:56.598    53     F  Mallige             None
# 20 2019-06-22 05:57:32.808    53     F  Mallige             None
# 21 2019-06-23 10:51:46.649  None     M  Mallige             None
# 22 2019-06-24 06:46:24.906    57     F  Mallige             None
# 23 2019-06-23 14:31:50.901  None  None  Mallige             None
# 24 2019-06-24 08:31:50.011    29     F  Mallige             None
# 25 2019-06-25 04:50:44.799    77     F  Mallige             None
# 26 2019-06-24 06:40:57.995    22     M  Mallige             None
# 27 2019-06-25 06:54:33.175    73     F  Mallige             None
# 28 2019-06-25 10:08:31.410    75     M  Mallige             None
# 29 2019-06-28 06:47:35.439    82     M  Mallige    Heart failure
# 30 2019-06-28 06:14:12.429    76     M  Mallige             None
# 31 2019-06-29 06:45:50.310    61     F  Mallige             None
# 32 2019-06-29 08:15:15.032    38     M  Mallige             None
# 33 2019-06-30 06:12:19.103    64     M  Mallige             None
# 34 2019-07-02 06:02:16.880    68  None  Mallige             None
# 35 2019-07-01 06:39:08.315    58     F  Mallige             None
# 36 2019-07-02 06:01:55.336    72     F  Mallige             None
# 37 2019-07-03 14:46:49.031    68     F  Mallige             None
# 38                     NaT    53     F  Mallige             None
# 39 2019-07-02 06:02:06.566    68     M  Mallige             None
# 40 2019-07-04 04:30:36.813    27     F  Mallige             None
# 41 2019-07-03 12:46:15.341    68     M  Mallige             None
# 42 2019-07-04 06:00:01.559    75  None  Mallige             None
# 43 2019-07-05 07:06:24.661    77     F  Mallige             None
# 44 2019-07-05 08:00:51.758    61     M  Mallige             None
# 45 2019-07-06 06:28:30.910    78     F  Mallige             None
# 46 2019-07-06 06:54:48.138    78     F  Mallige             None
# 47 2019-07-08 01:05:14.631    20     M  Mallige             None
# 48 2019-07-08 07:16:31.773    20     M  Mallige             None
# 49 2019-07-06 06:00:04.888    79     M  Mallige             None
# 50                     NaT    76     M  Mallige             None
# 51                     NaT    66     M  Mallige             None
# 52                     NaT    67     F  Mallige             None
# 53                     NaT    34     M  Mallige             None
# 54                     NaT    65     M  Mallige             None
#
#            Immune status Operative status  \
# 0                   None    Non-Operative
# 1                   None             None
# 2                   None             None
# 3                   None    Non-Operative
# 4                   None   Post-Operative
# 5                   None    Non-Operative
# 6                   None    Non-Operative
# 7                   None    Non-Operative
# 8                   None   Post-Operative
# 9                   None    Non-Operative
# 10                  None   Post-Operative
# 11                  None   Post-Operative
# 12                  None   Post-Operative
# 13  Metastatic Carcinoma   Post-Operative
# 14                  None    Non-Operative
# 15                  None    Non-Operative
# 16                  None    Non-Operative
# 17                  None    Non-Operative
# 18                  None    Non-Operative
# 19                  None   Post-Operative
# 20                  None   Post-Operative
# 21                  None    Non-Operative
# 22                  None    Non-Operative
# 23                  None    Non-Operative
# 24                  None    Non-Operative
# 25                  None    Non-Operative
# 26                  None    Non-Operative
# 27                  None   Post-Operative
# 28  Metastatic Carcinoma   Post-Operative
# 29                  None    Non-Operative
# 30                  None    Non-Operative
# 31                  None   Post-Operative
# 32                  None    Non-Operative
# 33                  None   Post-Operative
# 34                  None    Non-Operative
# 35                  None    Non-Operative
# 36                  None   Post-Operative
# 37                  None    Non-Operative
# 38                  None    Non-Operative
# 39                  None    Non-Operative
# 40                  None    Non-Operative
# 41                  None    Non-Operative
# 42                  None    Non-Operative
# 43                  None    Non-Operative
# 44                  None    Non-Operative
# 45                  None    Non-Operative
# 46                  None    Non-Operative
# 47                  None    Non-Operative
# 48                  None    Non-Operative
# 49                  None    Non-Operative
# 50                  None    Non-Operative
# 51                  None    Non-Operative
# 52                  None   Post-Operative
# 53                  None    Non-Operative
# 54                  None    Non-Operative
#
#                                 Dishcarge disposition  LOS  Foley days  \
# 0                            Discharged to ward/floor    1           0
# 1                            Discharged to ward/floor    2           0
# 2                            Discharged to ward/floor    3           0
# 3                            Discharged to ward/floor    3           0
# 4                            Discharged to ward/floor    2           0
# 5                            Discharged to ward/floor    1           0
# 6                      Discharged to another facility    2           0
# 7                            Discharged to ward/floor    2           0
# 8                            Discharged to ward/floor    1           0
# 9                            Discharged to ward/floor    3           3
# 10                           Discharged to ward/floor    2           2
# 11  Discharged to home/self care as per medical ad...    3           3
# 12                           Discharged to ward/floor    2           2
# 13                           Discharged to ward/floor    2           0
# 14                           Discharged to ward/floor    3           0
# 15                           Discharged to ward/floor    2           0
# 16                           Discharged to ward/floor    2           2
# 17                           Discharged to ward/floor    8           8
# 18                           Discharged to ward/floor    2           0
# 19                           Discharged to ward/floor    3           3
# 20                           Discharged to ward/floor    0           0
# 21                                              Death    2           2
# 22                           Discharged to ward/floor    2           0
# 23                           Discharged to ward/floor    0           0
# 24                           Discharged to ward/floor    2           2
# 25  Discharged to home/self care as per medical ad...    3           0
# 26                           Discharged to ward/floor    3           0
# 27                           Discharged to ward/floor    2           2
# 28                           Discharged to ward/floor    1           1
# 29                           Discharged to ward/floor    2           0
# 30  Discharged to home/self care as per medical ad...    0           0
# 31                           Discharged to ward/floor    3           3
# 32  Discharged to home/self care as per medical ad...    2           0
# 33                           Discharged to ward/floor    2           2
# 34                           Discharged to ward/floor    2           0
# 35                           Discharged to ward/floor    3           0
# 36                           Discharged to ward/floor    2           2
# 37  Discharged to home/self care AGAINST medical a...    3           3
# 38                                               None   13           0
# 39                           Discharged to ward/floor    1           0
# 40                           Discharged to ward/floor    2           0
# 41                                              Death    1           0
# 42                           Discharged to ward/floor    3           0
# 43                           Discharged to ward/floor    1           0
# 44                           Discharged to ward/floor    3           0
# 45                           Discharged to ward/floor    2           0
# 46                           Discharged to ward/floor    2           0
# 47                           Discharged to ward/floor    0           0
# 48                           Discharged to ward/floor    1           0
# 49                           Discharged to ward/floor    1           0
# 50                                               None   13          13
# 51                                               None    2           0
# 52                                               None    2           0
# 53                                               None    3           3
# 54                                               None    1           1
#
#     CVC days  Vent days  TWA Glucose     MAP  Temperature     HR    RR   SpO2  \
# 0          0          0          NaN  104.67        98.70   67.0  18.0   96.0
# 1          0          0        321.0   89.67        98.60  130.0  23.0   95.0
# 2          0          0        267.8  103.33        98.60  112.0  23.0   90.0
# 3          3          0          NaN   79.00        98.70  104.0  22.0   98.0
# 4          0          0          NaN     NaN        98.20   88.0  27.0   99.0
# 5          0          0          NaN   79.00        98.60   69.0  21.0   99.0
# 6          0          0          NaN  139.67        98.50   88.0  23.0   98.0
# 7          0          0          NaN  120.00        98.40   74.0  23.0   97.0
# 8          0          0          NaN   94.67        98.60   76.0  22.0   96.0
# 9          0          0        246.3  129.33        98.50   82.0  31.0   95.0
# 10         0          0          NaN   83.33        98.50   75.0  14.0  100.0
# 11         0          0          NaN   83.33        98.60   86.0  24.0   97.0
# 12         2          0          NaN   80.67        98.60   91.0  22.0   99.0
# 13         0          0        166.8   86.33        98.40   68.0  13.0   96.0
# 14         0          0        129.3   98.67        98.50  105.0  28.0   98.0
# 15         0          0         97.0   85.67        98.40   87.0  23.0  100.0
# 16         0          0        208.0   89.33        98.60   93.0  18.0   96.0
# 17         8          4        186.0   92.33        98.70  104.0  28.0   95.0
# 18         0          0          NaN  109.33        98.50   95.0  44.0   88.0
# 19         0          1        102.0   72.67        98.50   97.0  23.0   96.0
# 20         0          0          NaN     NaN          NaN    NaN   NaN    NaN
# 21         0          1        127.2  103.67        98.40  100.0   8.0   88.0
# 22         0          0        102.2  125.00        98.50   97.0  24.0   94.0
# 23         0          0          NaN     NaN          NaN    NaN   NaN    NaN
# 24         0          0          NaN   74.00        98.50   74.0  12.0   96.0
# 25         0          0         82.0   50.67        98.50   86.0  31.0   95.0
# 26         0          0          NaN   91.00        98.50   99.0  22.0   98.0
# 27         0          0        228.0     NaN        98.70  120.0  30.0   99.0
# 28         0          0        103.0  105.67        98.40   77.0  11.0   96.0
# 29         0          0        229.0  109.00        98.30   93.0  18.0   98.0
# 30         0          0          NaN     NaN          NaN    NaN   NaN    NaN
# 31         0          0        195.0  119.67        98.60   71.0  23.0  100.0
# 32         0          0          NaN  105.33        98.30   76.0  18.0   95.0
# 33         0          0        308.2  106.67        98.50   71.0  16.0  100.0
# 34         0          0          NaN   85.33        98.20  114.0  14.0   87.0
# 35         0          0          NaN     NaN        98.70   91.0  17.0   95.0
# 36         0          0          NaN  115.00        98.70   83.0  18.0  100.0
# 37         0          0          NaN  116.00        98.40   77.0  19.0   88.0
# 38         0          7        109.3  110.00        98.60  110.0  26.0   94.0
# 39         0          0          NaN   84.33        98.40  118.0  25.0   90.0
# 40         0          0        215.0   88.67        98.56   97.0  12.0   97.0
# 41         0          0        264.0   63.33        98.40  123.0  42.0   96.0
# 42         0          0        263.0  130.33        98.50   83.0  22.0   91.0
# 43         0          0        128.0   64.33        98.60   88.0  22.0   89.0
# 44         0          0          NaN   75.00        99.40   84.0  15.0   96.0
# 45         0          0          NaN   82.67        98.60   42.0  23.0   99.0
# 46         0          0          NaN   92.00        99.00   92.0  22.0   93.0
# 47         0          0          NaN     NaN          NaN    NaN   NaN    NaN
# 48         0          0          NaN   88.67        98.60   98.0  21.0   97.0
# 49         0          0          NaN   84.33        98.60   64.0  21.0   93.0
# 50         0          7          NaN   73.00        98.30  108.0  20.0   99.0
# 51         0          0        201.0   92.00        98.60   67.0  17.0   99.0
# 52         0          0        308.0   76.33        98.60   83.0  36.0  100.0
# 53         3          0        136.0   77.67        98.50   79.0  11.0   93.0
# 54         0          0          NaN   66.67        98.60  100.0  27.0   94.0
#
#      FiO2    E    V    M    pH   PaO2  PaCO2  Bicarb    Hb      TLC  \
# 0    32.0  4.0  5.0  6.0  7.38   63.0   34.9    15.5  16.2   9100.0
# 1    28.0  4.0  5.0  6.0  7.60   65.0   22.8    22.3   NaN      NaN
# 2    24.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 3    32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  11.6  12800.0
# 4    36.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  14.3   8980.0
# 5    21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  12.1   8970.0
# 6    21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 7    21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  11.5  14930.0
# 8    32.0  NaN  NaN  NaN   NaN    NaN    NaN     NaN   NaN      NaN
# 9    36.0  4.0  5.0  6.0  7.32  137.0   28.2    15.9   NaN      NaN
# 10   32.0  3.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 11   23.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 12   36.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 13   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 14   32.0  3.0  4.0  5.0   NaN    NaN    NaN     NaN   NaN      NaN
# 15   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 16   21.0  3.0  2.0  4.0   NaN    NaN    NaN     NaN   NaN      NaN
# 17   34.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  12.0  24500.0
# 18  100.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  17.4  10040.0
# 19   40.0  NaN  NaN  NaN   NaN    NaN    NaN     NaN   NaN      NaN
# 20    NaN  NaN  NaN  NaN   NaN    NaN    NaN     NaN   9.6  10560.0
# 21  100.0  1.0  0.0  1.0  7.22  284.0   37.2    33.0   9.2      NaN
# 22   32.0  4.0  5.0  6.0  7.45   51.0   25.1    17.4  12.0  10740.0
# 23    NaN  NaN  NaN  NaN   NaN    NaN    NaN     NaN   NaN      NaN
# 24   21.0  NaN  NaN  NaN   NaN    NaN    NaN     NaN  12.4  16060.0
# 25   32.0  2.0  1.0  4.0   NaN    NaN    NaN     NaN  13.7  12540.0
# 26   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  21.8   7420.0
# 27   36.0  4.0  4.0  6.0   NaN    NaN    NaN     NaN   9.0  18000.0
# 28   36.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  12.7  10830.0
# 29   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  13.8   5810.0
# 30    NaN  NaN  NaN  NaN   NaN    NaN    NaN     NaN   NaN      NaN
# 31   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  11.1  19410.0
# 32   21.0  4.0  4.0  6.0  7.40   82.0   36.3    21.9  13.9   6970.0
# 33   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 34   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   9.2  14470.0
# 35   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 36   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 37   28.0  4.0  4.0  6.0   NaN    NaN    NaN     NaN  10.3  11960.0
# 38   50.0  4.0  2.0  5.0   NaN    NaN    NaN     NaN   8.8   9500.0
# 39   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 40   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  11.7   8600.0
# 41   52.0  NaN  NaN  NaN   NaN    NaN    NaN     NaN   9.7  54000.0
# 42   32.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  10.3  11960.0
# 43   36.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  12.5   8700.0
# 44   26.0  4.0  5.0  6.0  7.46   45.0   35.6    24.0  13.4  10300.0
# 45   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   6.9   9880.0
# 46   36.0  4.0  5.0  6.0  7.37   37.0   26.0    14.8   NaN      NaN
# 47    NaN  NaN  NaN  NaN   NaN    NaN    NaN     NaN   NaN      NaN
# 48   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 49   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   NaN      NaN
# 50   60.0  4.0  0.0  6.0  7.08  339.0   28.7     8.1   NaN      NaN
# 51   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   4.0   5460.0
# 52   40.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN   8.1      NaN
# 53   21.0  4.0  5.0  6.0   NaN    NaN    NaN     NaN  11.4   9690.0
# 54   21.0  4.0  4.0  6.0  7.48   74.0   22.3    16.6  11.3  13000.0
#
#     Platelets    K     Na  Creatinine    BUN  T.Bili  Urine output  Lactate  \
# 0   308000.00  4.1  143.0        0.67   22.0    0.49           NaN      3.2
# 1         NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 2         NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 3   322000.00  5.2  137.0        0.82   20.0    0.35           NaN      NaN
# 4   243000.00  4.0  138.0        1.03   32.0    0.77           NaN      NaN
# 5   299000.00  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 6         NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 7   383000.00  4.1  127.0        0.75   21.0     NaN           NaN      NaN
# 8         NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 9         NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 10        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 11        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 12        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 13        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 14        NaN  3.9  126.0        0.53   14.0     NaN           NaN      NaN
# 15        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 16        NaN  4.5  133.0        6.10  119.0     NaN           NaN      NaN
# 17  321000.00  3.3  135.0        0.69   24.0     NaN           NaN      NaN
# 18  213000.00  3.7  137.0        1.28   32.0     NaN           NaN      NaN
# 19        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 20  207000.00  4.8  125.0        6.33  116.0     NaN           NaN      NaN
# 21  323000.00  5.4  129.0        5.88   90.0     NaN           NaN      1.8
# 22  299000.00  3.8  135.0        0.75   40.0     NaN           NaN      NaN
# 23        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 24  198000.00  3.7  134.0        0.58   33.0    0.58           NaN      NaN
# 25  260000.00  3.4  135.0        0.65   26.0    0.60           NaN      NaN
# 26   10000.00  5.3  135.0        1.25   23.0    0.82           NaN      NaN
# 27  198000.00  4.2  129.0        2.37  131.0    0.52           NaN      NaN
# 28  199000.00  4.7  136.0        0.95   27.0     NaN           NaN      NaN
# 29  180000.00  3.5  126.0         NaN    NaN     NaN           NaN      NaN
# 30        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 31  217000.00  4.1  133.0         NaN    NaN     NaN           NaN      NaN
# 32  194000.00  4.5  140.0        0.83   16.0    0.42           NaN      1.2
# 33        NaN  4.6  123.0        1.51   52.0     NaN           NaN      NaN
# 34  400400.00  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 35        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 36        NaN  4.4  133.0        1.51   70.0     NaN           NaN      NaN
# 37  424000.00  4.5  106.0        1.76   46.0    0.20           NaN      NaN
# 38  388000.00  3.6  136.0        6.12   85.0    0.50           NaN      NaN
# 39        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 40  286000.00  4.2  130.0        0.72   29.0    0.32           NaN      NaN
# 41   38000.00  3.6  134.0        2.74   89.0    1.97           NaN      NaN
# 42  424000.00  4.5  106.0        1.76   46.0    0.20           NaN      NaN
# 43  611000.00  5.0  134.0        0.36   11.0    0.26           NaN      NaN
# 44  264000.00  3.8  133.0        0.94   25.0    0.68           NaN      1.2
# 45       1.97  5.6  133.0        8.89  245.0     NaN           NaN      NaN
# 46        NaN  NaN    NaN         NaN    NaN     NaN           NaN      5.3
# 47        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 48        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 49        NaN  NaN    NaN         NaN    NaN     NaN           NaN      NaN
# 50        NaN  4.1  130.0        2.55   60.0    0.16           NaN      1.5
# 51  130000.00  4.4  140.0        1.13  112.0    1.20           NaN      NaN
# 52        NaN  5.2  133.0         NaN    NaN     NaN           NaN      NaN
# 53  337000.00  3.4  137.0        0.82   30.0    0.47           NaN      NaN
# 54   33000.00  3.8  135.0        1.67   59.0    0.68           NaN      2.1
#
#      INR
# 0   0.82
# 1    NaN
# 2    NaN
# 3    NaN
# 4   0.88
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24  1.03
# 25   NaN
# 26  1.58
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51  1.73
# 52  1.24
# 53  1.07
# 54   NaN

# %%
def getAuditLabs(pat_obj):
    attributes = getAttributes([pat_obj])
    pH = []; PaO2 = []; PaCO2 = []; HCO3 = []; Hb = []; TLC = []; Platelets = [];K = [];Na = []
    Cr = []; Ur = []; Bili = []; uo = []; Lactate = []; INR = [];
    for i in range(len(attributes)):
        pH.append(attributes[i][0].get('pH'))
        PaCO2.append(attributes[i][0].get('PaCO2'))
        PaO2.append(attributes[i][0].get('PaO2'))
        HCO3.append(attributes[i][0].get('Bicarb'))
        Hb.append(attributes[i][0].get('Hb'))
        TLC.append(attributes[i][0].get('Total count'))
        Platelets.append(attributes[i][0].get('Platelets'))
        K.append(attributes[i][0].get('K'))
        Na.append(attributes[i][0].get('Na'))
        Cr.append(attributes[i][0].get('Creatinine'))
        Ur.append(attributes[i][0].get('Urea'))
        Bili.append(attributes[i][0].get('Bili(Total)'))
        uo.append(attributes[i][0].get('Urine output'))
        Lactate.append(attributes[i][0].get('Lactic'))
        INR.append(attributes[i][0].get('INR'))
    return (pH, PaO2, PaCO2, HCO3, Hb, TLC, Platelets, K, Na, Cr, Ur, Bili, uo, Lactate, INR)

# %%
def removeNones(pat_obj):
    labs = getAuditLabs(pat_obj)
    clean_labs = []
    for i in range(len(labs)):
        clean_labs.append((pd.to_numeric([x for x in labs[i] if x is not None])))
    return clean_labs

# %%
def sortedAudits(pat_obj):
    cl = removeNones(pat_obj)
    for i in cl:
        if (i.size>0):
            if (i.sort()):
                i.sort()
    return cl

# %%
def create_table():
    c.execute('create table if not exists auditdb(Name text, CPMRN text, Admit_date text, Discharge_date text, Age integer, Sex text, Hospital text, Chronic_diseases text, Immune_status text, Operative_status text, Discharge_disposition text, LOS integer, Foley_days integer, CVC_days integer, Vent_days integer, TWA_Glucose real, MAP real, Temperature real, HR integer, RR integer, SpO2 real, FiO2 real, E integer, V integer, M integer, pH real, PaO2 real, PaCO2 real, Bicarb real, Hb real, TLC real, Platelets real, K real, Na real, Creatinine real, BUN real, T_Bili real, Urine_output real, Lactate real, INR real)')

# %%
def data_entry():
    c.execute("insert into stuffToPlot values()")

# %%
create_table()

# %%
final_df.to_csv("Mallige_JuneJuly.csv")

# %%
calculated_var_df = pd.DataFrame(data)

# %%
# Getting all vitals as a list of lists
all_vit_list = []
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    all_vit_list.append(getD1Array(pat_obj))

# %%
all_vent = []
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    all_vent.append(getAuditVent(pat_obj))
all_vent = np.array(all_vent)

# %%
all_twa = []
for x in range(len(all_pats)):
    pat_obj = all_pats[x]
    all_twa.append(getAuditTwa(pat_obj))
all_twa = np.array(all_twa)

# %%
# Getting all cvc day values
c_list = []
for j in range(len(all_pats)):
    c_list.append(getAuditCvc(all_pats[j]))

# Changing list to array
c_array = []
for i in range(len(c_list)):
    if (len(c_list[i])>0):
        c_array.append(c_list[i][0])
    else:
        c_array.append(0)
c_array = np.array(c_array)

# %%
f_list = []
for j in range(len(all_pats)):
    f_list.append(getAuditFoley(all_pats[j]))

# Changing list to array
f_array = []
for y in range(len(f_list)):
    if (len(f_list[y])>0):
        f_array.append(f_list[y][0])
    else:
        f_array.append(0)
f_array = np.array(f_array)

los_array = np.array(los_list)

# Rectifying cases where foley days > los
for z in range(len(f_array)):
    if((f_array[z] > los_array[z])):
        f_array[z] = los_array[z]

# %%
getFirstDayLabs(pat_obj)
# Out:
# [nan, nan, nan, nan, 9, 18000, nan, 4.2, 129, 2.37, 131, 0.52, nan, nan, nan]

# %%
pat_obj['orders']['active']
# Out:
# {'medications': [{'_id': ObjectId('5d23abd1b7a928eb57bd5590'),
#    'frequency': {'fType': 'every',
#     'hours': 24,
#     'mins': None,
#     'timeOfDay': None},
#    'type': 'medications',
#    'signed': 'Dr. Sharath Patel',
#    'state': 'green',
#    'category': 'active',
#    'name': 'Pantoprazole',
#    'quantity': 40,
#    'unit': 'mg',
#    'route': 'IV',
#    'numberOfDoses': None,
#    'urgency': None,
#    'sosReason': None,
#    'form': None,
#    'instructions': None,
#    'pta': False,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 8, 20, 36, 32, 314000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 3, 7, 57, 307000)},
#   {'_id': ObjectId('5d23abfcb7a9288f48bd5592'),
#    'frequency': {'fType': 'every',
#     'hours': 8,
#     'mins': None,
#     'timeOfDay': None},
#    'type': 'medications',
#    'signed': 'Dr. Sharath Patel',
#    'state': 'green',
#    'category': 'active',
#    'name': 'Actrapid',
#    'quantity': 6,
#    'unit': 'IU',
#    'route': 'SC',
#    'numberOfDoses': None,
#    'urgency': None,
#    'sosReason': None,
#    'form': None,
#    'instructions': 'as per slidiing scale',
#    'pta': False,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 8, 20, 37, 15, 729000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 3, 7, 58, 36000)},
#   {'_id': ObjectId('5d23acaab7a9281d58bd55a3'),
#    'frequency': {'fType': 'every',
#     'hours': 24,
#     'mins': None,
#     'timeOfDay': None},
#    'type': 'medications',
#    'signed': 'Dr. Sharath Patel',
#    'state': 'green',
#    'category': 'active',
#    'name': 'Aspirin + atorvastatin',
#    'quantity': 75,
#    'unit': 'mg',
#    'route': 'PO',
#    'numberOfDoses': None,
#    'urgency': None,
#    'sosReason': None,
#    'form': None,
#    'instructions': None,
#    'pta': False,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 8, 20, 40, 9, 594000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 3, 8, 0, 171000)},
#   {'_id': ObjectId('5d23acdab7a9281096bd55a5'),
#    'frequency': {'fType': 'every',
#     'hours': 24,
#     'mins': None,
#     'timeOfDay': None},
#    'type': 'medications',
#    'signed': 'Dr. Sharath Patel',
#    'state': 'green',
#    'category': 'active',
#    'name': 'Fenofibrate',
#    'quantity': 160,
#    'unit': 'mg',
#    'route': 'PO',
#    'numberOfDoses': None,
#    'urgency': None,
#    'sosReason': None,
#    'form': None,
#    'instructions': None,
#    'pta': False,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 8, 20, 40, 58, 47000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 3, 8, 0, 923000)},
#   {'_id': ObjectId('5d23acf7b7a928bf99bd55a7'),
#    'frequency': {'fType': 'every',
#     'hours': 24,
#     'mins': None,
#     'timeOfDay': None},
#    'type': 'medications',
#    'signed': 'Dr. Sharath Patel',
#    'state': 'green',
#    'category': 'active',
#    'name': 'Telmisartan',
#    'quantity': 40,
#    'unit': 'milligrams',
#    'route': 'PO',
#    'numberOfDoses': None,
#    'urgency': None,
#    'sosReason': None,
#    'form': None,
#    'instructions': None,
#    'pta': False,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 8, 20, 41, 26, 978000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 3, 8, 1, 676000)}],
#  'labs': [],
#  'diets': [{'_id': ObjectId('5d242f25b7a9282c64be3f03'),
#    'frequency': {'fType': None, 'hours': None, 'mins': None},
#    'type': 'diets',
#    'signed': 'Dt.  Shobha',
#    'state': 'red',
#    'category': 'active',
#    'name': 'Oral-semi solid',
#    'instructions': 'oral semisolid-soft diet as tolerated',
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 9, 6, 7, 23, 43000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 6, 7, 33, 859000)}],
#  'communications': [],
#  'bloods': [],
#  'procedures': [{'_id': ObjectId('5d240521b7a9288ab5bda911'),
#    'type': 'procedures',
#    'signed': 'Dr. Lokesh M B',
#    'state': 'green',
#    'category': 'active',
#    'name': None,
#    'pType': 'PIV',
#    'site': 'hand',
#    'laterality': 'Right',
#    'instructions': None,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 9, 2, 57, 37, 280000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 5, 38, 17, 901000)},
#   {'_id': ObjectId('5d240529b7a92846debda913'),
#    'type': 'procedures',
#    'signed': 'Dr. Lokesh M B',
#    'state': 'green',
#    'category': 'active',
#    'name': None,
#    'pType': 'Foley',
#    'site': 'Urethra',
#    'laterality': 'NA',
#    'instructions': None,
#    'additionalInformation': None,
#    'startTime': datetime.datetime(2019, 7, 9, 2, 57, 45, 655000),
#    'updatedAt': datetime.datetime(2019, 7, 9, 5, 38, 18, 660000)}]}

# %%
for i in range(len(all_pats)):
    inact_ords = all_pats[i]['orders']['inactive']
    if (inact_ords.get('labs')):
        for j in range(len(inact_ords.get('labs'))):
            if (inact_ords.get('labs')[k].get('discipline') == 'Microbiology'):
                print(inact_ords.get('labs')[k])

# %%
# Calculating night time orders
tot_count = 0; night_count = 0
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    for idx, item in pat_obj['orders'].items():
        for jdx, sub_item in item.items():
            if (len(sub_item)>0):
                for j in range(len(sub_item)):
                    tot_count += 1
                    order_dt = (sub_item[j]['startTime'])
                    order_dt = (assertAndChange(order_dt))
                    pm = order_dt.replace(hour=20, minute=0, second=0, microsecond=0)
                    am = order_dt.replace(hour=8, minute=0, second=0, microsecond=0)
                    if ((order_dt < am) | (order_dt > pm)):
                        night_count += 1
print(tot_count)
print(night_count)
# Out:
# 603
# 273

# %%
tot_count = 0; abn_count = 0
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    vit = getAuditVitals(pat_obj)
    for j in range(len(vit)):
        for k in range(2, 7):
            tot_count += 1
            if((i==18)&(j==3)&(k==5)):
                continue
            if ((abs(pd.to_numeric(vit[j][k]) - vital_normals[k][0]))>vital_normals[k][1]):
                abn_count += 1
print(tot_count)
print(abn_count)
# Out:
# 9545
# 240

# %% [markdown]
# ## ---------------

# %%
vital_normals = {
    2: [100, 34],
    3: [98.5, 2.4],
    4: [80, 39],
    5: [18, 11], 
    6: [100, 19]
}

# %%
pat_obj.get('documents')[0].get('tags')
# Out:
# ['Blood', 'Glucose']

# %%
labs = []
for i in range(len(all_pats[0])):
    doc_obj = all_pats[i].get('documents')
    if ((doc_obj == None)|(doc_obj == [])):
        continue
    for j in range(len(doc_obj)):
        labs.append(doc_obj[j].get('tags'))

# %%
for i in range(len(labs)):
    if(labs[i][0] == 'Urine'):
        print(labs[i])
# Out:
# ['Urine', 'Routine']
# ['Urine', 'Routine']

# %%
labs
# Out:
# [['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Documents', 'Admission notes', None, None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Documents', 'Admission notes', None, None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', None, None],
#  ['Blood', 'Coagulation', 'INR', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Chemistry', 'LFT', None],
#  ['Blood', 'Cardiac', 'Troponin', None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Blood', 'Glucose', None, None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Procedures', 'Cardiac', 'ECG', None],
#  ['Blood', 'Glucose', None, None],
#  ['Blood', 'Glucose', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', None, None, None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Imaging', 'Radiology', 'Xrays', None],
#  ['Imaging', 'Radiology', 'Xrays', None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Imaging', 'Radiology', 'Xrays', None],
#  ['Documents', None, None, None],
#  ['Blood', 'Glucose', None, None],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Chemistry', 'LFT', None],
#  ['Blood', 'Coagulation', 'PT', None],
#  ['Blood', 'Coagulation', 'aPTT', None],
#  ['Blood', 'Chemistry', 'Electrolytes', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', None, None, None],
#  ['Imaging', 'Radiology', 'Xrays', None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Coagulation', 'INR', None],
#  ['Blood', 'Coagulation', 'aPTT', None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Surgery Notes', None, None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Coagulation', 'INR', None],
#  ['Blood', 'Chemistry', 'RFT', None],
#  ['Blood', 'Chemistry', 'LFT', None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Progress notes', None, None],
#  ['Documents', 'Surgery Notes', None, None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Blood', 'Hematology', 'CBC', None],
#  ['Blood', 'Chemistry', 'Electrolytes', None],
#  ['Blood', 'Glucose', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Blood', 'Blood Gases', 'ABG', None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Blood', 'Glucose', None, None],
#  ['Documents', 'Nursing notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Admission notes', None, None],
#  ['Documents', 'Pharmacology notes', None, None],
#  ['Documents', 'Procedure notes', None, None],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Event notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Body Fluids', 'Cytology'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'Electrolytes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Event notes'],
#  ['Documents', 'Procedure notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'aPTT'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Imaging', 'Radiology', 'Ultrasound'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Procedures', 'Cardiac', 'ECG'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Glucose'],
#  ['Urine', 'Routine'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Coagulation', 'aPTT'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Cardiac', 'CKMB'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Coagulation', 'PT'],
#  ['Blood', 'Coagulation', 'aPTT'],
#  ['Urine', 'Routine'],
#  ['Procedures', 'Cardiac', 'ECG'],
#  ['Procedures', 'Cardiac', 'ECG'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Coagulation', 'aPTT'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Chemistry', 'Electrolytes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'Admission notes'],
#  ['Imaging', 'Cardiac', 'Echo'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Procedure notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Cardiac', 'CKMB'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Hematology', 'CBC', 'ESR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'Electrolytes'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'PT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'Electrolytes'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Coagulation', 'INR'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Event notes'],
#  ['Documents', 'OPD notes'],
#  ['Documents', 'Surgery Notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Glucose'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Documents', 'Pharmacology notes'],
#  ['Procedures', 'Cardiac', 'ECG'],
#  ['Procedures', 'Cardiac', 'ECG'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Endocrine'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'Progress notes'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Imaging', 'Radiology', 'CT'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Imaging', 'Radiology', 'Xrays'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Glucose'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Pharmacology notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Documents', 'Admission notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Cardiac', 'CKMB'],
#  ['Blood', 'Coagulation', 'PT'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Blood', 'Blood Gases', 'ABG'],
#  ['Blood', 'Glucose'],
#  ['Documents', 'Pharmacology notes'],
#  ['Blood', 'Hematology', 'CBC'],
#  ['Blood', 'Chemistry', 'RFT'],
#  ['Blood', 'Cardiac', 'Troponin'],
#  ['Blood', 'Chemistry', 'LFT'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes'],
#  ['Documents', 'Progress notes']]

# %%
tags = []
for i in range(len(labs)):
    if(len(labs[i])>2):
        tags.append(labs[i][2])

# %%
def unique(list1):
    ul = ['ECG','ABG','CBC','INR','RFT','LFT','Troponin','Xrays','PT','aPTT','Electrolytes','Ultrasound','CT','CKMB','Echo']
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x)
        if x in unique_list:
            
            continue
    return unique_list

# %%
from collections import Counter
Counter(tags)
# Out:
# Counter({'ECG': 14,
#          None: 45,
#          'ABG': 20,
#          'CBC': 57,
#          'INR': 14,
#          'RFT': 63,
#          'LFT': 20,
#          'Troponin': 7,
#          'Xrays': 11,
#          'PT': 4,
#          'aPTT': 6,
#          'Electrolytes': 6,
#          'Ultrasound': 1,
#          'CT': 9,
#          'CKMB': 3,
#          'Echo': 1})

# %%
for name, ls in (pat_obj[0]['orders']['active']).items():
    print(name)
# Out:
# medications
# labs
# diets
# communications
# bloods
# procedures

# %%
# Calculating night time orders
medications = 0; labs = 0; diets = 0;communications = 0; bloods = 0; procedures = 0;
tot_count = 0; night_count = 0
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    for idx, item in pat_obj['orders'].items():
        for jdx, sub_item in item.items():
            if (len(sub_item)>0):
                for j in range(len(sub_item)):
                    tot_count += 1
                    order_dt = (sub_item[j]['startTime'])
                    order_dt = assertAndChange(order_dt)
                    pm = order_dt.replace(hour=20, minute=0, second=0, microsecond=0)
                    am = order_dt.replace(hour=8, minute=0, second=0, microsecond=0)
                    if ((order_dt < am) | (order_dt > pm)):
                        night_count += 1
                        if (jdx == 'medications'):
                            medications += 1
                        elif (jdx == 'labs'):
                            labs += 1
                        elif (jdx == 'diets'):
                            diets += 1
                        elif (jdx == 'communications'):
                            communications += 1
                        elif (jdx == 'bloods'):
                            bloods += 1
                        elif (jdx == 'procedures'):
                            procedures += 1
print('Total orders: ' + str(tot_count))
print('Night time orders: ' + str(night_count))
print(medications + labs + diets + communications + bloods + procedures)
print('Number of med orders: ' + str(medications))
print('Number of lab orders: ' + str(labs))
print('Number of diet orders: ' + str(diets))
print('Number of communication orders: ' + str(communications))
print('Number of blood orders: ' + str(bloods))
print('Number of procedure orders: ' + str(procedures))
# Out:
# Total orders: 768
# Night time orders: 326
# 326
# Number of med orders: 239
# Number of lab orders: 2
# Number of diet orders: 56
# Number of communication orders: 0
# Number of blood orders: 5
# Number of procedure orders: 24

# %%
count = 0; obj_count = 0; list_of_objs = []
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    if (pat_obj.get('notes') == None):
        continue
    if (len(pat_obj.get('notes')) >2):
        for name, value in pat_obj['notes'].items():
            count += 1
            for name, obj in (pat_obj['notes']['codeSheet'][0]).items():
                list_of_objs.append(obj) 
        
        #final_note = pat_obj['notes']['finalNotes'][j]
        #for k in range(len(final_note['content'])):
            #print(final_note['content'][k]['noteType'])

# %%
list_of_objs[2]
# Out:
# {'timeTakenToAchieveAdvancedAirway': 'LESS than 10 mins',
#  'immediatePrecipitatingCause': 'Respiratory depression',
#  'timeToFirstDoseOfEpinephrine': 'Less than 3 mins',
#  'resuscitationAttempted': 'Yes combination interventions',
#  'initialResuscitationCondition': 'Apnea',
#  'timeOfCPRNeededToAchieveROSC': 'Yes first 10 minutes of CPR',
#  'initialRhythm': 'Pulseless electrical activity',
#  'ROSCAchievedLength': '>20 min but ≤24 hrs (intermediate)',
#  'timeCPRTeamCalled': '20:50',
#  'hospitalDischargeOrTransfer': None,
#  'timeCPRTeamArrives': 'Less than 2 mins',
#  'glasgowComaScoreAfterCPR': 'E1VTM2',
#  'timeCollapseConfirmed': '20:50',
#  'CPCScoreAt1Month': None,
#  'firstProviderGivingCPR': 'Clinical assistant',
#  'exactTimeOfROSC': '20:56:00',
#  'timeCPRGivenFor': 'LESS than 10 mins',
#  'exactTimeOfEndOfROSC': '20:56',
#  'timeOfDeath': None,
#  'outcome': 'Alive'}

# %%
a=10;b=20
print((lambda:b, lambda:a)[a<b]())
# Out:
# 10

# %%
import json

# %% [markdown]
# # Extracting notes for UMLS

# %%
notes = []
for i in range(len(all_pats)):
    pat_obj = all_pats[i]
    if (pat_obj.get('notes')):
        summary = []; ap = []; to_do = []; dx = []
        summary.append(pat_obj['notes']['finalNotes'][0]['content'][0]['primaryText'])
        ap.append(pat_obj['notes']['finalNotes'][0]['content'][0]['secondaryText'])
        to_do.append(pat_obj['notes']['finalNotes'][0]['content'][0]['tertiaryText'])
        notes.append([summary, ap, to_do, dx])

# %%
notes
# Out:
# [[['<p><strong><u>Summary</u></strong>:&nbsp;64 yr old male admitted with the h/o breathlessness and cough since 2 days . No h/o chest pain and palpitation . He is conscious and oriented , maintaining saturation on o2 mask and hemodynamcially stable .</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;patient is conscious, oriented, obeys commands,</li><li><strong>CVS</strong>:&nbsp;hemodynamically stable,get 12 leadECG , tand echo </li><li><strong>Resp</strong>:&nbsp;maintaining saturation on room air, b/l crackles and rhonchi according to bedside physician , get Chest x ray </li><li><strong>Abd/nutrition</strong>:&nbsp;can start orally,</li><li><strong>Renal</strong>:&nbsp;monitor outputs</li><li><strong>ID:</strong>&nbsp;on pipercillin tazobactum and levofloxacin </li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>MSK:</strong>&nbsp;no concerns,</li><li><strong>Prophylaxis:</strong>&nbsp;mobilise him  </li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>CBC, RFT, ECG, Echo , chest X ray</li><li>Continue antibiotics and nebulisations </li><li>Incentive spirometry</li><li>NIV sos</li><li>Monitor hemodynamics </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;75yr old male known HTN , IHD on medications , presented with the h/o malena  and palpitation since 1 day . He underwent OGD showed erosive espohagitis with fundal gastritis . He is conscious and oriented , hemodynamically stable. Hb- 7.4, plat- 66,0000, needs USG abdomen, coagulation profile  and thrombocytopenia work up. </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious and alert </li><li><strong>CVS</strong>:&nbsp;Hemodynamically stable, stop antiplatelets for now </li><li><strong>Resp</strong>:&nbsp;Breathing comfortably,maintaining good sats on room air.</li><li><strong>Abd/nutrition</strong>:&nbsp;continue PPI infusion , needs coags , LFT, USG abdomen to rule out CLD </li><li>Renal- Sodium 148, will have dehydration - needs fluid resciscitation , creat - 2.4 - monitor urine output and creat </li><li><strong>ID:</strong>&nbsp;Pieprcillin and Tazobactum is not indicated as there is no signs of infection , send dengue, malaria  for thrombocytopenia </li><li><strong>Endo:</strong>mainatin euglycemia </li><li><strong>DVT Prophylaxis:</strong>&nbsp;stockings </li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Monitor HB 8 th hourly - give PRBC if HB is less than 7. Coags stat , </li><li>Continue PPI infusion</li><li> LFT, USG abdomen to rule out CLD </li><li>Monitor hemodynamics </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;68 year old male pt,kco dm,htn,diagnosed case of carcinoma head of pancreas,shifted to ICU with hypotensin adn altered sensorium,being treated as a case of septic shock with encephalopathy.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious alert now,was encephalopathic at admission</li><li><strong>CVS</strong>:&nbsp;hr-78 bpm,bp-120/70 mm hg,on vasopressors-noradrenaline infusion,ecg-to be done,2d echo to be done</li><li><strong>Resp</strong>:&nbsp;saturating well on o2 mask at 6 litres per min</li><li><strong>Abd/nutrition</strong>:&nbsp;npo tillf urther orders,possibility of ascending cholangitis,usg abdomen to be done.</li><li><strong>Renal</strong>:&nbsp;I/O monitoring to be done,creatinine on the higher side-?AKI/AOCKD,urine routine and usg abdomen to be done,sodium-hypernatremic,continue IV hydration,recheck electrolytes tomorrow</li><li><strong>ID:</strong>&nbsp;fever spikes present,on piptaz,metronidazole,blood c/s and urine c/s to be done</li><li><strong>Skin:</strong>&nbsp;check for bed sores/cellulitis</li><li><strong>Endo:</strong>&nbsp;blood sugars to be kept below 180 mg/dl,insulin as per sliding scale.</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;dvt stockings</li><li><strong>Hemat:  anemic and thrombocytopenic,</strong>prbc transfusion,1 sdp/6 rdp transfusion,total counts ok,INR-PT REMAINS coagulopathic.</li><li><strong>ABG: metabolic acidosis on abg</strong></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;This is a 60 year old lady, known case of TVD,CAD,presents with altered sensorium. left leg cellulitis as per clinical notes.Admitted with breathing difficult and hypotension. Treating as septic shock.</p>'],
#   ["<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;GCS - 15/15.</li><li><strong>CVS</strong>:&nbsp;Hemodynamically unstable, on noradrenaline infusion. Please titrate noradrenaline to a MAP of 65 mmhg.</li><li><strong>Resp</strong>:&nbsp;Breathing pattern appears laboured.Follow up ABG please.S.O.S intubation. The breathing may be acidosis related,</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO</li><li><strong>Renal</strong>:&nbsp;FOley's,follow urine output</li><li><strong>ID:</strong>&nbsp;Rationalize antibiotics please</li><li><strong>Endo:</strong>&nbsp;Monitor sugars </li><li><strong>Prophylaxis:</strong>&nbsp;Will start LMWHH/Heparin after ABG</li></ol>"],
#   ["<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Repeat ABG.</li><li>Cautious Fluid resucitation.</li><li>Use ringer's lactate.</li><li>Repeat lactate after 4 hours</li></ol>"],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;22 year old male pt,a/h/o Hanging,gcs-e1m3vt on arrival,??intubated for low gcs-??neurogenic pulmonary edema/neurogenic shock.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;gcs-e2m4vt</li><li><strong>CVS</strong>:&nbsp;hr-118 bpm,bp-90/60 on high dose of noradrenaline</li><li><strong>Resp</strong>:&nbsp;on vent-vc-cmv-ss-16/400/5/0.6,saturating well on the above settings,cxr awaited.</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders</li><li><strong>Renal</strong>:&nbsp;i/o monitoring to be done,</li><li><strong>ID:</strong>&nbsp;afebrile as of now,on broad spectru antibiotics,consider deescalating antibiotics if no risk of mdr infections</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;blood sugars to be kept below 180 mg/dl</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;dvt stockings as of now</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>neuromonitoring</li><li>admission labs-cbc,rft,serum electrolytes,abg</li><li>cxr to be done</li><li>ct brain with ct cervical spine to be done</li><li><br></li></ol>'],
#   []],
#  [['<p>This is a 25 year old lady,presented with quadriparesis which she noticed on getting up from sleep in the morning - 3 days back,?onset of disease in sleep.She developed,dysphagia and breathing difficulty after 1 day,was shifted here.She has been intubated in v/o respiratory failure.No sensory findigs or symptoms as per bedside doctorPossible acute inflammatory demyelinating Polyneuropathy - suspect AMAN variant of AIDP.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;GCS -15/15,distal symmetrical flaccid quadriparesis as per bedside physician.Suspect AMAn variant in v/o rapid progression to bulbar symptoms,suspect AMAN variant of AIDP.Would consider administering IVIg or plasmapheresis both of which have relatively similar efficacy</li><li><strong>CVS</strong>:&nbsp;Hemodynamically stable</li><li><strong>Resp</strong>:&nbsp;Had respiratory acidosis in the morning, vent settings changed to VCCMVs with increased I;E ratio.Please ensure adequate minute volume in this patient.Please avoid SIMV mode of ventilation since this patient will develop respiratory muscle derecruitment rapidly and will prolong weaning. </li><li><strong>Abd/nutrition</strong>:&nbsp;RT feeds per protocol.</li><li><strong>Renal</strong>:&nbsp;Monitor U/O and follow up RFT.</li><li><strong>ID:</strong>&nbsp;Is on multiple antibiotics,consider deescalating antibiotics please <span style="background-color: transparent; color: rgb(0, 0, 0);" tabindex="-1">Prolonged antibiotic usage will lead to selecting out MDR bacteria in the same patient with a risk of resistant infections .It also leads to loss of protective normal commensal bacteria leading to propagation of gut translocation of organisms into the blood and also antibiotic associated diarrhoea and clostridium difficle.</span></li><li><strong>Endo:</strong>&nbsp;Monitor sugars atleast once daily</li><li><strong>Prophylaxis:</strong>&nbsp;Start DVT prophylaxis with inj.enoxaparin 40 mg S/C OD</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><p><br></p><ol><li>Plan IV Ig administration at a dose of 400mg/kg IV/day X 5 days. or alternatively plasmapharesis if feasible.</li><li> Continue CMV,avoid using SIMV mode in this patient  this patient will develop respiratory muscle derecruitment rapidly and will prolong weaning and liberation from he ventilator.</li><li><br></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;This is a 35 year old lady,has been in the ICU,shifted from another bed.C/O large ischemic stroke ( report or films not available to me ). As per the bedside doctor she is comatose, on very high dose of noradrenaline.Poor prognosis has been discussed with family.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;E1M1,poor prognosis to be discussed with family,will follow up CT report</li><li><strong>CVS</strong>:&nbsp;HR - 124/min,Bp - 100/50 mmhg</li><li><strong>Resp</strong>:&nbsp;On SIMV VC,suggest changing to VC-CMVs as SIMV as a mode has been found to increase duration of ventiation and time to extubation and can lead to respiratory muscle failure.</li><li><strong>Abd/nutrition</strong>:&nbsp;RT feeds.</li><li><strong>Renal</strong>:&nbsp;Monitor U/O</li><li><strong>ID:</strong>&nbsp;Is on Ceftriaxone,will continue the same for now.</li><li><strong>Endo:- Monitor sugars atleast once daily</strong></li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>uggest changing to VC-CMVs as SIMV as a mode has been found to increase duration of ventiation and time to extubation and can lead to respiratory muscle failure and waning failure.</li><li>Continue neuromonitoring.</li><li>Dismal prognosis to be discussed with family.</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp; Patient presented with complaints of left sided weakness, breathlesness, CXR is awaited, his GCS is E1V1M5, CT brain awaited,  hemodynamically stable, maintaining saturation on 5 ltr of O2, RT to be secured, and feeds to be started, outputs too be monitored, on multiple antibiotics, please consider stopping antibiotics as multiple antibiotics will not help in the setting of doubtful signs of infection, DVT stocking to be applied, avoid anticoagulant as of now.</p><p><br></p>'],
#   ["<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;his GCS is E1V1M5, please do consider for intubation if doesn't protect airway.</li><li><strong>CVS</strong>:&nbsp;hemodynamically stable, 2DEcho to be done.</li><li><strong>Resp</strong>:&nbsp;maintaining saturation on 5 ltr of O2, no breathless as of now, CXR awaited.</li><li><strong>Abd/nutrition</strong>:&nbsp;RT to be secured, and feeds to be started, </li><li><strong>Renal</strong>:&nbsp;outputs too be monitored.</li><li><strong>ID:</strong>&nbsp;on multiple antibiotics, please consider stopping antibiotics as multiple antibiotics will not help in the setting of doubtful signs of infection.</li><li><strong>Skin:</strong>&nbsp;intact</li><li><strong>Endo:</strong>&nbsp;normal</li><li><strong>Prophylaxis:</strong>&nbsp;DVT stocking to be applied, avoid anticoagulant as of now.</li></ol>"],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>CT brain to be done</li><li>consider stopping antibiotics as no signs of infections present.</li><li>secure Rt feeds and start RT,</li><li>monitor sensorium,</li><li>2DEcho to be done</li><li>CXR to be done</li><li>neurologist reference,</li><li>SOS intubation</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Mr. Jag Narayan singh , known HTN , admitted with the H/o  drowsiness and left sided weakness . CT abdomen showed rt capsuloganglionic bleed with IV extension . He was drowsy on arrival E1V1M4, had accelerated HTN  , has poor cough reflez and gurgling according to bedside physician , mainatining saturation on o2 mask </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:E1V1M4, , has poor cough reflez and gurgling according to bedside physician. Consider intubation in view of low GCS and not miantaining airway , neurosurgery , start antiedema , control the blood pressure </li><li><strong>CVS</strong>:ahving accelerated HTN - start Labetolol infusion to maintain MAp around 80mmhg </li><li><strong>Resp</strong>:gurgling and has poor cough reflex, needs emergency intubation., Chest X ray stat </li><li><strong>Abd/nutrition</strong>:&nbsp;NPO </li><li><strong>Renal</strong>:&nbsp;outputs to be monitored</li><li><strong>ID:</strong></li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong></li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings to be applied.</li><li><br></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Close neuromonitoring , Neurosurgery opnion for decompression craniotomy and EVD placement, continue antiedema </li><li>Needs emergency intubation and mechanical ventilation , ABG stat - prevent hypercarbia , hypoxia.</li><li>Start labetolol infusion - mainatin MAP around 80mmhg </li><li>Monitor urine output</li></ol><p><br></p>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Patient presented with complaints of SOB and altered sensorium. Patient is suboptimal in sensorium, hemodynamically stable, maintaining saturation on 5 ltr of O2, CXR to be done, hemodynamically stable, no intervention required as of now, maintaining saturation on 5 ltr of O2,&nbsp;NPO in view of low GCS and SOB, might need intubation, outputs yo be monitored,&nbsp;has fever spikes 102F, please send cultures (Blood and Urine and sputum), on multiple antibiotics, needs to downgrade antibiotics, please prefer azithromycin and ceftriaxone until we have culture and sensitivity report, apply DVT stockings for now.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;sub optimal in sensorium, GCS E2V1M4, needs CT brain.</li><li><strong>CVS</strong>:&nbsp;Hemodynamically stable, no intervention required as of now.</li><li><strong>Resp</strong>:&nbsp;Maintaining saturation on 5 ltr of O2.</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO in view of low GCS and SOB, might need intubation</li><li><strong>Renal</strong>:&nbsp;adequate outputs, </li><li><strong>ID:</strong>&nbsp;has fever spikes 102F, please send cultures (Blood and Urine and sputum), on multiple antibiotics, needs to downgrade antibiotics, please prefer azithromycin and ceftriaxone until we have culture and sensitivity report.</li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;to be monitored</li><li><strong>MSK:</strong>&nbsp;normal</li><li><strong>Prophylaxis:</strong>&nbsp;apply DVT stockings for now.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Send cultures</li><li>downgrade antibiotics until we have C/S report</li><li>might need LP</li><li>bring down temperature.</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;55 yr old male admitted with the h/o fever since 5 days, No h/o cough/SOB/ burning micturation . He was evaluated outside WIDAl was weakly positive -- later turned out to be negative , malaria- negative. She is conscious and oriented ,hemodynamcially stable </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">CNS/Psych:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;awake, alert,</span></li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;sinus rhythm, unsupported BP.</span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;breathing comfortably and maintaining saturation on room air, Chest X ray to be done</span></li><li><strong style="background-color: transparent;">Abd/nutrition</strong><span style="background-color: transparent;" tabindex="-1">:soft ,USG abdomen , urine routine,stat</span></li><li><strong style="background-color: transparent;">Renal</strong><span style="background-color: transparent;" tabindex="-1">: self voiding. please monitor urine output.&nbsp;and creatinine</span></li><li><strong style="background-color: transparent;">ID</strong><span style="background-color: transparent;" tabindex="-1">: </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact</span></li><li><strong style="background-color: transparent;">Endo:</strong></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;stockings</span></li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Chest X ray , urine routin, blood and urine c/s</li><li>Monitor hemodynamics</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;presented with sudden onset of vomitting breathlesness since one day. Patient is sub optimal in sensorium, GCS: E3V2M5, Ct brain done looks normal but radiology report awaited, hemodynamically stable, maintaining saturation on 5ltr of O2, NPO for now, monitor outputs, creatinine is elevated, hyperkalemia present, on multiple antibiotics, needs to downgrade or sto them as no signs of infections present.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;Patient is sub optimal in sensorium, GCS: E3V2M5, Ct brain done looks normal but radiology report awaited.</li><li><strong>CVS</strong>:&nbsp;hemodynamically stable, </li><li><strong>Resp</strong>:&nbsp;maintaining saturation on 5 ltr of O2, CXR looks normal.</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO for now,</li><li><strong>Renal</strong>:&nbsp;monitor outputs, creatinine is elevated, hyperkalemia present.</li><li><strong>ID:</strong>&nbsp;on multiple antibiotics, needs to downgrade or sto them as no signs of infections present.</li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings to be applied.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>insulin dextrose to be administered</li><li>duolin  and budecort nebulisation to be started.</li><li>USg abdomen to be done.</li><li>F/U CT brain report.</li><li>ABG to be done.</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Presented with alleged H/O consumption of OP poisoning, frothing in mouth present, patient is unconscious with B/L pin point pupils. Patient is conscious, oriented, obeys commands, hemodynamically stable, maintaining saturation non  T piece. Intubated in view of low GCS for airway protection, NPO for now, RT secured, outputs to be monitored, on multiple antibiotics, consider stopping antibiotics, DVT stockings to be applied.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;Patient is conscious, oriented, obeys commands, PUPILS 2 mm dilated,</li><li><strong>CVS</strong>:&nbsp;hemodynamically stable, HR 102bpm, hemodynamically stable.</li><li><strong>Resp</strong>:&nbsp;maintaining saturation non  T piece. Intubated in view of low GCS for airway protection, no secretions</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO for now, RT secured.</li><li><strong>Renal</strong>:&nbsp;Outputs to be monitored.</li><li><strong>ID:</strong>&nbsp;on multiple antibiotics, consider stopping antibiotics.</li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings to be applied.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>continue supportive care</li><li>consider respiratory weaning.</li><li>NPO for now.</li><li>watch for desaturations.</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;49/F unknown comorbids comes with abdominal distension, pain abdomen and constipation since 2 days. is currently in shock requiring multiple vasopressors. </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;drowsy rousable. E3V3M4</li><li><strong>CVS</strong>:&nbsp;tachycardia. hypotension on high dose vasopressors. is on high dose noradrenaline. vasopressin added. 500ml of fluid bolus is being administered. </li><li><strong>Resp</strong>:&nbsp;laboured respiration. patient would have increased work of breathing. to ideally intubate and ventilate the patient. ABG shows severe metabolic acidosis. </li><li><strong>Abd/nutrition</strong>:&nbsp;has come with pain abdomen. ?peritonitis. to get abdomen x ray/cxr or ideally CT abdomen. </li><li><strong>Renal</strong>:&nbsp;catheterise and monitor urine output. </li><li><strong>ID:</strong>&nbsp;on meropenem, ofloxacin and metronidazole. consider stopping ofloxacin and metronidazole. meropenem has wide coverage for both anaerobes and gram negatives. </li><li><strong>Skin:</strong>&nbsp;intact</li><li><strong>Endo:</strong>&nbsp;maintain sugars &lt;180</li><li><strong>MSK:</strong>&nbsp;no concerns. </li><li><strong>Prophylaxis:</strong>&nbsp;stockings. </li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>intubate and ventilate</li><li>urgent surgical opinion. </li><li>500ml LR bolus</li><li>discuss poor prognosis with family</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Presented with complaints of gasping to ICU, K/C/O CKD. Patient is hemodynamically unstable on vasopressors, had cardiac arrest twice, revived. She is sedated and paralysed on ventilatory support, RT to be secured. Poor prognosis explained.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;Patient is sedated and paralysed on ventilatory support</li><li><strong>CVS</strong>:&nbsp;hemodynamically unstable on multiple vasopressors.</li><li><strong>Resp</strong>:&nbsp;on ventilatory support</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO for now</li><li><strong>Renal</strong>:&nbsp;monitor outputs, it might drop in view of hypotension</li><li><strong>ID:</strong>&nbsp;on antibiotics, advised to send cultures.</li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;normal</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings to be applied.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>observe</li><li>wean vasopressors</li><li>therapeutic hypothermia to be done</li><li>continue antibiotics</li><li>send cultures</li><li>monitor outputs</li><li>might need RRT.</li></ol><p><br></p>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp; 55/M comes with left sided weakness. intubated for airway protection. CT head done shows pontine bleed. is currently E1M1. pupils small but not reactive. </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">CNS/Psych:</strong><span style="background-color: transparent;" tabindex="-1"> GCS E1M1. Ct head shows large pontine bleed. pupils small and non reactive. </span></li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1"> tachycardia noted. BP maintained. </span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1"> on ventilator. VC-CMVss.  no spontaneous respiration. </span></li><li><strong style="background-color: transparent;">Abd/nutrition:</strong><span style="background-color: transparent;" tabindex="-1"> on NG feeds, tolerating.&nbsp; Consider laxatives if bowels not opened for last 3 days.&nbsp;</span></li><li><strong style="background-color: transparent;">Renal:</strong><span style="background-color: transparent;" tabindex="-1"> catheterised. Good urine output.&nbsp;</span></li><li><strong style="background-color: transparent;">ID: </strong><span style="background-color: transparent;" tabindex="-1">afebrile, on ceftriaxone and piperacillin tazobactam,. both have same spectrum of activity. consider stopping. </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact. 2 hourly change of position to prevent pressure sores please</span></li><li><strong style="background-color: transparent;">Endo:</strong><span style="background-color: transparent;" tabindex="-1"> maintain sugars &lt;180</span></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1"> no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1"> stockings</span></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>consider stopping antibiotics, </li><li>continue anti edema measures. </li><li>poor prognosis to be explained. </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Mrs. Fatima was admitted with the complains of breathlessness and  cough since 2 days . On arrival , he was in severe respiratory distress and  and deasturating to unsafe levels . She was intubated on started on mechanicalm ventilation . She was found to have hypotension - started on  vasopressors after fluid bolus, is oliguric. Known  cas of IHD with LV dysfunction , bed bound state with pressure sores..</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:coamatosed , opens eye for pain</li><li><strong>CVS</strong>:&nbsp;hypotensive - on stiff doses of noradrenaline - conasider started adrenaline along with noradrenaline , continue fluid boluses after assessment of fluid responsiveness </li><li><strong>Resp</strong>:&nbsp;on assisted ventilation , get Chest X ray</li><li><strong>Abd/nutrition</strong>:&nbsp;start RT feeds , USG abdomen stat</li><li><strong>ID:on multiple antibiotics , can continue meropenam and colistin as it will have adequte coverage, xlindamycin for pressure sore  send blood , ET and urien cultures </strong></li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Prophylaxis:</strong>&nbsp;mobilise the patient.</li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Consider adding adrenaline along with noradrenaline , continue fluid boluses after assessment of fluid responsiveness </li><li>Chest X ray , 12 lead ECG, Echo, <strong>send blood , ET and urine cultures , CBC, RFT, coags, LFT , ABG stat </strong></li><li>Good ET care regular suctioning</li><li>Mainatin MAP of 70mmhg and spo2 more than 90%</li><li>Surgical opinion for pressure sore </li><li><br></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;30 yr old male  known case of alcoholi liver disease , was admitted on 30th June with the complains of hemetemesis - 4 episodes and malena 15 episodes since 1 day with pedal edema . He was intubated in view of low sensorium, had  hypotension with the HB- 4.2 - started on blood transfusion , vasopressors along with fluid boluses.</p><p>He is very critical, is comatosed - opens eye for pain , hypotensive despite of stiff doses of noradrenaline . Is oliguric with coagulaopathy .</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:coamatosed , opens eye for pain </li><li><strong>CVS</strong>:&nbsp;hypotensive - on stiff doses of noradrenaline - conasider started adrenaline along with noradrenaline , continue fluid boluses and blood product transfusion for coaguloapthy and low HB  </li><li><strong>Resp</strong>:&nbsp;on assisted ventilation , get Chest X ray </li><li><strong>Abd/nutrition</strong>:&nbsp;NPO , needs emergency OGD  and achieve hemostasis as early intervention will improve the outcome , continue terlipressin , prevent hypotheramia as it can worsen coagulopathy . USG abdomen stat </li><li><strong>Renal</strong>:&nbsp;monitor outputs</li><li><strong>ID:on Meropenam, Metronidazole, clindamycin  consider  deecalating to pipercillin and tazobactum as it gives adequate coverage for SBP </strong></li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Prophylaxis:</strong>&nbsp;mobilise the patient.</li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Needs emergency OGD  and achieve hemostasis as early intervention will improve the outcome , continue terlipressin , prevent hypotheramia as it can worsen coagulopathy . USG abdomen stat </li><li> Consider started adrenaline along with noradrenaline , continue fluid boluses and blood product transfusion for coaguloapthy and low HB .</li><li>Antiencephalopathy measures</li><li>Good ET care regular suctioning </li><li>Mainatin MAp of 60mmhg and spo2 more than 90%</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;63 YR gentleman, known hypertensive on medications, patient had left sided weakness since 10 days, bought to hospital today , CT BRAIN showed right sided capsuloganglionic haemorrhagivc bleed, in view of low GCS patient got intubated and ventilated, haemodynamics stable.Treating as haemorrhagic stroke. Adviced for nero consultation and continue supportive care.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;(Information from the bedside doctor)This is a 23 year old gentleman, presented to the hospital with an acute febrile illness with fever of 7 - 8 days.Cxray - b/l midzone non homogenous opacities.HRCT done - ........... Intubated today in v/o worsening respiratory distress. Was on a high dose of noradrenaline,Had a cardiac arrest post intubation and has been revived</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;This is a 70 year old gentleman,who presented to the hospital with a history of malena one episode altered sensorium since 2 days.Has left lower limb jerky movements - ? seizure.CT brain done - r  .</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Follow up labs.</li><li>LP CSF today.</li><li>Intubate S.O.S.</li><li>Start the Levetiracetam 1 g IV stat.</li><li><br></li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;70/M, underwent burr hole evacuation of  SDh. came to ICU intubated and ventilated. was tachycardic and hypotensive. fluid bolus to be given. </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">CNS/Psych:</strong><span style="background-color: transparent;" tabindex="-1"> sedated and ventilated.&nbsp;&nbsp;burr hole evacuation done for SDH. still on anti edema measures. to consider stopping by morning. </span></li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1"> tachycardia noted. hypotension on noradrenaline. consider fluid boluses. </span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1"> on ventilator. VC-CMVss</span></li><li><strong style="background-color: transparent;">Abd/nutrition:</strong><span style="background-color: transparent;" tabindex="-1"> NG in situ. NPO overnight. can start NG feeds. </span></li><li><strong style="background-color: transparent;">Renal:</strong><span style="background-color: transparent;" tabindex="-1"> catheterised. creatinine 0.94</span></li><li><strong style="background-color: transparent;">ID: </strong><span style="background-color: transparent;" tabindex="-1">afebrile&nbsp; on clindamycin and levofloxacin. both cover gram positive organisms. consider adding gram negative coverage. </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact. 2 hourly change of position to prevent pressure sores please</span></li><li><strong style="background-color: transparent;">Endo:</strong><span style="background-color: transparent;" tabindex="-1"> maintain sugars &lt;180</span></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1"> no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1"> stockings</span></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>fluid bolus please. </li><li>consider beta blockers</li><li>continue neuromonitoring. </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;22 year old female pt,26 weeks of gestation,came with h/o fever with cough since 1-2 months,came in severe respiratory distress,intubated for the same,currently on invasive mechanical ventilation,saturating well on the above settings.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;sedated for ventilation</li><li><strong>CVS</strong>:&nbsp;parameters ok,sinus tachycardia on monitor,ecg to be done</li><li><strong>Resp</strong>:&nbsp;on vent-vc-cmv-ss,16/400/5/0.8,advised to increase peep and decrease fio2 to keep saturations above 88-90%,cxr to be done with shield.</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders</li><li><strong>Renal</strong>:&nbsp;I/O monitoring to be done,rfts verbally informed to be normal.</li><li><strong>ID:</strong>&nbsp;afebrile,on piperacillin tazobactam,levofloxacin and antitubercular therapy,stop levofloxacin </li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:blood sugars ok</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp; dvt prophyalxis as of now</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>collect admission lab reports-cbc,rft,serum electrolytes,lft,abg,cxr</li><li>abg,cxr,12 lead ecg to be done</li><li>i/o monitoring</li><li>usg chest to look for effusions</li><li>continue invasive mechanical ventilation</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;22 year old male pt,??status epilepticus,loaded with antiepileptic medications and shifted to ICU for the same.physically restrained as of now.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious alert,no focal neurodefecits</li><li><strong>CVS</strong>:&nbsp;parameters ok</li><li><strong>Resp</strong>:&nbsp;breathing comfortably on room air</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders</li><li><strong>Renal</strong>:&nbsp;I/O monitoring to be done,labs awaited.</li><li><strong>ID:</strong>&nbsp;afebrile as of now,w/f fever</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;blood sugars to  be kept below 180 mg/dl.</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>neuromonitoirng</li><li>continue antiepileptics</li><li>routine labs-cbc,rft,serum electrolytes,abg,cxr</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;65 yr male , admitted with the h/o fever, altered sensorium since 5 days . On arrival, he was found to have hypoglycemia- 33mg/dl- correction given . He also has hyponatremia-109, with deranged renal function - creat - 4.8 . He is drowsy , opens eye , withdrawal  for pain , tachypneic , hemodynamically stable . CT brain appeas normal - reporting is awaited </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">NS/Psych:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;</span>drowsy , opens eye , withdrawal  for pain , tachypneic,. Close neuromonitoring . needs intubation in case of further deterioration of GCS or not maintaining the airway . may need CSF analysis if sensorium does not improve with correction of metabolic components . Get Ct reporting </li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;sinus rhythm,&nbsp;hemodynamcially stable. get 12 lead ECG </span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;</span>tachypneic,. Close neuromonitoring . needs intubation in case of further deterioration of GCS or not maintaining the airway . </li><li><strong style="background-color: transparent;">Abd/nutrition</strong><span style="background-color: transparent;" tabindex="-1">:NPO for now </span></li><li><strong style="background-color: transparent;">Renal</strong><span style="background-color: transparent;" tabindex="-1">: monitor urine output.&nbsp;send urine routine , USG abdomen and pelvis to rule out obstructive uropathy/ hydro/pyelonephritis</span></li><li><strong style="background-color: transparent;">ID</strong><span style="background-color: transparent;" tabindex="-1">: on pipercillin and tazobactum </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact</span></li><li><strong style="background-color: transparent;">Endo:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;maintain sugars &lt;180</span></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1">&nbsp;stockings</span></li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Close neuromonitoring . needs intubation in case of further deterioration of GCS or not maintaining the airway . may need CSF analysis if sensorium does not improve with correction of metabolic components . Get CT reporting </li><li>Correction of sodium and maintain  euglycemia .</li><li>monitor urine output.&nbsp;send urine routine , USG abdomen and pelvis to rule out obstructive uropathy/ hydro/pyelonephritis.</li><li>Repeat ABG , RFT at 10pm </li><li>Monitor vitals </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;82 year old female pt,kco HTN,COPD,??CAD,came with h/o bilateral both limb cellulitis and lymphedema,treating as SSTI.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;encephalopathic-gcse1m2v1,ct brain to be done-to r/o central causes of low gcs</li><li><strong>CVS</strong>:&nbsp;parameters ok</li><li><strong>Resp</strong>:&nbsp;maintaining sats on o2 nasal prongs</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders,ng insertion</li><li><strong>Renal</strong>:&nbsp;I/O monitoring to be done</li><li><strong>ID:</strong>&nbsp;afebrile as of now,on vancomycin,clindamycina nd meropenem</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;blood sugars ok</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;dvt stockings as of now</li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>neuromonitoring</li><li>intubation for airway protection</li><li>collect all routine lab reports</li><li>ct brain to be planned</li><li>skin wound dressing and surgical opinion</li></ol><p><br></p>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;55 yr amle , known IHD admitted with the h/o fever and breathlessness . On arrival, he had hypotension with elevated cardiac enzymes, bedside echo showed RWMA with EF- 25%, he is droswsy , opening eye and flexing  to pain . He has Type II respiratory failure  and stiff dose of noradrenaline to maintain blood pressure . He needs intubation  and mechanical ventilation </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:opening eye and flexing  to pain ., on NIV - neeeds intubation and mechanical ventilation </li><li><strong>CVS</strong>:&nbsp;hypotensive on stiff dose of noradrenaline , consider gentle fluid bolus if he is fluid responsive and taper vaopressor ,get ECG, Echo and cardiology opinion </li><li><strong>Resp</strong>:On NIV , spo2-90% , consider intubation get chest X ray</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO </li><li><strong>Renal</strong>:&nbsp;monitor urine output, antihyperkalemic measures, repeat RFT -morning </li><li><strong>ID:</strong>&nbsp;On meropenam, send blood , urine c/s deescalate acoording to sensitivity</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;Monitor GRBS hourly - maintain between 140 to 180mg/dl, </li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;Apply DVT stockings,</li></ol><p><br></p>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Neuromonitoring - neeeds intubation and mechanical ventilation </li><li>consider gentle fluid bolus if he is fluid responsive and taper vaopressor ,get ECG, Echo and cardiology opinion </li><li> send blood , urine c/s, USG abdomen , get chest X ray</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;76 year old male pt,kco bronchial asthma,came with breathing difficulty,??possible LRTI.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;CONSCIOUS ALERT,</li><li><strong>CVS</strong>:&nbsp;on minimal noradrenaline,parameters ok</li><li><strong>Resp</strong>:&nbsp;saturating well on o2 mask at 6 litres per min,cxr to be done,abg-shows respiratory alkalosis</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders</li><li><strong>Renal</strong>:&nbsp;I/O montioring to be done,rfts awaited</li><li><strong>ID:</strong>&nbsp;on multiple antibiotics,can start simpler antibiotics if no indication for mdr sepsis/recent ICU admission</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;blood sugars to be checked and kept below 180 mg/dl</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;dvt stockings as of now</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>cxr</li><li>cbc,rft,serum electrolytes,lft to be done</li><li>continue antibiotoics and nebulisations</li><li>i/o monitoring</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;49 year old male pt,a/h/o consumption of aluminium phosphide ,in severe metabolic acidosis as of now.</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious alert</li><li><strong>CVS</strong>:&nbsp;parameters ok</li><li><strong>Resp</strong>:&nbsp;breathing comfortably on room air,to be intubated in view of severe metabolic acidosis</li><li><strong>Abd/nutrition</strong>:&nbsp;gastric lavage and decontamination done.</li><li><strong>Renal</strong>:&nbsp;i/o monitoring,severe metabolic acidosis present,awaiting labs</li><li><strong>ID:</strong>&nbsp;afebrile as of now</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;blood sugars ok</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>endotracheal intubation</li><li>rrt sos for severe metabolic acidosis</li><li>mg so4 stat</li><li>antihyperkalemnic therapy</li><li>grave prognosis to be explained to the relatives.</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;This is a 48 year old lady,known case of Lupus nephritis on long term steroids and HCQ -10 years,sudden onset dyspnea last night,frothy sputum in ET tube.presented to the hospital with type 1 respiratory failure.She is currently intubated and ventilated.She is on VCIMVs.PaO2 on ABG - Respiratory alkalosis with mild metabolic acedemic compensation.E4M6. Possibly cardiogenic pulmonary edema. on diuretics - 1200ml u/o so far.Cxray show b/l diffuse fluffy as well as nodular shadows. Would suspect</p>'],
#   ["<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;E4M6VT. Continue neuromonitoring.Avoid benzodiazepines and paralytic agents unless absolutely essential as they prolong length of ICU stay.</li><li><strong>CVS</strong>:&nbsp;Hemodynamically stable.Get 2D ECHO please. Temproal courseof this patient's disease is not fully explained with pulmonary edema.</li><li><strong>Resp</strong>:&nbsp;Maintaining good sats on 40% FiO2. In v/o nodular and fluffy opacities in the lung with background steroid use,suspect fungal and pneumocystis infection. Consider CT chest to look for s/o fungal pneumonia. Get serum LDH,if LDH is below 200,likelyhood of PCP decreases.</li><li><strong>Abd/nutrition</strong>:&nbsp;May institute RT feeds.</li><li><strong>Renal</strong>:&nbsp;if Oliguric .use diuretics cautiously.</li><li><strong>ID:</strong>&nbsp;Is on adequate antibacterials.In v/o risk factors for fungal infection and nodular shadows on Cxray - consider starting on an Eichanocandin - Caspofungin or Anidulafungin. (If not feasible then consider voriconazole). If serum LDH is more than 200,consider PCP and would advise starting Cotrimoxazole</li><li><strong>Endo:</strong>&nbsp;Monitor GRBS 6 hourly please.</li><li><strong>Prophylaxis:</strong>&nbsp;DVT stockings.</li></ol>"],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>Consider starting on an Eichanocandin - Caspofungin or Anidulafungin. (If not feasible then consider voriconazole). If serum LDH is more than 200,consider PCP and would advise starting Cotrimoxazole</li><li>Change mode to either VC or PC,SIMV increases time to extubation and ventilator dependancy time.</li><li>2D ECHO</li><li>ABG in the evening.</li><li>Continue steroids</li><li>Reduce FiO2 to 35%,PEEP - 7</li><li>Send LDH</li><li>Consider CT chest in case the shadows are progressive.</li></ol>'],
#   []],
#  [["<p><strong><u>Summary</u></strong>:&nbsp; 70/M known case of parkinson's, bed bound. comes with altered sensorium. evaluated at other ICU of same hospital. intubated for airway protection. CT head done, CSF done suggestive of TB Meningitis. shifted here for further management,. </p>"],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">CNS/Psych:</strong><span style="background-color: transparent;" tabindex="-1"> CT head done, no acute changes noted. CSF done suggestive of TBM, still in altered sensorium.&nbsp;&nbsp;</span></li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1"> is tachycardic. BP unsupported, </span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1"> on ventilator. PC-CMVss laboured respiration noted. ABG and CXR awaited. consider sedation. will optimise ventilator parameters based on ABG and CXR</span></li><li><strong style="background-color: transparent;">Abd/nutrition:</strong><span style="background-color: transparent;" tabindex="-1"> NG tube in situ. to start feeds. </span></li><li><strong style="background-color: transparent;">Renal:</strong><span style="background-color: transparent;" tabindex="-1"> catheterised. monitor urine output.&nbsp;sodium remained high 154- is on 5% dextrose and free water on NG. </span></li><li><strong style="background-color: transparent;">ID: </strong><span style="background-color: transparent;" tabindex="-1">afebrile&nbsp;antibiotics escalated to Meropenem and vancomycin. AKT on flow. </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact. 2 hourly change of position to prevent pressure sores please</span></li><li><strong style="background-color: transparent;">Endo:</strong><span style="background-color: transparent;" tabindex="-1"> maintain sugars &lt;180</span></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1"> no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1"> stockings</span></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>CXR and ABG along with CBC, RFT, LFT if not done today. </li><li>consider sedation. </li><li>consider starting steroids. </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Patient presented with breathlessness, K/C/O ILD, HTN, HYPOTHYROID. conscious, oriented, obeys commands GCS 15/15, hemodynamically unstable. Patient is on IV vasopressors. Last measured BP is 110/70, could be infective or cardiogenic needs further evaluation, patient is in NIV saturating 94% on 40% FiO2. ABG suggestive of respiratory acidosis, can start orally., outputs to be monitored, afebrile for the last 24 hours. Patient currently on D-1 of Moxifloxacin 400 mg q24 hrs, anemia noted (6.6). Low platelets (129000). might need transfusion.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious, oriented, obeys commands GCS 15/15. </li><li><strong>CVS</strong>:&nbsp;Hemodynamically unstable. Patient is on IV vasopressors. Last measured BP is 110/70, could be infective or cardiogenic needs further evaluation.</li><li><strong>Resp</strong>:&nbsp;Patient is in NIV saturating 94% on 40% FiO2. ABG suggestive of respiratory acidosis. </li><li><strong>Abd/nutrition</strong>:&nbsp;can start orally. </li><li><strong>Renal</strong>:&nbsp;outputs to be monitored. </li><li><strong>ID:</strong>&nbsp;Afebrile for the last 24 hours. Patient currently on D-1 of Moxifloxacin 400 mg q24 hrs. Leukocytosis (16.5).</li><li><strong>Hematologic:</strong>&nbsp;Anemia noted (6.6). Low platelets (129000). might need transfusion.</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp; normal(121)</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;DVT prophylaxis to be applied.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>continue NIV</li><li>2DEcho to be done</li><li>wean vasopressors</li><li>continue antibiotics</li><li>if fever spikes present send cultures.</li><li>repeat ABG @ 7PM</li></ol><p><br></p>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;22/F, unknown comorbids comes with fever, cough and breathlessness. treating as pneumonia. now connected to NIV. tachypneic and desaturating well. </p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong style="background-color: transparent;">CNS/Psych:</strong><span style="background-color: transparent;" tabindex="-1"> GCS 15/15. No focal deficits.&nbsp;</span></li><li><strong style="background-color: transparent;">CVS:</strong><span style="background-color: transparent;" tabindex="-1"> tachycardia noted. BP maintained. </span></li><li><strong style="background-color: transparent;">Resp:</strong><span style="background-color: transparent;" tabindex="-1"> desaturating to 50% on oxygen. saturating well on NIV with 15L oxygen. to continue NIV, but low threshold for intubation and ventilation. </span></li><li><strong style="background-color: transparent;">Abd/nutrition</strong><span style="background-color: transparent;" tabindex="-1">: can eat and drink as tolerated. elevated liver enzymes. bilirubin in normal limits. ultrasound abdomen to be done to look for structural liver issues. also to get dengue panel done in view of thrombocytopenia and elevated liver enzymes. </span></li><li><strong style="background-color: transparent;">Renal</strong><span style="background-color: transparent;" tabindex="-1">: catheterise and monitor urine output.&nbsp;creatinine &lt;1.0</span></li><li><strong style="background-color: transparent;">ID</strong><span style="background-color: transparent;" tabindex="-1">: treating as pneumonia. started on meropenem, moxifloxacin, teicoplanin. oseltamivir. would suggest de-escalate antibiotic based on cultures. </span></li><li><strong style="background-color: transparent;">Skin</strong><span style="background-color: transparent;" tabindex="-1">: intact</span></li><li><strong style="background-color: transparent;">Endo:</strong><span style="background-color: transparent;" tabindex="-1"> maintain sugars &lt;180</span></li><li><strong style="background-color: transparent;">MSK:</strong><span style="background-color: transparent;" tabindex="-1"> no concerns</span></li><li><strong style="background-color: transparent;">Prophylaxis:</strong><span style="background-color: transparent;" tabindex="-1"> stockings</span></li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>continue NIV. low threshold for intubation. would consider intubation anyways if no response in 1 hour. </li><li>ECG, ABG to be done. collect CXR </li><li>ultrasound abdomen.</li><li>send for dengue panel please</li><li>intubation and ventilation if distress not settled in 1 hour. </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;patient not maintaining spo2 on NIV support, continuous desaturation noted</p><p><br></p><p>plan for Intubation, discussed with ground staff</p>'],
#   [None],
#   [None],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Patient presented with complaints of malena since 15 days. Patient is conscious oriented, hemodynamically stable, maintaining saturation on room air, NPO for now, needs colonoscopy and endoscopy to look for cause for GI bleed, started on pantoprazole infusion, monitor outputs, no signs of infection present, on multiple antibiotics, please consider stopping antibiotics, can be continued amoxicillin or ceftriaxone to be started, mobilise as early as possible.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;conscious, oriented, obeys commands.</li><li><strong>CVS</strong>:&nbsp;hemodynamically stable</li><li><strong>Resp</strong>:&nbsp;maintaining saturation on room air</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO for now, needs colonoscopy and endoscopy to look for cause for GI bleed.</li><li><strong>Renal</strong>:&nbsp;monitor outputs</li><li><strong>ID:</strong>&nbsp;no signs of infection present, on multiple antibiotics, please consider stopping antibiotics, can be continued amoxicillin or ceftriaxone to be started.</li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;normal</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;mobilise as early as possible.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>continue pantoprazole infusion</li><li>gastroenterology reference.</li><li>watch for further episodes of malena</li><li>needs endoscopy/ colonoscopy</li><li>check hemoglobin Q12H.</li><li>needs 1-2 PRBC transfusion. </li><li>consider downgrading antibiotics. </li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;Patient presented with complaints of fever, altered sensorium since 2 days, vomiting since 2 days, she was admitted in other hospital and was diagnosed to have septic shock and type II respiratory failure, on ventilation. Patient is intubated ventilated, in view of severe respiratory distress, low GCS. Could be septic encephalopathy, hemodynamically unstable, on multiple vasopressor nor-adrenaline, BP still not measurable advised to start vasopressin. Could be septic shock, maintaining saturation on ventilatory settings, NPO for now, on RT tube, outputs to be measured, on multiple antibiotics, please send cultures of blood, urine, and ET, apply DVT stockings.</p><p><br></p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;Patient is intubated ventilated, in view of severe respiratory distress, low GCS.</li><li><strong>CVS</strong>:&nbsp;hemodynamically unstable, on multiple vasopressor nor-adrenaline, BP still not measurable advised to start vasopressin. Could be septic shock.</li><li><strong>Resp</strong>:&nbsp;maintaining saturation on ventilatory settings, CXR to be done, ABG shows compensated metabolic acidosis, oxygenation is (PaO2) 60.</li><li><strong>Abd/nutrition</strong>:&nbsp;NPO for now, on RT tube</li><li><strong>Renal</strong>:&nbsp;outputs to be measured.</li><li><strong>ID:</strong>&nbsp;on multiple antibiotics, please send cultures of blood, urine, and ET, </li><li><strong>Skin:</strong>&nbsp;Intact</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;start DVT stockings.</li><li><strong>LABS:</strong> Thrombocytopenia present could be due to infection, raised TLC doue be due to infection, raised sodium and chloride could be due excessive use of NS or could be due to dehydration, please consider RL and monitor serum sodium level.</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>send cultures</li><li>continue antibiotics until culture reports arrives.</li><li>continue ventilation</li><li>continue vasopressors to maintain MAP of 65-70mmHg</li><li>2Decho to be done</li><li>CXR to be done</li><li>NPO for now, </li><li>USG abdomen to be done</li><li>outputs to be monitored.</li><li>monitor sodium level Q12H</li></ol>'],
#   []],
#  [['<p><strong><u>Summary</u></strong>:&nbsp;46 year old female pt,recent admission in icu for septic shock and septic encephalopathy.has now come with pain abdomen,altered sensorium and hypotension</p>'],
#   ['<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;GCS SUBOOPTIMAL,MAY NEED CT BRAIN IF PT REMAINS persistently encephalopathic</li><li><strong>CVS</strong>:&nbsp;on noradrenaline infusion,ecg to be done</li><li><strong>Resp</strong>:&nbsp;breathing comfortably on room air</li><li><strong>Abd/nutrition</strong>:&nbsp;npo till further orders,ct abdomen done-no gross bowel distension</li><li><strong>Renal</strong>:&nbsp;i/o monitoring to be done,rfts to be checked.</li><li><strong>ID:</strong>&nbsp;afebrile as of now,cbc,blood and urine c/s o be done.</li><li><strong>Skin:</strong>&nbsp;</li><li><strong>Endo:</strong>&nbsp;keep blood sugars below 180 mg/dl</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>'],
#   ['<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>admission labs-cbc,rft,serum electrolytes,abg,cxr,ecg</li><li>i/o monitoring</li><li>surgical opinion for the subacute obstruction</li><li>blood c/s and urine c/s to be done</li></ol>'],
#   []]]

# %% [markdown]
# # SQL

# %%
import sqlite3
connection = sqlite3.connect('mallige.db')
cursor = connection.cursor()

# %%
connection.close()

# %%
list(cursor.execute('SELECT * FROM Mallige_JuneJuly'))
# Out:
# [('0',
#   'Vijaya',
#   'INKABLRMAL1',
#   '2019-06-04 22:40:43.009000+00:00',
#   '2019-06-05 06:30:20.480000+00:00',
#   '67',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '104.67',
#   '98.7',
#   '67.0',
#   '18.0',
#   '96.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.38',
#   '63.0',
#   '34.9',
#   '15.5',
#   '16.2',
#   '9100.0',
#   '308000.0',
#   '4.1',
#   '143.0',
#   '0.67',
#   '22.0',
#   '0.49',
#   '',
#   '3.2',
#   '0.82'),
#  ('1',
#   'Sathi skandan',
#   'INKABLRMAL2',
#   '2019-06-09 08:50:06.686000+00:00',
#   '2019-06-10 07:50:30.440000+00:00',
#   '67',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   '',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '321.0',
#   '89.67',
#   '98.6',
#   '130.0',
#   '23.0',
#   '95.0',
#   '28.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.6',
#   '65.0',
#   '22.8',
#   '22.3',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('2',
#   'Vijaya ravi',
#   'INKABLRMAL3',
#   '2019-06-09 11:30:59.479000+00:00',
#   '2019-06-11 06:31:19.852000+00:00',
#   '57',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   '',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '267.8',
#   '103.33',
#   '98.6',
#   '112.0',
#   '23.0',
#   '90.0',
#   '24.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('3',
#   'Annapurna',
#   'INKABLRMAL4',
#   '2019-06-11 00:52:32.399000+00:00',
#   '2019-06-18 10:39:37.261000+00:00',
#   '52',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '8',
#   '8',
#   '8',
#   '4',
#   '186.0',
#   '92.33',
#   '98.7',
#   '104.0',
#   '28.0',
#   '95.0',
#   '34.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.48',
#   '68.0',
#   '30.2',
#   '30.3',
#   '9.2',
#   '24500.0',
#   '276000.0',
#   '3.3',
#   '133.0',
#   '0.44',
#   '47.0',
#   '',
#   '',
#   '0.1',
#   ''),
#  ('4',
#   'Kavitha',
#   'INKABLRMAL5',
#   '2019-06-11 10:38:01.392000+00:00',
#   '2019-06-13 07:30:11.659000+00:00',
#   '40',
#   '',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '3',
#   '0',
#   '',
#   '79.0',
#   '98.7',
#   '104.0',
#   '22.0',
#   '98.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '11.6',
#   '12800.0',
#   '322000.0',
#   '5.2',
#   '137.0',
#   '0.82',
#   '20.0',
#   '0.35',
#   '',
#   '',
#   ''),
#  ('5',
#   'Sarojamma V',
#   'INKABLRMAL6',
#   '2019-06-11 22:16:30.710000+00:00',
#   '2019-06-12 07:11:36.401000+00:00',
#   '73',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '79.0',
#   '98.6',
#   '69.0',
#   '21.0',
#   '99.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '12.1',
#   '8970.0',
#   '299000.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('6',
#   'Keshava Narayana Raju',
#   'INKABLRMAL7',
#   '2019-06-11 22:52:19.014000+00:00',
#   '2019-06-13 08:26:18.420000+00:00',
#   '83',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '120.0',
#   '98.4',
#   '74.0',
#   '23.0',
#   '97.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '11.5',
#   '14930.0',
#   '383000.0',
#   '4.1',
#   '127.0',
#   '0.75',
#   '21.0',
#   '',
#   '',
#   '',
#   ''),
#  ('7',
#   'Selvaraj',
#   'INKABLRMAL8',
#   '2019-06-13 16:46:45.046000+00:00',
#   '2019-06-14 06:31:11.989000+00:00',
#   '40',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '98.2',
#   '88.0',
#   '27.0',
#   '99.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '14.3',
#   '8980.0',
#   '243000.0',
#   '4.0',
#   '138.0',
#   '1.03',
#   '32.0',
#   '0.77',
#   '',
#   '',
#   '0.88'),
#  ('8',
#   'Sai Nath',
#   'INKABLRMAL9',
#   '2019-06-14 10:32:17.807000+00:00',
#   '2019-06-15 10:10:50.022000+00:00',
#   '35',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to another facility',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '139.67',
#   '98.5',
#   '88.0',
#   '23.0',
#   '98.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('9',
#   'Shobha',
#   'INKABLRMAL10',
#   '2019-06-14 19:51:03.372000+00:00',
#   '2019-06-17 06:00:28.366000+00:00',
#   '61',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to home/self care as per medical advice',
#   '3',
#   '3',
#   '0',
#   '0',
#   '',
#   '83.33',
#   '98.6',
#   '86.0',
#   '24.0',
#   '97.0',
#   '23.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('10',
#   'Hamsa',
#   'INKABLRMAL11',
#   '2019-06-16 10:44:40.208000+00:00',
#   '2019-06-18 05:55:18.120000+00:00',
#   '63',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '3',
#   '0',
#   '0',
#   '246.3',
#   '129.33',
#   '98.5',
#   '82.0',
#   '31.0',
#   '95.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.32',
#   '137.0',
#   '28.2',
#   '15.9',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('11',
#   'Sudhakar Reddy',
#   'INKABLRMAL12',
#   '2019-06-17 18:40:36.487000+00:00',
#   '2019-06-18 04:30:52.656000+00:00',
#   '58',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '94.67',
#   '98.6',
#   '76.0',
#   '22.0',
#   '96.0',
#   '32.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('12',
#   'Ugam Devi Purohit',
#   'INKABLRMAL13',
#   '2019-06-18 12:40:45.049000+00:00',
#   '2019-06-19 09:35:40.760000+00:00',
#   '49',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '',
#   '83.33',
#   '98.5',
#   '75.0',
#   '14.0',
#   '100.0',
#   '32.0',
#   '3.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('13',
#   'Marappa',
#   'INKABLRMAL14',
#   '2019-06-18 18:06:15.321000+00:00',
#   '2019-06-20 10:43:51.571000+00:00',
#   '55',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '129.3',
#   '98.67',
#   '98.5',
#   '105.0',
#   '28.0',
#   '98.0',
#   '32.0',
#   '3.0',
#   '4.0',
#   '5.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '3.9',
#   '126.0',
#   '0.53',
#   '14.0',
#   '',
#   '',
#   '',
#   ''),
#  ('14',
#   'Banu Kumari',
#   'INKABLRMAL15',
#   '2019-06-19 11:32:38.311000+00:00',
#   '2019-06-20 06:28:46.720000+00:00',
#   '22',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '2',
#   '0',
#   '',
#   '80.67',
#   '98.6',
#   '91.0',
#   '22.0',
#   '99.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('15',
#   'Channappa Sajjan',
#   'INKABLRMAL16',
#   '2019-06-21 10:30:55.794000+00:00',
#   '2019-06-22 10:43:36.668000+00:00',
#   '74',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '208.0',
#   '89.33',
#   '98.6',
#   '93.0',
#   '18.0',
#   '96.0',
#   '21.0',
#   '3.0',
#   '2.0',
#   '4.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.5',
#   '133.0',
#   '6.1',
#   '119.0',
#   '',
#   '',
#   '',
#   ''),
#  ('16',
#   'Rajaleela',
#   'INKABLRMAL17',
#   '2019-06-21 18:13:35.360000+00:00',
#   '2019-06-22 07:08:16.658000+00:00',
#   '70',
#   'F',
#   'Mallige',
#   '[]',
#   "['Metastatic Carcinoma']",
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '166.8',
#   '86.33',
#   '98.4',
#   '68.0',
#   '13.0',
#   '96.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('17',
#   'G D SHINDE',
#   'INKABLRMAL18',
#   '2019-06-21 18:17:50.446000+00:00',
#   '2019-06-22 07:31:43.921000+00:00',
#   '83',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '97.0',
#   '85.67',
#   '98.4',
#   '87.0',
#   '23.0',
#   '100.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('18',
#   'Narayanappa V',
#   'INKABLRMAL19',
#   '2019-06-21 22:20:16.577000+00:00',
#   '2019-06-23 10:51:46.649000+00:00',
#   '',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Death',
#   '2',
#   '2',
#   '0',
#   '1',
#   '127.2',
#   '103.67',
#   '98.4',
#   '100.0',
#   '8.0',
#   '88.0',
#   '100.0',
#   '1.0',
#   '0.0',
#   '1.0',
#   '7.22',
#   '284.0',
#   '37.2',
#   '33.0',
#   '9.2',
#   '',
#   '323000.0',
#   '5.4',
#   '129.0',
#   '5.88',
#   '90.0',
#   '',
#   '',
#   '1.8',
#   ''),
#  ('19',
#   'Ramamani K',
#   'INKABLRMAL20',
#   '2019-06-22 05:36:21.119000+00:00',
#   '2019-06-22 05:57:32.808000+00:00',
#   '53',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '9.6',
#   '10560.0',
#   '207000.0',
#   '4.8',
#   '125.0',
#   '6.33',
#   '116.0',
#   '',
#   '',
#   '',
#   ''),
#  ('20',
#   'Ramamani K',
#   'INKABLRMAL20',
#   '2019-06-22 05:58:32.773000+00:00',
#   '2019-06-24 11:18:56.598000+00:00',
#   '53',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '3',
#   '0',
#   '1',
#   '102.0',
#   '72.67',
#   '98.5',
#   '97.0',
#   '23.0',
#   '96.0',
#   '40.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('21',
#   'N. Sainath',
#   'INKABLRMAL21',
#   '2019-06-22 06:36:16.341000+00:00',
#   '2019-06-23 04:44:04.369000+00:00',
#   '67',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '109.33',
#   '98.5',
#   '95.0',
#   '44.0',
#   '88.0',
#   '100.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '17.4',
#   '10040.0',
#   '213000.0',
#   '3.7',
#   '137.0',
#   '1.28',
#   '32.0',
#   '',
#   '',
#   '',
#   ''),
#  ('22',
#   'Akash',
#   'INKABLRMAL22',
#   '2019-06-22 09:13:24.651000+00:00',
#   '2019-06-24 06:40:57.995000+00:00',
#   '22',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '',
#   '91.0',
#   '98.5',
#   '99.0',
#   '22.0',
#   '98.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '21.8',
#   '7420.0',
#   '10000.0',
#   '5.3',
#   '135.0',
#   '1.25',
#   '23.0',
#   '0.82',
#   '',
#   '',
#   '1.58'),
#  ('23',
#   'Sheela',
#   'INKABLRMAL23',
#   '2019-06-23 05:21:42.281000+00:00',
#   '2019-06-24 06:46:24.906000+00:00',
#   '57',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '102.2',
#   '125.0',
#   '98.5',
#   '97.0',
#   '24.0',
#   '94.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.45',
#   '51.0',
#   '25.1',
#   '17.4',
#   '12.0',
#   '10740.0',
#   '299000.0',
#   '3.8',
#   '135.0',
#   '0.75',
#   '40.0',
#   '',
#   '',
#   '',
#   ''),
#  ('24',
#   'Uma Devamma',
#   'INKABLRMAL24',
#   '2019-06-23 06:48:03.365000+00:00',
#   '2019-06-25 04:50:44.799000+00:00',
#   '77',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to home/self care as per medical advice',
#   '3',
#   '0',
#   '0',
#   '0',
#   '82.0',
#   '50.67',
#   '98.5',
#   '86.0',
#   '31.0',
#   '95.0',
#   '32.0',
#   '2.0',
#   '1.0',
#   '4.0',
#   '',
#   '',
#   '',
#   '',
#   '13.7',
#   '12540.0',
#   '260000.0',
#   '3.4',
#   '135.0',
#   '0.65',
#   '26.0',
#   '0.6',
#   '',
#   '',
#   ''),
#  ('25',
#   'Brunda G S',
#   'INKABLRMAL25',
#   '2019-06-23 09:49:30.272000+00:00',
#   '2019-06-24 08:31:50.011000+00:00',
#   '29',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '',
#   '74.0',
#   '98.5',
#   '74.0',
#   '12.0',
#   '96.0',
#   '21.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '12.4',
#   '16060.0',
#   '198000.0',
#   '3.7',
#   '134.0',
#   '0.58',
#   '33.0',
#   '0.58',
#   '',
#   '',
#   '1.03'),
#  ('26',
#   'vbvb',
#   'INKABLRMAL26',
#   '2019-06-23 09:52:47.617000+00:00',
#   '2019-06-23 14:31:50.901000+00:00',
#   '',
#   '',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('27',
#   'Lakshmamma',
#   'INKABLRMAL27',
#   '2019-06-24 09:44:14.381000+00:00',
#   '2019-06-25 06:54:33.175000+00:00',
#   '73',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '228.0',
#   '',
#   '98.7',
#   '120.0',
#   '30.0',
#   '99.0',
#   '36.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '9.0',
#   '18000.0',
#   '198000.0',
#   '4.2',
#   '129.0',
#   '2.37',
#   '131.0',
#   '0.52',
#   '',
#   '',
#   ''),
#  ('28',
#   'Kusalavan V',
#   'INKABLRMAL28',
#   '2019-06-24 18:55:58.970000+00:00',
#   '2019-06-25 10:08:31.410000+00:00',
#   '75',
#   'M',
#   'Mallige',
#   '[]',
#   "['Metastatic Carcinoma']",
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '1',
#   '0',
#   '0',
#   '103.0',
#   '105.67',
#   '98.4',
#   '77.0',
#   '11.0',
#   '96.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '12.7',
#   '10830.0',
#   '199000.0',
#   '4.7',
#   '136.0',
#   '0.95',
#   '27.0',
#   '',
#   '',
#   '',
#   ''),
#  ('29',
#   'Sumangala V Pattanashetti',
#   'INKABLRMAL29',
#   '2019-06-26 20:23:00.154000+00:00',
#   '2019-06-29 06:45:50.310000+00:00',
#   '61',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '3',
#   '0',
#   '0',
#   '195.0',
#   '119.67',
#   '98.6',
#   '71.0',
#   '23.0',
#   '100.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '11.1',
#   '19410.0',
#   '185000.0',
#   '4.1',
#   '133.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('30',
#   'Dr Nagaraj',
#   'INKABLRMAL30',
#   '2019-06-27 08:02:43.224000+00:00',
#   '2019-06-28 06:47:35.439000+00:00',
#   '82',
#   'M',
#   'Mallige',
#   "['Heart failure']",
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '229.0',
#   '109.0',
#   '98.3',
#   '93.0',
#   '18.0',
#   '98.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '13.8',
#   '5810.0',
#   '180000.0',
#   '3.5',
#   '126.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('31',
#   'Ramamani K',
#   'INKABLRMAL31',
#   '2019-06-27 03:00:00+00:00',
#   '2019-07-12 16:58:04.880000+00:00',
#   '53',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '16',
#   '0',
#   '0',
#   '9',
#   '112.6',
#   '110.0',
#   '98.6',
#   '110.0',
#   '26.0',
#   '94.0',
#   '50.0',
#   '4.0',
#   '2.0',
#   '5.0',
#   '',
#   '',
#   '',
#   '',
#   '6.9',
#   '11280.0',
#   '125000.0',
#   '3.2',
#   '121.0',
#   '6.12',
#   '88.0',
#   '0.44',
#   '',
#   '',
#   ''),
#  ('32',
#   'Mallegowda',
#   'INKABLRMAL32',
#   '2019-06-28 03:26:41.124000+00:00',
#   '2019-06-28 06:14:12.429000+00:00',
#   '76',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to home/self care as per medical advice',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('33',
#   'Malle Gowda',
#   'INKABLRMAL33',
#   '2019-06-28 04:29:12.019000+00:00',
#   '2019-07-11 09:27:44.455000+00:00',
#   '76',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '14',
#   '13',
#   '0',
#   '7',
#   '',
#   '73.0',
#   '98.3',
#   '108.0',
#   '20.0',
#   '99.0',
#   '60.0',
#   '4.0',
#   '0.0',
#   '6.0',
#   '7.08',
#   '339.0',
#   '25.5',
#   '8.1',
#   '8.6',
#   '24920.0',
#   '194000.0',
#   '5.7',
#   '128.0',
#   '3.39',
#   '128.0',
#   '0.16',
#   '',
#   '0.5',
#   '1.9'),
#  ('34',
#   'Naveen S G',
#   'INKABLRMAL34',
#   '2019-06-28 05:19:39.861000+00:00',
#   '2019-06-29 08:15:15.032000+00:00',
#   '38',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to home/self care as per medical advice',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '105.33',
#   '98.3',
#   '76.0',
#   '18.0',
#   '95.0',
#   '21.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '7.4',
#   '82.0',
#   '36.3',
#   '21.9',
#   '13.9',
#   '6970.0',
#   '194000.0',
#   '4.5',
#   '140.0',
#   '0.83',
#   '16.0',
#   '0.42',
#   '',
#   '1.2',
#   ''),
#  ('35',
#   'K Selvam',
#   'INKABLRMAL35',
#   '2019-06-29 07:36:00.601000+00:00',
#   '2019-06-30 06:12:19.103000+00:00',
#   '64',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '308.2',
#   '106.67',
#   '98.5',
#   '71.0',
#   '16.0',
#   '100.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.6',
#   '123.0',
#   '1.51',
#   '52.0',
#   '',
#   '',
#   '',
#   ''),
#  ('36',
#   'Shanthamma',
#   'INKABLRMAL36',
#   '2019-06-29 12:34:50.275000+00:00',
#   '2019-07-01 06:39:08.315000+00:00',
#   '58',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '98.7',
#   '91.0',
#   '17.0',
#   '95.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('37',
#   'Srinivas reddy',
#   'INKABLRMAL37',
#   '2019-07-01 04:20:31.164000+00:00',
#   '2019-07-02 06:02:16.880000+00:00',
#   '68',
#   '',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '85.33',
#   '98.2',
#   '114.0',
#   '14.0',
#   '87.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '9.2',
#   '14470.0',
#   '400400.0',
#   '4.2',
#   '135.0',
#   '3.75',
#   '57.0',
#   '',
#   '',
#   '',
#   ''),
#  ('38',
#   'Lakshmamma',
#   'INKABLRMAL38',
#   '2019-07-01 10:03:32.795000+00:00',
#   '2019-07-02 06:01:55.336000+00:00',
#   '72',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '',
#   '115.0',
#   '98.7',
#   '83.0',
#   '18.0',
#   '100.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.4',
#   '133.0',
#   '1.51',
#   '70.0',
#   '',
#   '',
#   '',
#   ''),
#  ('39',
#   'Vimalamma',
#   'INKABLRMAL39',
#   '2019-07-01 13:29:02.392000+00:00',
#   '2019-07-03 14:46:49.031000+00:00',
#   '68',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to home/self care AGAINST medical advice (DAMA)',
#   '3',
#   '3',
#   '0',
#   '0',
#   '',
#   '116.0',
#   '98.4',
#   '77.0',
#   '19.0',
#   '88.0',
#   '28.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '10.3',
#   '11960.0',
#   '424000.0',
#   '4.5',
#   '106.0',
#   '1.76',
#   '46.0',
#   '0.2',
#   '',
#   '',
#   ''),
#  ('40',
#   'Siddaiha',
#   'INKABLRMAL40',
#   '2019-07-01 20:47:29.134000+00:00',
#   '2019-07-02 06:02:06.566000+00:00',
#   '68',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '84.33',
#   '98.4',
#   '118.0',
#   '25.0',
#   '90.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('41',
#   'Eramma',
#   'INKABLRMAL41',
#   '2019-07-02 10:07:24.856000+00:00',
#   '2019-07-04 06:00:01.559000+00:00',
#   '75',
#   '',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '263.0',
#   '130.33',
#   '98.5',
#   '83.0',
#   '22.0',
#   '91.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '10.3',
#   '11960.0',
#   '424000.0',
#   '4.5',
#   '106.0',
#   '1.76',
#   '46.0',
#   '0.2',
#   '',
#   '',
#   ''),
#  ('42',
#   'Siddaiha',
#   'INKABLRMAL40',
#   '2019-07-02 20:11:05.738000+00:00',
#   '2019-07-03 12:46:15.341000+00:00',
#   '68',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Death',
#   '1',
#   '0',
#   '0',
#   '0',
#   '264.0',
#   '63.33',
#   '98.4',
#   '123.0',
#   '42.0',
#   '96.0',
#   '52.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '9.7',
#   '54000.0',
#   '38000.0',
#   '3.6',
#   '134.0',
#   '2.74',
#   '89.0',
#   '1.97',
#   '',
#   '',
#   ''),
#  ('43',
#   'Aaisha begum',
#   'INKABLRMAL42',
#   '2019-07-03 06:52:19.453000+00:00',
#   '2019-07-04 04:30:36.813000+00:00',
#   '27',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '215.0',
#   '88.67',
#   '98.56',
#   '97.0',
#   '12.0',
#   '97.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '11.7',
#   '8600.0',
#   '286000.0',
#   '4.2',
#   '130.0',
#   '0.72',
#   '29.0',
#   '0.32',
#   '',
#   '',
#   ''),
#  ('44',
#   'Mohammed Asifulla',
#   'INKABLRMAL43',
#   '2019-07-03 17:51:00+00:00',
#   '2019-07-05 08:00:51.758000+00:00',
#   '61',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '0',
#   '0',
#   '0',
#   '',
#   '75.0',
#   '99.4',
#   '84.0',
#   '15.0',
#   '96.0',
#   '26.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.46',
#   '45.0',
#   '35.6',
#   '24.0',
#   '13.4',
#   '10300.0',
#   '264000.0',
#   '3.8',
#   '133.0',
#   '0.94',
#   '25.0',
#   '0.68',
#   '',
#   '1.2',
#   ''),
#  ('45',
#   'Umadevamma',
#   'INKABLRMAL44',
#   '2019-07-05 01:26:32.942000+00:00',
#   '2019-07-05 07:06:24.661000+00:00',
#   '77',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '128.0',
#   '64.33',
#   '98.6',
#   '88.0',
#   '22.0',
#   '89.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '12.5',
#   '8700.0',
#   '611000.0',
#   '5.0',
#   '134.0',
#   '0.36',
#   '11.0',
#   '0.26',
#   '',
#   '',
#   ''),
#  ('46',
#   'Boramma',
#   'INKABLRMAL45',
#   '2019-07-05 04:04:19.101000+00:00',
#   '2019-07-06 06:28:30.910000+00:00',
#   '78',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '82.67',
#   '98.6',
#   '42.0',
#   '23.0',
#   '99.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '6.9',
#   '9880.0',
#   '1.97',
#   '5.6',
#   '133.0',
#   '8.89',
#   '245.0',
#   '',
#   '',
#   '',
#   ''),
#  ('47',
#   'Padma',
#   'INKABLRMAL46',
#   '2019-07-05 08:35:58.236000+00:00',
#   '2019-07-06 06:54:48.138000+00:00',
#   '78',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '92.0',
#   '99.0',
#   '92.0',
#   '22.0',
#   '93.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.37',
#   '37.0',
#   '26.0',
#   '14.8',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '5.3',
#   ''),
#  ('48',
#   'Chandrasekhar',
#   'INKABLRMAL47',
#   '2019-07-06 04:36:51.440000+00:00',
#   '2019-07-06 06:00:04.888000+00:00',
#   '79',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '84.33',
#   '98.6',
#   '64.0',
#   '21.0',
#   '93.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('49',
#   'Praveen Kumar',
#   'INKABLRMAL48',
#   '2019-07-07 13:41:22.194000+00:00',
#   '2019-07-11 11:57:26.575000+00:00',
#   '34',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '5',
#   '5',
#   '5',
#   '0',
#   '122.1',
#   '77.67',
#   '98.5',
#   '79.0',
#   '11.0',
#   '93.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '10.0',
#   '9690.0',
#   '337000.0',
#   '3.4',
#   '137.0',
#   '0.82',
#   '30.0',
#   '0.47',
#   '',
#   '',
#   '1.07'),
#  ('50',
#   'Gowtham S',
#   'INKABLRMAL49',
#   '2019-07-08 00:51:29.994000+00:00',
#   '2019-07-08 01:05:14.631000+00:00',
#   '20',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('51',
#   'Gowtham S',
#   'INKABLRMAL50',
#   '2019-07-08 00:51:29.994000+00:00',
#   '2019-07-08 07:16:31.773000+00:00',
#   '20',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '0',
#   '0',
#   '0',
#   '',
#   '88.67',
#   '98.6',
#   '98.0',
#   '21.0',
#   '97.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('52',
#   'Saroja B P',
#   'INKABLRMAL51',
#   '2019-07-08 13:41:03.285000+00:00',
#   '2019-07-11 09:27:58.361000+00:00',
#   '67',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '4',
#   '0',
#   '0',
#   '0',
#   '224.9',
#   '76.33',
#   '98.6',
#   '83.0',
#   '36.0',
#   '100.0',
#   '40.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.44',
#   '62.0',
#   '32.6',
#   '21.8',
#   '8.1',
#   '',
#   '',
#   '5.2',
#   '133.0',
#   '',
#   '',
#   '',
#   '',
#   '0.6',
#   '1.24'),
#  ('53',
#   'Somashekar M B',
#   'INKABLRMAL52',
#   '2019-07-08 14:22:01.989000+00:00',
#   '2019-07-09 11:03:03+00:00',
#   '66',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '201.0',
#   '92.0',
#   '98.6',
#   '67.0',
#   '17.0',
#   '99.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '4.0',
#   '5460.0',
#   '130000.0',
#   '4.4',
#   '140.0',
#   '1.13',
#   '112.0',
#   '1.2',
#   '',
#   '',
#   '1.73'),
#  ('54',
#   'Bili Gowda',
#   'INKABLRMAL53',
#   '2019-07-08 20:30:42.938000+00:00',
#   '2019-07-09 07:47:14.927000+00:00',
#   '65',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '1',
#   '0',
#   '0',
#   '',
#   '66.67',
#   '98.6',
#   '100.0',
#   '27.0',
#   '94.0',
#   '21.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '7.48',
#   '74.0',
#   '22.3',
#   '16.6',
#   '11.3',
#   '13000.0',
#   '33000.0',
#   '3.8',
#   '135.0',
#   '1.67',
#   '59.0',
#   '0.68',
#   '',
#   '2.1',
#   ''),
#  ('55',
#   'Banumathi B K',
#   'INKABLRMAL54',
#   '2019-07-09 07:06:13.546000+00:00',
#   '2019-07-10 07:33:57.703000+00:00',
#   '67',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '107.1',
#   '88.67',
#   '98.6',
#   '70.0',
#   '22.0',
#   '',
#   '40.0',
#   '2.0',
#   '3.0',
#   '4.0',
#   '7.49',
#   '109.0',
#   '29.0',
#   '21.6',
#   '12.7',
#   '7980.0',
#   '286000.0',
#   '4.2',
#   '131.0',
#   '0.48',
#   '27.0',
#   '0.49',
#   '',
#   '1.4',
#   '1.02'),
#  ('56',
#   'Kouser Pasha',
#   'INKABLRMAL55',
#   '2019-07-09 08:28:15.982000+00:00',
#   '2019-07-10 07:34:18.485000+00:00',
#   '55',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '150.0',
#   '81.0',
#   '98.7',
#   '107.0',
#   '18.0',
#   '96.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.52',
#   '130.0',
#   '33.4',
#   '27.3',
#   '13.4',
#   '11650.0',
#   '265000.0',
#   '3.7',
#   '130.0',
#   '0.84',
#   '21.0',
#   '0.3',
#   '',
#   '0.8',
#   '1.05'),
#  ('57',
#   'B Bhaskar',
#   'INKABLRMAL56',
#   '2019-07-09 08:29:21.406000+00:00',
#   '2019-07-12 11:02:02.026000+00:00',
#   '62',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '4',
#   '0',
#   '0',
#   '1',
#   '140.3',
#   '88.0',
#   '98.6',
#   '78.0',
#   '26.0',
#   '99.0',
#   '32.0',
#   '4.0',
#   '0.0',
#   '6.0',
#   '7.46',
#   '84.0',
#   '32.5',
#   '23.9',
#   '11.8',
#   '33680.0',
#   '366000.0',
#   '4.6',
#   '100.0',
#   '0.48',
#   '36.0',
#   '0.74',
#   '',
#   '1.2',
#   '1.36'),
#  ('58',
#   'Bili Gowda',
#   'INKABLRMAL53',
#   '2019-07-09 11:46:24.538000+00:00',
#   '2019-07-11 07:40:28.722000+00:00',
#   '65',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '3',
#   '3',
#   '0',
#   '0',
#   '202.0',
#   '86.33',
#   '98.2',
#   '106.0',
#   '23.0',
#   '97.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.48',
#   '74.0',
#   '22.3',
#   '16.6',
#   '11.3',
#   '13000.0',
#   '93000.0',
#   '3.8',
#   '135.0',
#   '1.67',
#   '59.0',
#   '0.68',
#   '',
#   '2.1',
#   ''),
#  ('59',
#   'Syed Ameer Pasha',
#   'INKABLRMAL57',
#   '2019-07-10 07:49:32.154000+00:00',
#   '2019-07-12 06:08:00+00:00',
#   '80',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Death',
#   '3',
#   '3',
#   '0',
#   '1',
#   '141.1',
#   '115.0',
#   '98.9',
#   '93.0',
#   '25.0',
#   '98.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.06',
#   '78.0',
#   '28.0',
#   '36.0',
#   '11.5',
#   '12820.0',
#   '263000.0',
#   '7.1',
#   '132.0',
#   '4.24',
#   '106.0',
#   '1.01',
#   '',
#   '7.3',
#   ''),
#  ('60',
#   'Sugunamma',
#   'INKABLRMAL58',
#   '2019-07-10 22:48:33.654000+00:00',
#   '2019-07-16 08:36:27.863000+00:00',
#   '68',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '6',
#   '4',
#   '0',
#   '0',
#   '254.1',
#   '85.67',
#   '98.5',
#   '112.0',
#   '14.0',
#   '95.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '7.51',
#   '80.0',
#   '19.0',
#   '10.9',
#   '8.7',
#   '4800.0',
#   '68000.0',
#   '3.5',
#   '131.0',
#   '3.13',
#   '104.0',
#   '',
#   '',
#   '2.31',
#   ''),
#  ('61',
#   'Hanumantappa',
#   'INKABLRMAL59',
#   '2019-07-11 07:25:23.417000+00:00',
#   '2019-07-12 09:10:49.870000+00:00',
#   '50',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '',
#   '80.0',
#   '98.6',
#   '103.0',
#   '19.0',
#   '94.0',
#   '21.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '16.0',
#   '6760.0',
#   '210000.0',
#   '3.8',
#   '140.0',
#   '0.76',
#   '21.0',
#   '0.53',
#   '',
#   '',
#   ''),
#  ('62',
#   'Mariyamma',
#   'INKABLRMAL60',
#   '2019-07-13 15:46:41.206000+00:00',
#   '2019-07-14 07:03:49.887000+00:00',
#   '75',
#   'F',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '2',
#   '0',
#   '0',
#   '130.0',
#   '96.67',
#   '98.5',
#   '84.0',
#   '20.0',
#   '100.0',
#   '36.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '10.5',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('63',
#   'Shakti Prasad',
#   'INKABLRMAL61',
#   '2019-07-13 20:43:35.304000+00:00',
#   '2019-07-15 12:51:58.367000+00:00',
#   '22',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to home/self care as per medical advice',
#   '2',
#   '0',
#   '0',
#   '0',
#   '138.0',
#   '',
#   '98.6',
#   '75.0',
#   '21.0',
#   '96.0',
#   '21.0',
#   '4.0',
#   '4.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '13.3',
#   '4300.0',
#   '281000.0',
#   '4.2',
#   '140.0',
#   '0.84',
#   '14.0',
#   '0.27',
#   '',
#   '',
#   '0.96'),
#  ('64',
#   'Mohd. Khaleed',
#   'INKABLRMAL62',
#   '2019-07-13 20:50:43.143000+00:00',
#   '2019-07-15 06:28:56.387000+00:00',
#   '23',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   'Discharged to ward/floor',
#   '2',
#   '0',
#   '0',
#   '0',
#   '119.1',
#   '72.0',
#   '98.7',
#   '96.0',
#   '18.0',
#   '98.0',
#   '21.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '6100.0',
#   '12000.0',
#   '4.2',
#   '134.0',
#   '0.72',
#   '8.0',
#   '0.34',
#   '',
#   '',
#   '1.04'),
#  ('65',
#   'Visweswaraiah T m',
#   'INKABLRMAL63',
#   '2019-07-14 15:29:54.466000+00:00',
#   '',
#   '63',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Non-Operative',
#   '',
#   '4',
#   '1',
#   '0',
#   '0',
#   '121.5',
#   '75.33',
#   '98.6',
#   '90.0',
#   '20.0',
#   '98.0',
#   '46.0',
#   '2.0',
#   '2.0',
#   '5.0',
#   '7.51',
#   '115.0',
#   '13.8',
#   '12.8',
#   '6.3',
#   '13200.0',
#   '34000.0',
#   '5.8',
#   '131.0',
#   '3.97',
#   '128.0',
#   '',
#   '',
#   '13.0',
#   '2.83'),
#  ('66',
#   'Anand',
#   'INKABLRMAL64',
#   '2019-07-16 18:41:52.326000+00:00',
#   '2019-07-17 07:27:23.604000+00:00',
#   '45',
#   'M',
#   'Mallige',
#   '[]',
#   '[]',
#   'Post-Operative',
#   'Discharged to ward/floor',
#   '1',
#   '1',
#   '0',
#   '0',
#   '',
#   '86.67',
#   '98.7',
#   '62.0',
#   '18.0',
#   '94.0',
#   '32.0',
#   '4.0',
#   '5.0',
#   '6.0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '')]

# %%
import datetime
from datetime import timedelta

# %%
timedelta(hours=5, minutes=30)
# Out:
# datetime.timedelta(seconds=19800)

# %%
list(db2.patients.find({'name':'Malcolm Merlyn'}))
# Out:
# [{'_id': ObjectId('5c88d1226dce706dc3807574'),
#   'orders': {'active': {'medications': [],
#     'diets': [],
#     'labs': [],
#     'communications': [],
#     'bloods': [],
#     'procedures': []},
#    'inactive': {'medications': [{'_id': ObjectId('5c91c9beb9b1fa693b8110ca'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'active': True,
#       'signed': 'jitesh',
#       'name': 'Depo-medroxyprogesterone',
#       'quantity': 12,
#       'unit': 'kg',
#       'route': 'IO',
#       'numberOfDoses': None,
#       'urgency': 'SOS',
#       'sosReason': 'asad',
#       'form': None,
#       'instructions': 'sdsd',
#       'pta': False,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 3, 20, 5, 3, 57, 102000),
#       'updatedAt': datetime.datetime(2019, 3, 20, 9, 54, 31, 382000),
#       'createdAt': datetime.datetime(2019, 3, 20, 9, 54, 31, 382000)},
#      {'_id': ObjectId('5c948afa6ca80d0ccd7c45dd'),
#       'frequency': {'fType': 'before',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'name': 'Medium Chain + triglycerides + soyabean Oil + omega 3 Acid + tryglycerides',
#       'quantity': 12,
#       'unit': 'IU',
#       'route': 'Intraocular',
#       'numberOfDoses': 12,
#       'urgency': 'SOS',
#       'sosReason': 'sdsds',
#       'form': 'tab',
#       'instructions': 'asas',
#       'pta': False,
#       'additionalInformation': 'asasasas',
#       'startTime': datetime.datetime(2019, 3, 22, 7, 12, 57, 230000),
#       'communicated': False,
#       'updatedAt': datetime.datetime(2019, 3, 22, 12, 5, 24, 417000),
#       'createdAt': datetime.datetime(2019, 3, 22, 12, 5, 24, 417000)},
#      {'_id': ObjectId('5c98715cade5392053e998c5'),
#       'frequency': {'fType': 'before',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'name': 'Emedastine',
#       'quantity': 12,
#       'unit': 'kg',
#       'route': 'Intraocular',
#       'numberOfDoses': 1,
#       'urgency': 'SOS',
#       'sosReason': 'dsdsdsds',
#       'form': 'tablet',
#       'instructions': 'sdsds',
#       'pta': False,
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 3, 25, 6, 12, 42, 940000),
#       'communicated': False,
#       'updatedAt': datetime.datetime(2019, 3, 25, 6, 44, 16, 136000),
#       'createdAt': datetime.datetime(2019, 3, 25, 6, 44, 16, 136000)},
#      {'_id': ObjectId('5c987b4ed75d0224ab06492f'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'name': 'Medroxyprogesterone',
#       'quantity': 2,
#       'unit': 'drops',
#       'route': 'Intraocular',
#       'numberOfDoses': 1,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'diet',
#       'instructions': 'sadsds',
#       'pta': False,
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 3, 25, 6, 55, 8, 487000),
#       'communicated': False,
#       'updatedAt': datetime.datetime(2019, 3, 25, 6, 55, 51, 716000),
#       'createdAt': datetime.datetime(2019, 3, 25, 6, 55, 51, 716000)},
#      {'_id': ObjectId('5ca734dd14481043939fad6a'),
#       'frequency': {'fType': 'continuous',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Medrogestone',
#       'quantity': 1,
#       'unit': 'grams',
#       'route': 'Epidural',
#       'numberOfDoses': 5,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'rtr',
#       'instructions': 'erere',
#       'pta': False,
#       'additionalInformation': 'ererer',
#       'startTime': datetime.datetime(2019, 4, 5, 10, 58, 34, 104000),
#       'updatedAt': datetime.datetime(2019, 4, 8, 8, 47, 14, 852000),
#       'createdAt': datetime.datetime(2019, 4, 8, 8, 47, 14, 852000)},
#      {'_id': ObjectId('5cb04353b6b1580eda6d1048'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'red',
#       'category': 'pta',
#       'name': 'Azilsartan Medoxomil',
#       'quantity': 12,
#       'unit': 'grams',
#       'route': 'Epidural',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'fff',
#       'instructions': 'sdsd',
#       'pta': True,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 4, 12, 7, 2, 15, 781000),
#       'updatedAt': datetime.datetime(2019, 4, 12, 9, 16, 20, 250000),
#       'createdAt': datetime.datetime(2019, 4, 12, 9, 16, 20, 250000)},
#      {'_id': ObjectId('5cb030d70ee2740d09f6aaf7'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Dr. Hugo Strange',
#       'state': 'red',
#       'category': 'pta',
#       'name': 'Whey Protein Hydrolysate + Medium Chain Triglygeride + Soya Oil',
#       'quantity': 12,
#       'unit': 'grams',
#       'route': 'ID',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tablet',
#       'instructions': 'dsds',
#       'pta': True,
#       'additionalInformation': 'sdd',
#       'startTime': datetime.datetime(2019, 4, 12, 6, 30, 32, 84000),
#       'updatedAt': datetime.datetime(2019, 4, 12, 9, 22, 8, 167000),
#       'createdAt': datetime.datetime(2019, 4, 12, 9, 22, 8, 167000)},
#      {'_id': ObjectId('5cb0455152f84a0ff5f97bd7'),
#       'frequency': {'fType': 'continuous',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'red',
#       'category': 'pending',
#       'name': 'Medrysone',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'ID',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'er',
#       'instructions': 'er',
#       'pta': False,
#       'additionalInformation': '',
#       'startTime': datetime.datetime(2019, 4, 12, 7, 54, 28, 652000),
#       'updatedAt': datetime.datetime(2019, 4, 12, 9, 24, 3, 808000),
#       'createdAt': datetime.datetime(2019, 4, 12, 9, 24, 3, 808000)},
#      {'_id': ObjectId('5cb05a88d32362134b67d5b9'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'red',
#       'category': 'pending',
#       'name': 'Medium Chain + triglycerides + soyabean Oil + omega 3 Acid + tryglycerides',
#       'quantity': 12,
#       'unit': 'grams',
#       'route': 'Epidural',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tablet',
#       'instructions': 'sffdf',
#       'pta': False,
#       'additionalInformation': 'dfdfdf',
#       'startTime': datetime.datetime(2019, 4, 12, 9, 29, 41, 880000),
#       'updatedAt': datetime.datetime(2019, 4, 12, 9, 30, 28, 797000),
#       'createdAt': datetime.datetime(2019, 4, 12, 9, 30, 28, 797000)},
#      {'_id': ObjectId('5cbdbaab1989123b9180bb29'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Nuclear Medicine',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'ID',
#       'numberOfDoses': 12,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tab',
#       'instructions': 'sd',
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 4, 22, 12, 59, 22, 244000),
#       'updatedAt': datetime.datetime(2019, 4, 29, 9, 1, 52, 331000),
#       'createdAt': datetime.datetime(2019, 4, 29, 9, 1, 52, 331000)},
#      {'_id': ObjectId('5cff57577b4cf75ffd670c8e'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Aspirin',
#       'quantity': 1,
#       'unit': 'g',
#       'route': 'IV',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tab',
#       'instructions': 'sdsd',
#       'pta': False,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 6, 11, 7, 25, 9, 69000),
#       'updatedAt': datetime.datetime(2019, 6, 11, 7, 25, 11, 3000)},
#      {'_id': ObjectId('5cff57967b4cf75ffd670c92'),
#       'frequency': {'fType': 'every',
#        'hours': '12',
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Aspirin',
#       'quantity': 1,
#       'unit': 'g',
#       'route': 'IV',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'aa',
#       'pta': False,
#       'additionalInformation': 'sasa',
#       'startTime': datetime.datetime(2019, 6, 11, 7, 26, 13, 803000),
#       'updatedAt': datetime.datetime(2019, 6, 11, 7, 26, 14, 347000)},
#      {'_id': ObjectId('5cd3d1c15358ce2b3ee35d41'),
#       'frequency': {'fType': 'every',
#        'hours': '12',
#        'mins': '3',
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': 'Doctor',
#       'state': 'yellow',
#       'category': 'active',
#       'name': 'Emedastine',
#       'quantity': 1,
#       'unit': 'g',
#       'route': 'IV',
#       'numberOfDoses': 2,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': None,
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 5, 9, 7, 7, 36, 507000),
#       'updatedAt': datetime.datetime(2019, 5, 9, 7, 8, 21, 607000)},
#      {'_id': ObjectId('5d1f00fa12c7983ae5aeaae8'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Azilsartan Medoxomil',
#       'quantity': 12,
#       'unit': 'grams',
#       'route': 'ID',
#       'numberOfDoses': 2,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'sdsdsd',
#       'pta': False,
#       'additionalInformation': 'sdsdsdsds',
#       'startTime': datetime.datetime(2019, 7, 5, 7, 49, 13, 753000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 7, 58, 48, 997000)},
#      {'_id': ObjectId('5d1f035512c7983ae5aeab16'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Azilsartan Medoxomil',
#       'quantity': 12,
#       'unit': 'IU/kg',
#       'route': 'Epidural',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'sdsd',
#       'pta': False,
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 7, 5, 7, 59, 15, 988000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 8, 0, 27, 479000)},
#      {'_id': ObjectId('5d1f041112c7983ae5aeab54'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Azilsartan Medoxomil',
#       'quantity': 23,
#       'unit': 'g',
#       'route': 'ID',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'asas',
#       'pta': False,
#       'additionalInformation': 'asas',
#       'startTime': datetime.datetime(2019, 7, 5, 8, 2, 24, 816000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 8, 2, 52, 102000)},
#      {'_id': ObjectId('5d1f19a912c7983ae5aeab90'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Medrogestone',
#       'quantity': 1,
#       'unit': 'IU',
#       'route': 'IM',
#       'numberOfDoses': 12,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tab',
#       'instructions': 'sdsd',
#       'pta': False,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 7, 5, 9, 34, 32, 854000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 9, 35, 4, 683000)},
#      {'_id': ObjectId('5d1f1a0512c7983ae5aeabcc'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Medroxyprogestrone',
#       'quantity': 12,
#       'unit': 'IU',
#       'route': 'IM',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'dsds',
#       'pta': False,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 7, 5, 9, 36, 5, 101000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 9, 38, 19, 954000)},
#      {'_id': ObjectId('5d1f1a2512c7983ae5aeabd0'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Medrysone',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'IM',
#       'numberOfDoses': 12,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'cap',
#       'instructions': None,
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 5, 9, 36, 36, 744000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 12, 19, 43, 801000),
#       'toBeDiscarded': True},
#      {'_id': ObjectId('5d22db36c0d94661c0b77e2f'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Dexmedetomidine',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'Epidural',
#       'numberOfDoses': 1,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'asadsad',
#       'pta': False,
#       'additionalInformation': 'asasa',
#       'startTime': datetime.datetime(2019, 7, 8, 5, 57, 10, 26000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 6, 18, 12, 957000),
#       'toBeDiscarded': True}],
#     'labs': [{'_id': ObjectId('5c909af257aacd3915a15946'),
#       'type': 'labs',
#       'active': True,
#       'signed': 'jitesh',
#       'investigation': 'Extended scleroderma panel    SCLAB SENT SOTONI',
#       'discipline': 'Immunology',
#       'specimenType': 'sputum',
#       'instructions': 'we',
#       'additionalInformation': 'wewewe',
#       'startTime': datetime.datetime(2019, 3, 19, 7, 32, 1, 894000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 19, 55, 465000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 19, 55, 465000),
#       'communicated': True},
#      {'_id': ObjectId('5caae85ef7c0b615a96f4220'),
#       'type': 'labs',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'investigation': 'Somotomedin-C (see IGF-1)',
#       'discipline': 'Biochemistry',
#       'specimenType': 'stone/calculus',
#       'instructions': 'asas',
#       'additionalInformation': 'asasas',
#       'startTime': datetime.datetime(2019, 4, 8, 6, 21, 11, 994000),
#       'endTime': datetime.datetime(2019, 4, 24, 7, 3),
#       'updatedAt': datetime.datetime(2019, 4, 8, 8, 47, 18, 741000),
#       'createdAt': datetime.datetime(2019, 4, 8, 8, 47, 18, 741000)},
#      {'_id': ObjectId('5cbdb02e7547da2dc17670c0'),
#       'type': 'labs',
#       'signed': 'Selina Kyle',
#       'state': 'yellow',
#       'category': 'active',
#       'investigation': 'Extended scleroderma panel    SCLAB SENT SOTONI',
#       'discipline': 'Immunology',
#       'specimenType': 'fluid',
#       'instructions': 'ghg',
#       'additionalInformation': 'ghgh',
#       'startTime': datetime.datetime(2019, 4, 22, 12, 14, 36, 568000),
#       'updatedAt': datetime.datetime(2019, 4, 22, 13, 9, 21, 625000)},
#      {'_id': ObjectId('5d2317cec0d94661c0b77f7b'),
#       'type': 'labs',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'active',
#       'investigation': 'Red Cell Enzymes (dicuss with laboratory)',
#       'discipline': 'Haematology',
#       'specimenType': 'blood',
#       'instructions': 'asasa',
#       'additionalInformation': 'asasa',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 15, 41, 81000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 10, 22, 48, 410000),
#       'toBeDiscarded': True}],
#     'diets': [{'_id': ObjectId('5c90a4c357aacd3915a15986'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'active': True,
#       'signed': 'jitesh',
#       'npo': None,
#       'name': 'Oral-normal',
#       'instructions': 'dfdfd',
#       'additionalInformation': 'dfdf',
#       'startTime': datetime.datetime(2019, 3, 19, 8, 13, 53, 684000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 19, 56, 486000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 19, 56, 486000)},
#      {'_id': ObjectId('5c91e3594d74d46f90ec5991'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'active': True,
#       'signed': 'jitesh',
#       'npo': None,
#       'name': 'Oral-soft',
#       'instructions': 'fdfgg',
#       'additionalInformation': 'gfgfg',
#       'startTime': datetime.datetime(2019, 3, 20, 6, 53, 12, 885000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 19, 57, 432000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 19, 57, 432000)},
#      {'_id': ObjectId('5c93675ab69d0534ab363a10'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'active': True,
#       'signed': 'jitesh',
#       'communicated': False,
#       'npo': None,
#       'name': 'Oral-soft',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 3, 21, 10, 18, 36, 473000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 19, 58, 882000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 19, 58, 882000)},
#      {'_id': ObjectId('5ca73ba5073166496bdff78b'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': 'Selina Kyle',
#       'state': 'yellow',
#       'name': 'Tube-NG',
#       'instructions': '121212',
#       'additionalInformation': 'ewewew',
#       'startTime': datetime.datetime(2019, 4, 5, 11, 27, 32, 351000),
#       'updatedAt': datetime.datetime(2019, 4, 8, 8, 47, 41, 583000)},
#      {'_id': ObjectId('5d1f1a1012c7983ae5aeabce'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Oral-semi solid',
#       'instructions': 'sds',
#       'additionalInformation': 'dsdsd',
#       'startTime': datetime.datetime(2019, 7, 5, 9, 36, 15, 783000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 9, 56, 37, 47000)},
#      {'_id': ObjectId('5d1df0f8efb3623739cd7f45'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Oral-liquid',
#       'instructions': 'adsa',
#       'additionalInformation': 'asas',
#       'startTime': datetime.datetime(2019, 7, 4, 12, 28, 39, 701000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 9, 57, 8, 234000)},
#      {'_id': ObjectId('5d231a4bc0d94661c0b78036'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Tube-NG',
#       'instructions': '1212',
#       'additionalInformation': 'dsdsd',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 26, 17, 884000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 11, 27, 49, 339000),
#       'toBeDiscarded': True},
#      {'_id': ObjectId('5d23186cc0d94661c0b77f7d'),
#       'frequency': {'fType': 'every', 'hours': '12', 'mins': None},
#       'type': 'diets',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'name': 'Oral-liquid',
#       'instructions': 'dsd',
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 18, 19, 703000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 11, 33, 56, 625000)}],
#     'communications': [{'_id': ObjectId('5c989f6bd75d0224ab064997'),
#       'type': 'communications',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'communicated': False,
#       'title': 'asdfggh',
#       'instructions': 'sdsds',
#       'additionalInformation': 'sdsda',
#       'startTime': datetime.datetime(2019, 3, 25, 9, 29, 13, 797000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 46, 49, 729000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 46, 49, 729000)},
#      {'_id': ObjectId('5d1dee8de539b936d32336f0'),
#       'type': 'communications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'active',
#       'title': 'asad',
#       'instructions': 'asasa',
#       'additionalInformation': 'sasas',
#       'startTime': datetime.datetime(2019, 7, 4, 12, 18, 19, 331000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 9, 53, 43, 201000)},
#      {'_id': ObjectId('5d1df8d83abeff39c2916934'),
#       'type': 'communications',
#       'signed': ' Doctor',
#       'state': 'red',
#       'category': 'active',
#       'title': 'asaad',
#       'instructions': 'asasa',
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 4, 13, 2, 15, 859000),
#       'updatedAt': datetime.datetime(2019, 7, 5, 9, 55, 8, 477000)},
#      {'_id': ObjectId('5d231875c0d94661c0b77f7f'),
#       'type': 'communications',
#       'signed': ' Doctor',
#       'state': 'yellow',
#       'category': 'active',
#       'title': 'sds',
#       'instructions': 'dsds',
#       'additionalInformation': 'dsdsd',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 18, 28, 219000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 10, 22, 54, 264000),
#       'toBeDiscarded': True}],
#     'bloods': [{'_id': ObjectId('5c90a4ff57aacd3915a15988'),
#       'type': 'bloods',
#       'active': True,
#       'signed': 'jitesh',
#       'title': 'FFP',
#       'quantity': 2,
#       'instructions': 'sdsds',
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 3, 19, 8, 14, 55, 43000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 19, 59, 971000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 19, 59, 971000)},
#      {'_id': ObjectId('5cab0391f7c0b615a96f425a'),
#       'type': 'bloods',
#       'active': True,
#       'signed': 'Selina Kyle',
#       'state': 'yellow',
#       'title': 'FFP',
#       'quantity': 4,
#       'instructions': 'fgfg',
#       'additionalInformation': 'fgfgf',
#       'startTime': datetime.datetime(2019, 4, 12, 7, 26),
#       'updatedAt': datetime.datetime(2019, 4, 8, 8, 34, 8, 876000),
#       'createdAt': datetime.datetime(2019, 4, 8, 8, 34, 8, 876000)},
#      {'_id': ObjectId('5cde53ac71a50168a31492d3'),
#       'type': 'bloods',
#       'signed': 'Doctor',
#       'state': 'green',
#       'category': 'active',
#       'title': 'PRBC',
#       'quantity': 12,
#       'instructions': 'wewe',
#       'additionalInformation': 'wewe',
#       'startTime': datetime.datetime(2019, 5, 17, 6, 24, 43, 137000),
#       'updatedAt': datetime.datetime(2019, 5, 17, 12, 19, 55, 798000)},
#      {'_id': ObjectId('5d00f8f1bf700c3fb2efd58c'),
#       'type': 'bloods',
#       'signed': 'Dr. Hugo Strange',
#       'state': 'red',
#       'category': 'active',
#       'title': 'FFP',
#       'quantity': 4,
#       'instructions': 'qwe',
#       'additionalInformation': 'qwe',
#       'startTime': datetime.datetime(2019, 6, 12, 13, 6, 54, 623000),
#       'updatedAt': datetime.datetime(2019, 6, 12, 13, 6, 57, 999000)},
#      {'_id': ObjectId('5d00f881bf700c3fb2efd586'),
#       'type': 'bloods',
#       'signed': 'Hugo Strange',
#       'state': 'red',
#       'category': 'active',
#       'title': 'PRBC',
#       'quantity': 3,
#       'instructions': 'qwe',
#       'additionalInformation': 'qwe',
#       'startTime': datetime.datetime(2019, 6, 12, 13, 4, 58, 879000),
#       'updatedAt': datetime.datetime(2019, 6, 12, 13, 5, 5, 256000)},
#      {'_id': ObjectId('5d23187fc0d94661c0b77f81'),
#       'type': 'bloods',
#       'signed': ' Doctor',
#       'state': 'yellow',
#       'category': 'active',
#       'title': 'PRBC',
#       'quantity': 12,
#       'instructions': 'sdsd',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 18, 39, 114000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 10, 22, 57, 723000),
#       'toBeDiscarded': True}],
#     'procedures': [{'_id': ObjectId('5c934306b381e80c28694310'),
#       'type': 'procedures',
#       'signed': 'Suraj',
#       'pType': 'Foley',
#       'site': 'sd',
#       'laterality': None,
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 3, 21, 7, 53, 40, 461000),
#       'updatedAt': datetime.datetime(2019, 3, 21, 8, 5, 9, 476000),
#       'createdAt': datetime.datetime(2019, 3, 21, 8, 5, 9, 476000)},
#      {'_id': ObjectId('5c91dd7835b2a71d7fdc3413'),
#       'type': 'procedures',
#       'signed': 'Dr. Hugo Strange',
#       'pType': 'PICC',
#       'site': 'qqq',
#       'laterality': 'right',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 3, 20, 6, 28, 7, 88000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 20, 0, 816000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 20, 0, 816000)},
#      {'_id': ObjectId('5c93222f17bb5a215f48fecf'),
#       'type': 'procedures',
#       'signed': 'jitesh',
#       'name': 'neuro',
#       'pType': 'PICC',
#       'site': 'chest',
#       'laterality': 'Left',
#       'instructions': 'sdsdsd',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 3, 21, 5, 33, 33, 584000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 20, 5, 359000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 20, 5, 359000)},
#      {'_id': ObjectId('5c9347c7b381e80c2869433b'),
#       'type': 'procedures',
#       'signed': 'Suraj',
#       'pType': 'Foley',
#       'site': 'sad',
#       'laterality': None,
#       'instructions': 'sad',
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 3, 21, 8, 13, 58, 953000),
#       'updatedAt': datetime.datetime(2019, 3, 25, 9, 20, 6, 403000),
#       'createdAt': datetime.datetime(2019, 3, 25, 9, 20, 6, 403000)},
#      {'_id': ObjectId('5cab0681f7c0b615a96f4266'),
#       'type': 'procedures',
#       'signed': 'Selina Kyle',
#       'state': 'yellow',
#       'name': None,
#       'pType': 'Introducer',
#       'site': 'leg',
#       'laterality': 'NA',
#       'instructions': 'dfdf',
#       'additionalInformation': 'dfdf',
#       'startTime': datetime.datetime(2019, 4, 8, 8, 29, 45, 990000),
#       'endTime': datetime.datetime(2019, 4, 11, 7, 4),
#       'updatedAt': datetime.datetime(2019, 4, 8, 8, 34, 10, 303000),
#       'createdAt': datetime.datetime(2019, 4, 8, 8, 34, 10, 303000)},
#      {'_id': ObjectId('5cbdb4e67547da2dc17670d4'),
#       'type': 'procedures',
#       'state': 'red',
#       'category': 'active',
#       'name': 'asd',
#       'pType': 'CVC',
#       'site': 'neck',
#       'laterality': 'Right',
#       'instructions': 'sdsd',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 4, 22, 12, 34, 45, 605000),
#       'updatedAt': datetime.datetime(2019, 4, 29, 8, 49, 54, 938000),
#       'createdAt': datetime.datetime(2019, 4, 29, 8, 49, 54, 938000)},
#      {'_id': ObjectId('5cbdb4e67547da2dc17670d4'),
#       'type': 'procedures',
#       'state': 'red',
#       'category': 'active',
#       'name': 'asd',
#       'pType': 'CVC',
#       'site': 'neck',
#       'laterality': 'Right',
#       'instructions': 'sdsd',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 4, 22, 12, 34, 45, 605000),
#       'updatedAt': datetime.datetime(2019, 4, 29, 8, 52, 45, 886000),
#       'createdAt': datetime.datetime(2019, 4, 29, 8, 52, 45, 886000)},
#      {'_id': ObjectId('5caeca051b68557d48287251'),
#       'type': 'procedures',
#       'signed': 'Selina Kyle',
#       'state': 'red',
#       'name': 'asdf',
#       'pType': 'CVC',
#       'site': 'asas',
#       'laterality': 'Bilateral',
#       'instructions': 'asas',
#       'additionalInformation': 'asas',
#       'startTime': datetime.datetime(2019, 4, 11, 5, 0, 52, 186000),
#       'updatedAt': datetime.datetime(2019, 4, 11, 5, 0, 53, 766000)},
#      {'_id': ObjectId('5d23188ec0d94661c0b77f83'),
#       'type': 'procedures',
#       'signed': ' Doctor',
#       'state': 'yellow',
#       'category': 'active',
#       'name': None,
#       'pType': 'Foley',
#       'site': 'Urethra',
#       'laterality': 'NA',
#       'instructions': 'sdsds',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 7, 8, 10, 18, 52, 312000),
#       'updatedAt': datetime.datetime(2019, 7, 8, 10, 22, 59, 822000),
#       'toBeDiscarded': True}]},
#    'pta': {'medications': [{'_id': ObjectId('5c8b897fb1872c5a682286a7'),
#       'frequency': {'fType': 'continuous',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'active': True,
#       'name': 'Nuclear Medicine',
#       'quantity': 12,
#       'unit': 'IU/kg',
#       'route': 'Intraocular',
#       'numberOfDoses': 23,
#       'urgency': 'SOS',
#       'sosReason': 'asasas',
#       'form': 'tab',
#       'instructions': 'sdesed',
#       'pta': True,
#       'additionalInformation': 'wewewe',
#       'startTime': datetime.datetime(2019, 3, 15, 11, 16, 14, 61000),
#       'updatedAt': datetime.datetime(2019, 3, 15, 11, 16, 15, 686000),
#       'createdAt': datetime.datetime(2019, 3, 15, 11, 16, 15, 686000)}],
#     'labs': [],
#     'diets': [],
#     'communications': [],
#     'bloods': [],
#     'procedures': []},
#    'pending': {'medications': [],
#     'labs': [],
#     'procedures': [],
#     'bloods': [],
#     'communications': [],
#     'diets': [{'_id': ObjectId('5d2727f839bca75d4cc7e51f'),
#       'frequency': {'fType': None, 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Nurse',
#       'state': 'red',
#       'category': 'pending',
#       'name': 'Oral-liquid',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 11, 12, 13, 42, 810000),
#       'updatedAt': datetime.datetime(2019, 7, 11, 12, 13, 44, 434000)},
#      {'_id': ObjectId('5d287ee729f1d9030e473bde'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Nurse',
#       'state': 'red',
#       'category': 'pending',
#       'name': 'Oral-liquid',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 12, 12, 36, 46, 376000),
#       'endTime': datetime.datetime(2019, 7, 13, 12, 30),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 36, 55, 903000)}]},
#    'completed': {'medications': [{'_id': ObjectId('5ca72e74ffc5aa423eb89fa4'),
#       'frequency': {'fType': 'after',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'signed': 'Doctor',
#       'state': 'green',
#       'name': 'Dexmedetomidine',
#       'quantity': 12,
#       'unit': 'IU/kg',
#       'route': 'Nasal Spray',
#       'numberOfDoses': 12,
#       'urgency': 'ASAP',
#       'sosReason': None,
#       'form': 'tablet',
#       'instructions': 'dsds',
#       'pta': False,
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 4, 5, 10, 31, 4, 243000),
#       'endTime': datetime.datetime(2019, 5, 1, 7, 4),
#       'updatedAt': datetime.datetime(2019, 7, 3, 14, 30, 57, 990000),
#       'category': 'completed'},
#      {'_id': ObjectId('5cbd86a296447217c88ca9d6'),
#       'frequency': {'fType': 'before',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Azilsartan Medoxomil',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'Epidural',
#       'numberOfDoses': 2,
#       'urgency': None,
#       'sosReason': None,
#       'form': 'tablet',
#       'instructions': None,
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 4, 22, 9, 17, 2, 782000),
#       'updatedAt': datetime.datetime(2019, 7, 3, 14, 36, 6, 735000)},
#      {'_id': ObjectId('5ca7352714481043939fad6e'),
#       'frequency': {'fType': 'after',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Medium Chain + triglycerides + soyabean Oil + omega 3 Acid + tryglycerides',
#       'quantity': 12,
#       'unit': 'drops',
#       'route': 'Inhalation',
#       'numberOfDoses': 12,
#       'urgency': 'STAT',
#       'sosReason': None,
#       'form': 'tablet',
#       'instructions': 'sdsds',
#       'pta': False,
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 4, 5, 10, 59, 50, 438000),
#       'updatedAt': datetime.datetime(2019, 7, 3, 14, 36, 36, 82000),
#       'category': 'completed'},
#      {'_id': ObjectId('5d19e1938c290f244a75ff1a'),
#       'frequency': {'fType': 'continuous',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Emedastine',
#       'quantity': 2,
#       'unit': 'mcg/hr',
#       'route': 'IV',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': None,
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 1, 10, 33, 54, 550000),
#       'updatedAt': datetime.datetime(2019, 7, 3, 14, 37, 57, 693000)},
#      {'_id': ObjectId('5d1b4c215a9b6b67bc844bb8'),
#       'frequency': {'fType': 'before',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': 'lunch'},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Depo-medroxyprogesterone',
#       'quantity': 12,
#       'unit': 'g',
#       'route': 'Epidural',
#       'numberOfDoses': 1,
#       'urgency': 'SOS',
#       'sosReason': 'dsdsd',
#       'form': 'cap',
#       'instructions': 'sdsd',
#       'pta': False,
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 7, 2, 12, 20, 47, 507000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 6, 25, 20, 405000)},
#      {'_id': ObjectId('5d1da07420cc075d00861d94'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Depo-medroxyprogesterone',
#       'quantity': 12,
#       'unit': 'grams',
#       'route': 'Epidural',
#       'numberOfDoses': 1,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'asas',
#       'pta': False,
#       'additionalInformation': 'asasa',
#       'startTime': datetime.datetime(2019, 7, 4, 6, 45, 4, 897000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 46, 56, 693000)},
#      {'_id': ObjectId('5d1de2bf34bb562fca2cbe85'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Depo-medroxyprogesterone',
#       'quantity': 1,
#       'unit': 'g',
#       'route': 'ID',
#       'numberOfDoses': 12,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': 'sd',
#       'pta': False,
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 7, 4, 11, 27, 58, 282000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 11, 31, 33, 442000)},
#      {'_id': ObjectId('5d27205039bca75d4cc7e4d6'),
#       'frequency': {'fType': 'once',
#        'hours': None,
#        'mins': None,
#        'timeOfDay': None},
#       'type': 'medications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Normal Saline',
#       'quantity': 1,
#       'unit': 'mg/min',
#       'route': 'Transdermal',
#       'numberOfDoses': None,
#       'urgency': None,
#       'sosReason': None,
#       'form': None,
#       'instructions': None,
#       'pta': False,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 11, 11, 41, 2, 694000),
#       'updatedAt': datetime.datetime(2019, 7, 11, 11, 43, 3, 405000)}],
#     'labs': [{'_id': ObjectId('5d1dc0b620cc075d00861de3'),
#       'type': 'labs',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'investigation': 'Red Cell Enzymes (dicuss with laboratory)',
#       'discipline': 'Haematology',
#       'specimenType': 'stone/calculus',
#       'instructions': 'asd',
#       'additionalInformation': 'asas',
#       'startTime': datetime.datetime(2019, 7, 4, 9, 2, 44, 382000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 47, 16, 505000)}],
#     'procedures': [{'_id': ObjectId('5cab0586f7c0b615a96f4260'),
#       'type': 'procedures',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': None,
#       'pType': 'Introducer',
#       'site': 'neck',
#       'laterality': 'Left',
#       'instructions': 'sdsdsd',
#       'additionalInformation': 'sdsdsd',
#       'startTime': datetime.datetime(2019, 4, 8, 8, 25, 39, 649000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 54, 56, 533000),
#       'category': 'completed'}],
#     'bloods': [{'_id': ObjectId('5cbd65dc96447217c88ca99e'),
#       'type': 'bloods',
#       'state': 'green',
#       'title': 'Whole blood',
#       'quantity': 2,
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 4, 22, 6, 57, 32, 12000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 55, 37, 704000),
#       'category': 'completed'}],
#     'communications': [{'_id': ObjectId('5cab014ff7c0b615a96f4252'),
#       'type': 'communications',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'title': 'asasadsdsd',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 4, 8, 8, 7, 35, 233000),
#       'endTime': datetime.datetime(2019, 4, 25, 7, 4),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 55, 46, 31000),
#       'category': 'completed'},
#      {'_id': ObjectId('5d1de67434bb562fca2cbedb'),
#       'type': 'communications',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'title': 'ase hi ho',
#       'instructions': 'asasa',
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 7, 4, 11, 43, 47, 255000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 12, 11, 45, 896000)}],
#     'diets': [{'_id': ObjectId('5d1dcdd034bb562fca2cbe2a'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': ' Doctor',
#       'state': 'green',
#       'category': 'completed',
#       'name': 'Oral-liquid',
#       'instructions': 'asad',
#       'additionalInformation': 'asas',
#       'startTime': datetime.datetime(2019, 7, 4, 9, 58, 38, 735000),
#       'updatedAt': datetime.datetime(2019, 7, 4, 9, 59, 58, 550000)},
#      {'_id': ObjectId('5caec4f25c40617b5cad37a5'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Oral-liquid',
#       'instructions': 'dfd',
#       'additionalInformation': 'dfdf',
#       'startTime': datetime.datetime(2019, 4, 11, 4, 39, 11, 966000),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 14, 10, 847000),
#       'toBeDiscarded': False,
#       'category': 'completed'},
#      {'_id': ObjectId('5caec8361b68557d48287245'),
#       'frequency': {'fType': 'every', 'hours': '12', 'mins': '34'},
#       'type': 'diets',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Oral-normal',
#       'instructions': '3434',
#       'additionalInformation': '3434',
#       'startTime': datetime.datetime(2019, 4, 11, 4, 53, 9, 157000),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 23, 28, 504000),
#       'category': 'completed'},
#      {'_id': ObjectId('5cbd58e796447217c88ca980'),
#       'frequency': {'fType': 'every', 'hours': '12', 'mins': '3'},
#       'type': 'diets',
#       'state': 'green',
#       'name': 'Oral-liquid',
#       'instructions': 'sds',
#       'additionalInformation': 'sdsd',
#       'startTime': datetime.datetime(2019, 4, 22, 6, 2, 14, 49000),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 32, 51, 453000),
#       'completedTime': datetime.datetime(2019, 7, 12, 12, 32, 51, 454000),
#       'category': 'completed'},
#      {'_id': ObjectId('5cbd821c96447217c88ca9d2'),
#       'frequency': {'fType': 'every', 'hours': '12', 'mins': '34'},
#       'type': 'diets',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Oral-liquid',
#       'instructions': None,
#       'additionalInformation': None,
#       'startTime': datetime.datetime(2019, 4, 22, 8, 58, 2, 831000),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 36, 22, 50000),
#       'completedTime': datetime.datetime(2019, 7, 12, 12, 36, 22, 50000),
#       'category': 'completed'},
#      {'_id': ObjectId('5cbdb0cb7547da2dc17670c4'),
#       'frequency': {'fType': 'continuous', 'hours': None, 'mins': None},
#       'type': 'diets',
#       'signed': 'Selina Kyle',
#       'state': 'green',
#       'name': 'Oral-semi solid',
#       'instructions': 'sdsd',
#       'additionalInformation': 'sdsds',
#       'startTime': datetime.datetime(2019, 4, 22, 12, 17, 14),
#       'updatedAt': datetime.datetime(2019, 7, 12, 12, 37, 8, 92000),
#       'completedTime': datetime.datetime(2019, 7, 12, 12, 37, 8, 92000),
#       'category': 'completed'}]}},
#   'io': {'props': {'drain': [], 'procedure': [], 'dialysis': []}, 'days': []},
#   'name': 'Malcolm Merlyn',
#   'sex': 'M',
#   'patientImage': 'test',
#   'heightCm': 150,
#   'heightUnit': 'cm',
#   'weightKg': None,
#   'weightUnit': 'kg',
#   'IBW': 54,
#   'BMI': None,
#   'bloodGroup': 'B-',
#   'MRN': '23323',
#   'CPMRN': 'INKAMYSBHI1',
#   'bedNo': '420',
#   'camera': None,
#   'hospitalName': 'BHIO',
#   'code': 'No CPR',
#   'ICUAdmitDate': datetime.datetime(2019, 3, 13, 9, 40, 10, 471000),
#   'allergies': 'terror spreading ',
#   'diagnoses': None,
#   'PCP': None,
#   'isCurrentlyAdmitted': True,
#   'encounters': 1,
#   'documents': [{'tags': ['Blood', 'Blood Gases', 'ABG', None],
#     '_id': ObjectId('5ccacfa2cc71731b59718707'),
#     'key': 'images/3471186759:2019-05-02T11:08:17.379Z.jpg',
#     'attributes': {'pH': '7.33',
#      'PaCO2': '14',
#      'PaO2': '250',
#      'Bicarb': '0',
#      'Lactic': '9',
#      'Na': '45',
#      'K': '56',
#      'Creatinine': '67'},
#     'reportedAt': datetime.datetime(2019, 5, 2, 11, 8, 9, 36000),
#     'updatedAt': datetime.datetime(2019, 5, 2, 11, 8, 18, 162000),
#     'createdAt': datetime.datetime(2019, 5, 2, 11, 8, 18, 162000)},
#    {'tags': ['Blood', 'Glucose', None, None],
#     '_id': ObjectId('5ccacfdacc71731b59718709'),
#     'key': '',
#     'attributes': {'Glucose': '25'},
#     'reportedAt': datetime.datetime(2019, 4, 12, 7, 15),
#     'updatedAt': datetime.datetime(2019, 5, 2, 11, 9, 14, 297000),
#     'createdAt': datetime.datetime(2019, 5, 2, 11, 9, 14, 297000)},
#    {'tags': ['Pathology', 'Cytology', None, None],
#     'inActive': True,
#     '_id': ObjectId('5cd018fd943064139240f896'),
#     'key': 'images/2351867790:2019-05-06T11:22:37.299Z.png',
#     'attributes': {'Sample type': 'as',
#      'Source': 'dsdf',
#      'Laterality': 'dfdf'},
#     'reportedAt': datetime.datetime(2019, 5, 6, 11, 22, 33, 409000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 9, 34, 9, 460000),
#     'createdAt': datetime.datetime(2019, 6, 11, 9, 34, 9, 460000)},
#    {'tags': ['Imaging', 'Radiology', 'Ultrasound', None],
#     '_id': ObjectId('5cd1310374ef5b1769ea444f'),
#     'key': 'images/3858773826:2019-05-07T07:17:23.335Z.jpg',
#     'attributes': {'Site': 'chest', 'Laterality': 'none'},
#     'updatedAt': datetime.datetime(2019, 5, 7, 7, 17, 23, 988000),
#     'createdAt': datetime.datetime(2019, 5, 7, 7, 17, 23, 988000)},
#    {'tags': ['Imaging', 'Radiology', 'Xrays', None],
#     'inActive': True,
#     '_id': ObjectId('5cd3e1525358ce2b3ee35d75'),
#     'key': 'images/326650302:2019-05-09T08:14:10.210Z.jpg',
#     'attributes': {'Site': 'chest', 'Laterality': 'none'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 8, 14, 7, 837000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 9, 23, 56, 48000),
#     'createdAt': datetime.datetime(2019, 6, 11, 9, 23, 56, 48000)},
#    {'tags': ['Imaging', 'Radiology', 'Xrays', None],
#     'inActive': True,
#     '_id': ObjectId('5cd3e2e45358ce2b3ee35d93'),
#     'key': 'images/1186686256:2019-05-09T08:20:51.914Z.jpg',
#     'attributes': {'Site': 'qwe', 'Laterality': 'asas'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 8, 20, 47, 421000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 9, 16, 20, 74000),
#     'createdAt': datetime.datetime(2019, 6, 11, 9, 16, 20, 74000)},
#    {'tags': ['Imaging', 'Radiology', 'Xrays', None],
#     'isInactive': True,
#     '_id': ObjectId('5cd3eb275358ce2b3ee35dc0'),
#     'key': 'images/3814122347:2019-05-09T08:56:06.595Z.jpg',
#     'attributes': {'Site': 'asd', 'Laterality': 'qwqw'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 8, 56, 2, 453000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 12, 41, 16, 323000),
#     'createdAt': datetime.datetime(2019, 6, 11, 12, 41, 16, 323000),
#     'reason': 'sdsdsd'},
#    {'tags': ['Imaging', 'Radiology', 'Ultrasound', None],
#     'inActive': True,
#     '_id': ObjectId('5cd3eb8e5358ce2b3ee35dc6'),
#     'key': 'images/3561619877:2019-05-09T08:57:49.652Z.jpg',
#     'attributes': {'Site': 'sds', 'Laterality': 'sdsd'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 8, 57, 46, 218000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 9, 41, 16, 851000),
#     'createdAt': datetime.datetime(2019, 6, 11, 9, 41, 16, 851000)},
#    {'tags': ['Blood', 'Hematology', 'CBC', None],
#     '_id': ObjectId('5cd3ec4e5358ce2b3ee35dcc'),
#     'key': 'images/2968368016:2019-05-09T09:01:01.827Z.png',
#     'attributes': {'Hb': 'ere',
#      'Platelet': 'er',
#      'MCV': 'er',
#      'Eosinophil': 'er',
#      'Neutrophils': 'er'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 9, 0, 55, 512000),
#     'updatedAt': datetime.datetime(2019, 5, 9, 9, 1, 2, 257000),
#     'createdAt': datetime.datetime(2019, 5, 9, 9, 1, 2, 257000)},
#    {'tags': ['Imaging', 'Radiology', 'Ultrasound', None],
#     'inActive': True,
#     '_id': ObjectId('5cd3ed945358ce2b3ee35dd2'),
#     'key': 'images/4104925324:2019-05-09T09:06:27.883Z.jpg',
#     'attributes': {'Site': 'abdomen', 'Laterality': 'left'},
#     'reportedAt': datetime.datetime(2019, 5, 9, 9, 6, 23, 62000),
#     'updatedAt': datetime.datetime(2019, 6, 11, 9, 36, 3, 470000),
#     'createdAt': datetime.datetime(2019, 6, 11, 9, 36, 3, 470000)},
#    {'tags': ['Blood', 'Hematology', 'CBC', None],
#     'isInactive': True,
#     '_id': ObjectId('5cd3eff85358ce2b3ee35ddc'),
# ...
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 55, 11, 138000),
#        'pendOrSigned': 'pended',
#        'lock': 'Nurse'},
#       {'_id': ObjectId('5d120c43fa6e3063265a67e7'),
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 57, 55, 395000),
#        'addendum': [],
#        'pendOrSigned': 'pended'},
#       {'_id': ObjectId('5d120c43fa6e3063265a67e7'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 57, 55, 395000),
#        'pendOrSigned': 'pended',
#        'lock': 'Nurse'},
#       {'_id': ObjectId('5d120c8d662dcd6352f13dd0'),
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 59, 9, 828000),
#        'addendum': [],
#        'pendOrSigned': 'pended'},
#       {'_id': ObjectId('5d120c8d662dcd6352f13dd0'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 59, 9, 828000),
#        'pendOrSigned': 'pended',
#        'lock': 'Hugo Strange'},
#       {'_id': ObjectId('5d120c8d662dcd6352f13dd0'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Nursing',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;fdsfdsf</p><p>dsfsdf</p><p>dsfsdfasdsadsdsdssadnsakdqqqqq</p>',
#        'timestamp': datetime.datetime(2019, 6, 25, 11, 59, 9, 828000),
#        'pendOrSigned': 'pended'}],
#      'isDeleteEnabled': False},
#     {'_id': ObjectId('5d121099a9e90b63f336c882'),
#      'createdTimestamp': datetime.datetime(2019, 6, 25, 12, 16, 25, 572000),
#      'content': [{'_id': ObjectId('5d121099a9e90b63f336c883'),
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 16, 25, 572000),
#        'pendOrSigned': 'pended',
#        'addendum': []},
#       {'_id': ObjectId('5d121099a9e90b63f336c883'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 16, 25, 572000),
#        'pendOrSigned': 'pended',
#        'lock': 'Nurse'},
#       {'_id': ObjectId('5d121099a9e90b63f336c883'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 16, 25, 572000),
#        'pendOrSigned': 'pended'},
#       {'_id': ObjectId('5d121099a9e90b63f336c883'),
#        'addendum': [],
#        'author': 'Nurse',
#        'authorId': 'nurse@cp.net',
#        'authorType': 'Nurse',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 16, 25, 572000),
#        'pendOrSigned': 'pended',
#        'lock': 'Hugo Strange'},
#       {'_id': ObjectId('5d1210e0a9e90b63f336c986'),
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 17, 36, 169000),
#        'addendum': [],
#        'pendOrSigned': 'signed'},
#       {'_id': ObjectId('5d1210e0a9e90b63f336c986'),
#        'addendum': [],
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 17, 36, 169000),
#        'pendOrSigned': 'signed',
#        'lock': 'Hugo Strange'},
#       {'_id': ObjectId('5d1210e5a9e90b63f336c9bd'),
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 17, 41, 197000),
#        'addendum': [],
#        'pendOrSigned': 'pended'},
#       {'_id': ObjectId('5d1210e5a9e90b63f336c9bd'),
#        'addendum': [],
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 17, 41, 197000),
#        'pendOrSigned': 'pended'},
#       {'_id': ObjectId('5d1210e5a9e90b63f336c9bd'),
#        'addendum': [],
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 17, 41, 197000),
#        'pendOrSigned': 'pended',
#        'lock': 'Hugo Strange'},
#       {'_id': ObjectId('5d12112da9e90b63f336cae2'),
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 18, 53, 689000),
#        'addendum': [],
#        'pendOrSigned': 'signed'},
#       {'_id': ObjectId('5d12112da9e90b63f336cae2'),
#        'addendum': [],
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 18, 53, 689000),
#        'pendOrSigned': 'signed',
#        'lock': 'Hugo Strange'},
#       {'_id': ObjectId('5d12112da9e90b63f336cae2'),
#        'addendum': [],
#        'author': 'Hugo Strange',
#        'authorId': 'drstrange@dc.com',
#        'authorType': 'Physician',
#        'noteType': 'Progress',
#        'primaryText': '<p><strong><u>Summary</u></strong>:&nbsp;adsdsada</p>',
#        'secondaryText': '<p><strong><u>Assessment and Plan</u></strong>:&nbsp;</p><ol><li><strong>CNS/Psych</strong>:&nbsp;</li><li><strong>CVS</strong>:&nbsp;</li><li><strong>Resp</strong>:&nbsp;asdasd</li><li><strong>Abd/nutrition</strong>:&nbsp;</li><li><strong>Renal</strong>:&nbsp;</li><li><strong>ID:</strong>&nbsp;</li><li><strong>Skin:</strong>&nbsp;sadads</li><li><strong>Endo:</strong>&nbsp;</li><li><strong>MSK:</strong>&nbsp;</li><li><strong>Prophylaxis:</strong>&nbsp;</li></ol>',
#        'tertiaryText': '<p><strong><u>To-Do List</u></strong>:&nbsp;</p><ol><li>sadads</li></ol>',
#        'timestamp': datetime.datetime(2019, 6, 25, 12, 18, 53, 689000),
#        'pendOrSigned': 'signed'}],
#      'isDeleteEnabled': False}]},
#   'isPressor': True,
#   'chronic': [],
#   'hospitalLogo': 'https://s3.ap-south-1.amazonaws.com/emr-public/assets/images/HCG-logo.png',
#   'immune': [],
#   'operativeStatus': None,
#   'phone': None,
#   'severity': 'Fair',
#   'summary': [{'_id': ObjectId('5cca9aab974b75169f550ee9'),
#     'timestamp': datetime.datetime(2019, 5, 2, 7, 22, 19, 15000),
#     'file': 'pdfs/1255993809:2019-05-02T07:22:18.526Z.pdf'},
#    {'_id': ObjectId('5cbd738a190386347adb0912'),
#     'timestamp': datetime.datetime(2019, 4, 22, 7, 55, 54, 233000),
#     'file': 'pdfs/4226202586:2019-04-22T07:55:53.826Z.pdf'},
#    {'_id': ObjectId('5cbd7235190386347adb090e'),
#     'timestamp': datetime.datetime(2019, 4, 22, 7, 50, 13, 658000),
#     'file': 'pdfs/3265026973:2019-04-22T07:50:13.220Z.pdf'},
#    {'_id': ObjectId('5cbd5674190386347adb0907'),
#     'timestamp': datetime.datetime(2019, 4, 22, 5, 51, 48, 939000),
#     'file': 'pdfs/4018051084:2019-04-22T05:51:48.493Z.pdf'},
#    {'_id': ObjectId('5cbd52dd190386347adb08f9'),
#     'timestamp': datetime.datetime(2019, 4, 22, 5, 36, 29, 534000),
#     'file': 'pdfs/3978438435:2019-04-22T05:36:28.974Z.pdf'}],
#   'pastMedicalHistory': None,
#   'isIntubated': {'value': True, 'timestamp': 1563192649685.0},
#   'isNIV': {'value': False, 'timestamp': 1563192649685.0},
#   'isTrach': {'value': False, 'timestamp': 1563192649685.0}}]

# %%
"condition_if_true if condition else condition_if_false"

# %%
d_list = True if(15 > 10) else False

# %%
d_list
# Out:
# True

# %%
pat_obj['orders']['active']['diets']
# Out:
# []
